# %% [markdown]
# ## Web Crawling

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import pandas as pd
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### Reviews of top15 beer brands

# %%
driver = webdriver.Chrome(service=Service("chromedriver.exe"))
url = "https://www.beeradvocate.com/beer/top-rated/"
driver.get(url)

# %%
links = []
for i in range(2,17):
    l1 = '//*[@id="ba-content"]/table/tbody/tr['+ str(i) +']/td[2]/a'
    l2 = driver.find_elements(By.XPATH, l1)
    links.extend(l2)

# %%
top = []
for l in links:
    l.send_keys(Keys.CONTROL +"\n") 
    time.sleep(3)
    
    main_window = driver.current_window_handle
    driver.switch_to.window(driver.window_handles[1])
    
    end = len(driver.find_elements_by_id("rating_fullview_content_2"))
    idid = [driver.find_elements_by_id("rating_fullview_content_2")[s].text for s in range(0, end)]
    
    for r in idid:
        if '\n' in r:
            top.append(r)
   
    driver.close()
    driver.switch_to.window(main_window)
    time.sleep(3)
# Out:
# <ipython-input-4-33c500aa6a90>:9: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   end = len(driver.find_elements_by_id("rating_fullview_content_2"))
# <ipython-input-4-33c500aa6a90>:10: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   idid = [driver.find_elements_by_id("rating_fullview_content_2")[s].text for s in range(0, end)]

# %%
top1 = [top[i].split("\n\n")[1:-1] for i in range(len(top))]
top2 = [''.join(top1[i]).replace("\n", "") for i in range(len(top))]

# %% [markdown]
# ### Reviews of the worst15 beer brands

# %%
driver = webdriver.Chrome(service=Service("chromedriver.exe"))
url = "https://www.beeradvocate.com/beer/worst/"
driver.get(url)

# %%
links = []
for i in range(2,17):
    l1 = '//*[@id="ba-content"]/table/tbody/tr['+ str(i) +']/td[2]/a'
    l2 = driver.find_elements(By.XPATH, l1)
    links.extend(l2)

# %%
worst = []
for l in links:
    r_count = 0
    l.send_keys(Keys.CONTROL +"\n") 
    time.sleep(3)
    
    main_window = driver.current_window_handle
    driver.switch_to.window(driver.window_handles[1])
    
    end = len(driver.find_elements_by_id("rating_fullview_content_2"))
    idid = [driver.find_elements_by_id("rating_fullview_content_2")[s].text for s in range(0, end)]
    
    for r in idid:
        if '\n' in r:
            worst.append(r)
   
    driver.close()
    driver.switch_to.window(main_window)
    time.sleep(3)
# Out:
# <ipython-input-8-065b0341fb21>:10: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   end = len(driver.find_elements_by_id("rating_fullview_content_2"))
# <ipython-input-8-065b0341fb21>:11: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   idid = [driver.find_elements_by_id("rating_fullview_content_2")[s].text for s in range(0, end)]

# %%
worst1 = [worst[i].split("\n\n")[1:-1] for i in range(len(worst))]
worst2 = [''.join(worst1[i]).replace("\n", "") for i in range(len(worst))]

# %% [markdown]
# ### Reviews of our target brands (Kloud, Hite, Cass)

# %%
klinks = ['https://www.beeradvocate.com/beer/profile/34664/120494/', 
          'https://www.beeradvocate.com/beer/profile/1472/3981/',
         'https://www.beeradvocate.com/beer/profile/874/8750/']

# %%
driver = webdriver.Chrome(service=Service("chromedriver.exe"))
kbeer = []
kbeer1 = []
for l in klinks:
    driver.get(l)
    main_window = driver.current_window_handle
    end = len(driver.find_elements_by_id("rating_fullview_content_2"))
    idid = [driver.find_elements_by_id("rating_fullview_content_2")[s].text for s in range(0, end)]
    
    for r in idid:
        if '\n' in r:
            kbeer.append(r)
    
    kbeer1.extend(kbeer[0:10])   
    kbeer = []
# Out:
# <ipython-input-12-424e000463b8>:7: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   end = len(driver.find_elements_by_id("rating_fullview_content_2"))
# <ipython-input-12-424e000463b8>:8: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   idid = [driver.find_elements_by_id("rating_fullview_content_2")[s].text for s in range(0, end)]

# %%
kbeer2 = [kbeer1[i].split("\n\n")[1:-1] for i in range(len(kbeer1))]
kbeer3 = [''.join(kbeer2[i]).replace("\n", "") for i in range(len(kbeer1))]
kloud = kbeer3[0:10]
hite = kbeer3[10:20]
cass = kbeer3[20:]

# %% [markdown]
# ## Preprocessing

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk_stopwords = set(stopwords.words("english"))
my_stopwords = ['beer', 'look', 'smell', 'taste', 'feel', 'mouthfeel', 'overall', 'good', 'terrible', 'well', 'korean']
new_stopwords = nltk_stopwords.union(my_stopwords)

# %%
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
from nltk import pos_tag
from nltk.corpus import wordnet

# %%
def get_pos(w):
    tag = pos_tag([w])[0][1][0].upper()
    if tag == "V":
        return wordnet.VERB
    elif tag == "N":
        return wordnet.NOUN
    elif tag == "J":
        return wordnet.ADJ
    elif tag == "R":
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def my_tokenizer(r):
    r1 = word_tokenize(r)
    r2 = [w.lower() for w in r1 if w.isalpha()]
    r3 = [w for w in r2 if not w in new_stopwords]
    r4 = [lem.lemmatize(w, get_pos(w)) for w in r3]
    return r4

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## 1. LSA (using SVD)

# %% [markdown]
# ### top15

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(tokenizer = my_tokenizer)
tfidf_top = tfidf.fit_transform(top2)
tfidf_terms = tfidf.get_feature_names()

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=3, random_state=0)
svd.fit(tfidf_top)
# Out:
# TruncatedSVD(n_components=3, random_state=0)

# %%
svd.components_
# Out:
# array([[ 0.00924106,  0.00714241,  0.00366116, ...,  0.00640376,
#          0.00765156,  0.01025254],
#        [-0.00512379,  0.00802232, -0.00341113, ..., -0.00487367,
#          0.00648551,  0.02080725],
#        [-0.00095513, -0.00060882,  0.00068192, ..., -0.00220068,
#          0.00641947,  0.00761665]])

# %%
svd_topics = svd.components_.argsort()[:, ::-1]
for i in range(0, 3):
    top_words = [tfidf_terms[x] for x in svd_topics[i, :5]]
    print(top_words)
# Out:
# ['maple', 'chocolate', 'thick', 'barrel', 'like']
# ['orange', 'citrus', 'hop', 'mango', 'tropical']
# ['bottle', 'courtesy', 'johnnyhops', 'share', 'thx']

# %% [markdown]
# ### worst15

# %%
tfidf_worst = tfidf.fit_transform(worst2)
tfidf_terms = tfidf.get_feature_names()

# %%
svd = TruncatedSVD(n_components=4, random_state=0)
svd.fit(tfidf_worst)
# Out:
# TruncatedSVD(n_components=4, random_state=0)

# %%
svd.components_
# Out:
# array([[ 0.00470303,  0.00554007,  0.01223386, ...,  0.00362638,
#          0.00705661,  0.0163984 ],
#        [-0.00013567,  0.00515128,  0.00525685, ...,  0.01099566,
#          0.00641434, -0.03322886],
#        [-0.00078342,  0.00523268,  0.00054709, ..., -0.00611817,
#         -0.00041922, -0.0265412 ],
#        [ 0.0031838 , -0.00803221,  0.01832461, ..., -0.00484437,
#          0.01200559, -0.00283707]])

# %%
svd_topics = svd.components_.argsort()[:, ::-1]
for i in range(0, 4):
    top_words = [tfidf_terms[x] for x in svd_topics[i, :5]]
    print(top_words)
# Out:
# ['light', 'like', 'water', 'taste', 'drink']
# ['ice', 'best', 'drink', 'get', 'price']
# ['water', 'like', 'taste', 'miller', 'coors']
# ['light', 'bud', 'miller', 'lite', 'easy']

# %% [markdown]
# ### Korean brands

# %% [markdown]
# ### Kloud

# %%
tfidf_kloud = tfidf.fit_transform(kloud)
tfidf_terms = tfidf.get_feature_names()

# %%
svd = TruncatedSVD(n_components=1, random_state=0)
svd.fit(tfidf_kloud)
# Out:
# TruncatedSVD(n_components=1, random_state=0)

# %%
svd.components_
# Out:
# array([[0.02659428, 0.02025397, 0.05044032, 0.02025397, 0.01103005,
#         0.04157749, 0.0924181 , 0.09985318, 0.01103005, 0.04050795,
#         0.053487  , 0.04050795, 0.01103005, 0.02025397, 0.04266514,
#         0.09594895, 0.04157749, 0.01103005, 0.1560938 , 0.09985318,
#         0.08699785, 0.05044032, 0.02025397, 0.02025397, 0.1617596 ,
#         0.02025397, 0.13987002, 0.05044032, 0.01103005, 0.04050795,
#         0.03856473, 0.05619323, 0.02025397, 0.07731433, 0.10088063,
#         0.02025397, 0.02025397, 0.02025397, 0.02025397, 0.02025397,
#         0.02025397, 0.01103005, 0.02025397, 0.05044032, 0.05619323,
#         0.13064762, 0.02025397, 0.04266514, 0.06126847, 0.02025397,
#         0.05044032, 0.02025397, 0.02025397, 0.01103005, 0.05044032,
#         0.05619323, 0.1214427 , 0.02025397, 0.01103005, 0.04157749,
#         0.04050795, 0.04266514, 0.02025397, 0.05044032, 0.02025397,
#         0.01103005, 0.01103005, 0.02025397, 0.05619323, 0.01103005,
#         0.05044032, 0.01103005, 0.01103005, 0.04050795, 0.01103005,
#         0.02025397, 0.01103005, 0.02025397, 0.02025397, 0.05044032,
#         0.01103005, 0.04050795, 0.12936471, 0.10348317, 0.0924181 ,
#         0.02025397, 0.02025397, 0.07129151, 0.05619323, 0.05619323,
#         0.07129151, 0.04157749, 0.05619323, 0.0681282 , 0.07129151,
#         0.1214427 , 0.01103005, 0.1214427 , 0.18483619, 0.02025397,
#         0.07161393, 0.01103005, 0.04050795, 0.15499461, 0.05044032,
#         0.02025397, 0.05044032, 0.02025397, 0.02206011, 0.07129151,
#         0.04050795, 0.20062359, 0.02025397, 0.04157749, 0.04157749,
#         0.05619323, 0.02025397, 0.02025397, 0.02025397, 0.02025397,
#         0.02025397, 0.04157749, 0.02025397, 0.02025397, 0.05044032,
#         0.08651926, 0.01103005, 0.13021701, 0.03309016, 0.02025397,
#         0.05044032, 0.09896098, 0.06126847, 0.05619323, 0.05044032,
#         0.05044032, 0.20496614, 0.04266514, 0.04266514, 0.01103005,
#         0.04381201, 0.06126847, 0.04050795, 0.24848481, 0.02025397,
#         0.01103005, 0.02025397, 0.03856473, 0.02025397, 0.01103005,
#         0.07129151, 0.01103005, 0.02025397, 0.06126847, 0.12559011,
#         0.04050795, 0.09687356, 0.10348317, 0.04266514, 0.11390849,
#         0.03856473, 0.01103005, 0.04266514, 0.01103005, 0.02025397,
#         0.02025397, 0.04266514, 0.02025397, 0.04050795, 0.06009661,
#         0.05044032, 0.02025397, 0.04266514, 0.05619323, 0.01103005,
#         0.06126847, 0.02025397, 0.04266514, 0.07129151, 0.02025397,
#         0.06126847, 0.02025397, 0.02025397, 0.02025397, 0.01103005,
#         0.04050795, 0.01103005, 0.01103005, 0.04050795, 0.05619323,
#         0.04050795, 0.02025397, 0.05044032, 0.02025397, 0.11134737,
#         0.02025397, 0.02025397, 0.01103005, 0.12633321, 0.01103005,
#         0.01103005, 0.02025397, 0.02025397, 0.02025397, 0.02025397,
#         0.11471994, 0.05619323, 0.02025397, 0.02025397, 0.02025397,
#         0.01103005, 0.16790147, 0.02025397, 0.13916812, 0.02025397,
#         0.02025397, 0.01103005, 0.0924181 , 0.07129151, 0.07129151,
#         0.01103005, 0.05044032, 0.08553777, 0.02025397, 0.05044032,
#         0.05044032, 0.02025397, 0.06126847, 0.02025397, 0.14636205,
#         0.09453206, 0.02025397, 0.02025397, 0.04266514, 0.01103005,
#         0.01103005, 0.02025397, 0.05044032, 0.05044032, 0.02025397,
#         0.07129151, 0.01103005, 0.02025397, 0.02025397, 0.02025397,
#         0.02025397, 0.02025397, 0.02025397, 0.04266514, 0.04157749,
#         0.02025397, 0.01103005, 0.14501119, 0.02025397, 0.02025397,
#         0.05044032, 0.15926961, 0.02025397, 0.03856473, 0.0777172 ,
#         0.02025397, 0.01103005, 0.05225543, 0.05044032, 0.01103005]])

# %%
svd_topics = svd.components_.argsort()[:, ::-1]
for i in range(0, 1):
    top_words = [tfidf_terms[x] for x in svd_topics[i, :5]]
    print(top_words)
# Out:
# ['malt', 'light', 'hop', 'grassy', 'slightly']

# %% [markdown]
# ### Hite

# %%
tfidf_hite = tfidf.fit_transform(hite)
tfidf_terms = tfidf.get_feature_names()

# %%
svd = TruncatedSVD(n_components=1, random_state=0)
svd.fit(tfidf_hite)
# Out:
# TruncatedSVD(n_components=1, random_state=0)

# %%
svd.components_
# Out:
# array([[0.04706187, 0.08487791, 0.02764983, 0.02764983, 0.02865599,
#         0.08487791, 0.04587161, 0.09354658, 0.02865599, 0.05219714,
#         0.05827533, 0.13787549, 0.16699719, 0.02764983, 0.05219714,
#         0.04587161, 0.05827533, 0.05827533, 0.02865599, 0.02764983,
#         0.05443721, 0.04706187, 0.09373209, 0.02764983, 0.06351177,
#         0.06335526, 0.17875065, 0.08487791, 0.05827533, 0.05219714,
#         0.05827533, 0.05219714, 0.04587161, 0.02764983, 0.02865599,
#         0.02764983, 0.0816052 , 0.04587161, 0.02865599, 0.09412374,
#         0.08138699, 0.13451405, 0.20354603, 0.05529965, 0.04587161,
#         0.04706187, 0.0816052 , 0.05443721, 0.05827533, 0.02764983,
#         0.11872573, 0.04706187, 0.04786509, 0.04587161, 0.02865599,
#         0.02865599, 0.13988651, 0.12158045, 0.07304423, 0.04587161,
#         0.02764983, 0.06978148, 0.02764983, 0.12718619, 0.05219714,
#         0.02865599, 0.02764983, 0.02764983, 0.05827533, 0.05219714,
#         0.11374422, 0.10836693, 0.15733892, 0.04706187, 0.02764983,
#         0.05219714, 0.09287676, 0.05529965, 0.05219714, 0.04786509,
#         0.04706187, 0.12438612, 0.02865599, 0.04706187, 0.08487791,
#         0.05827533, 0.08437923, 0.05219714, 0.04587161, 0.05529965,
#         0.04587161, 0.05443721, 0.11224955, 0.04587161, 0.08138699,
#         0.02865599, 0.02865599, 0.02865599, 0.05827533, 0.05827533,
#         0.02865599, 0.05529965, 0.05219714, 0.02764983, 0.14327154,
#         0.05443721, 0.1976857 , 0.08487791, 0.02764983, 0.0998711 ,
#         0.02865599, 0.02764983, 0.09412374, 0.02764983, 0.09042967,
#         0.05827533, 0.08336739, 0.02764983, 0.07304423, 0.04587161,
#         0.0816052 , 0.02764983, 0.04706187, 0.04706187, 0.04706187,
#         0.10439428, 0.02764983, 0.05827533, 0.05443721, 0.02764983,
#         0.14205398, 0.02764983, 0.05827533, 0.05827533, 0.05529965,
#         0.04587161, 0.07063681, 0.07304423, 0.08138699, 0.06351177,
#         0.04706187, 0.02764983, 0.04706187, 0.0816052 , 0.10836693,
#         0.05219714, 0.08138699, 0.05219714, 0.05827533, 0.0816052 ,
#         0.02865599, 0.02865599, 0.02865599, 0.05443721, 0.02764983,
#         0.02865599, 0.07304423, 0.07389956, 0.02764983, 0.02764983,
#         0.02764983, 0.05219714, 0.02865599, 0.05219714, 0.02764983,
#         0.05827533, 0.04587161, 0.02865599, 0.02764983, 0.04587161,
#         0.05443721, 0.05529965, 0.14152586, 0.08138699, 0.05827533,
#         0.04706187, 0.08336739, 0.02764983, 0.04587161, 0.04587161,
#         0.10793792, 0.04706187, 0.05443721, 0.02865599, 0.08138699,
#         0.02764983, 0.02764983, 0.05219714, 0.09174321, 0.05219714,
#         0.02764983, 0.04587161, 0.09269126, 0.04587161, 0.02764983,
#         0.02865599, 0.05827533, 0.04587161, 0.02764983, 0.21033828,
#         0.08437923, 0.02764983, 0.04587161, 0.05219714, 0.05827533]])

# %%
svd_topics = svd.components_.argsort()[:, ::-1]
for i in range(0, 1):
    top_words = [tfidf_terms[x] for x in svd_topics[i, :5]]
    print(top_words)
# Out:
# ['well', 'cold', 'light', 'bottle', 'asian']

# %% [markdown]
# ### Cass

# %%
tfidf_cass = tfidf.fit_transform(cass)
tfidf_terms = tfidf.get_feature_names()

# %%
svd = TruncatedSVD(n_components=1, random_state=0)
svd.fit(tfidf_cass)
# Out:
# TruncatedSVD(n_components=1, random_state=0)

# %%
svd.components_
# Out:
# array([[ 5.24975517e-02,  5.98811003e-02,  5.98811003e-02,
#          1.31064489e-02,  5.98811003e-02,  1.93448928e-01,
#          1.04995103e-01,  9.59618863e-02,  9.35378363e-02,
#          9.35378363e-02,  1.31064489e-02,  2.16900744e-02,
#         -9.95286401e-17,  1.31064489e-02,  5.98811003e-02,
#          5.01515864e-02,  5.01515864e-02,  9.65331783e-02,
#          3.45327072e-02,  1.31064489e-02,  9.59618863e-02,
#          1.91748001e-01,  4.33801489e-02,  9.65331783e-02,
#          4.33801489e-02,  2.95802238e-02,  1.31064489e-02,
#          5.24975517e-02,  5.01515864e-02,  1.26204086e-01,
#          1.24209801e-01,  5.24975517e-02,  2.21438127e-01,
#          1.31064489e-02,  5.01515864e-02,  5.98811003e-02,
#          9.59618863e-02,  2.16900744e-02,  2.16900744e-02,
#          2.95802238e-02,  5.98811003e-02, -9.95286401e-17,
#          2.16900744e-02,  2.16900744e-02,  3.45327072e-02,
#          5.24975517e-02,  1.31064489e-02,  2.16900744e-02,
#          2.16900744e-02,  8.02603620e-02,  5.01515864e-02,
#          3.45327072e-02,  9.65331783e-02,  8.02603620e-02,
#          1.00303173e-01,  1.00303173e-01,  5.24975517e-02,
#          3.45327072e-02,  5.24975517e-02,  1.87699596e-01,
#          5.01515864e-02,  1.31064489e-02,  5.01515864e-02,
#          9.65331783e-02,  5.01515864e-02,  1.41588017e-01,
#          3.45327072e-02,  1.26204086e-01,  5.01515864e-02,
#          5.24975517e-02,  1.91923773e-01,  5.24975517e-02,
#          1.31064489e-02,  1.47712875e-01,  5.98811003e-02,
#          1.00303173e-01,  1.31064489e-02,  1.47712875e-01,
#          3.45327072e-02,  2.16900744e-02,  9.59618863e-02,
#          5.98811003e-02,  5.98811003e-02,  9.65331783e-02,
#          5.98811003e-02,  3.45327072e-02,  5.01515864e-02,
#          2.20357090e-01,  6.10719752e-02,  5.01515864e-02,
#          1.31064489e-02,  9.59618863e-02,  7.19893863e-02,
#          1.31064489e-02,  5.01515864e-02,  1.24695451e-01,
#          2.16900744e-02,  5.01515864e-02,  3.45327072e-02,
#          1.31064489e-02,  3.45327072e-02,  1.26204086e-01,
#          1.90244088e-01,  5.24975517e-02,  1.31064489e-02,
#          5.98811003e-02,  1.31064489e-02,  5.37751093e-02,
#          5.24975517e-02,  1.04995103e-01,  1.31064489e-02,
#         -9.95286401e-17,  4.33801489e-02,  1.31064489e-02,
#          1.31064489e-02,  3.45327072e-02,  3.45327072e-02,
#          5.01515864e-02,  5.98811003e-02,  5.24975517e-02,
#          5.24975517e-02,  1.31064489e-02,  5.24975517e-02,
#          2.16900744e-02,  1.27259342e-01,  2.16900744e-02,
#          1.31064489e-02,  7.95105200e-02,  4.04976350e-02,
#          3.45327072e-02,  1.27259342e-01,  1.31064489e-02,
#          9.35378363e-02,  1.31064489e-02,  5.01515864e-02,
#          5.01515864e-02,  5.01515864e-02,  1.31064489e-02,
#          1.27259342e-01,  2.16900744e-02,  2.16900744e-02,
#          1.63638391e-01,  4.33801489e-02,  5.01515864e-02,
#          3.45327072e-02,  2.16900744e-02,  9.65331783e-02,
#          2.16900744e-02,  1.31064489e-02,  5.01515864e-02,
#          9.59618863e-02,  2.16900744e-02, -9.95286401e-17,
#          7.93099620e-02,  4.33801489e-02,  2.16900744e-02,
#          3.45327072e-02,  5.24975517e-02,  5.24975517e-02,
#          2.16900744e-02,  3.45327072e-02,  3.45327072e-02,
#          5.01515864e-02,  8.72611455e-02,  5.24975517e-02,
#          5.01515864e-02,  9.59618863e-02,  9.65331783e-02,
#          1.31064489e-02,  3.45327072e-02,  1.31064489e-02,
#          2.16900744e-02,  9.59618863e-02,  3.45327072e-02,
#          2.16900744e-02,  3.45327072e-02,  5.98811003e-02,
#          1.19762201e-01,  1.26204086e-01,  3.45327072e-02,
#         -9.95286401e-17,  1.19762201e-01,  3.45327072e-02]])

# %%
svd_topics = svd.components_.argsort()[:, ::-1]
for i in range(0, 1):
    top_words = [tfidf_terms[x] for x in svd_topics[i, :5]]
    print(top_words)
# Out:
# ['come', 'lager', 'american', 'grassy', 'bottle']

# %% [markdown]
# ## 2. LDA

# %% [markdown]
# ### TOP15

# %%
top3 = []

for d in top2:
    d1 = my_tokenizer(d)
    top3.append(d1)

top3
# Out:
# [['didnt',
#   'think',
#   'go',
#   'give',
#   'perfect',
#   'score',
#   'look',
#   'smell',
#   'taste',
#   'however',
#   'mouth',
#   'mean',
#   'equal',
#   'pardon',
#   'sit',
#   'mouth',
#   'yeh',
#   'like',
#   'twice',
#   'anything',
#   'ive',
#   'ever',
#   'grab',
#   'face',
#   'hand',
#   'say',
#   'go',
#   'throat',
#   'taste',
#   'familiar',
#   'like',
#   'real',
#   'pure',
#   'butter',
#   'real',
#   'buttermilk',
#   'pancake',
#   'fresh',
#   'highbush',
#   'blueberry',
#   'real',
#   'vermont',
#   'maple',
#   'syrup',
#   'madagascar',
#   'vanilla',
#   'serve',
#   'seattle',
#   'coffee',
#   'shot',
#   'pappy'],
#  ['read',
#   'review',
#   'call',
#   'legendary',
#   'kbbs',
#   'kinda',
#   'make',
#   'nervous',
#   'dig',
#   'stout',
#   'thought',
#   'could',
#   'miss',
#   'white',
#   'stout',
#   'happily',
#   'guy',
#   'drinking',
#   'something',
#   'else',
#   'maybe',
#   'meant',
#   'kbbs',
#   'like',
#   'mountain',
#   'dew',
#   'enjoy',
#   'reviewer',
#   'afraid',
#   'bah',
#   'care',
#   'kbbs',
#   'look',
#   'great',
#   'pour',
#   'wine',
#   'stem',
#   'really',
#   'dark',
#   'lovely',
#   'stuff',
#   'foam',
#   'judge',
#   'base',
#   'foam',
#   'yep',
#   'present',
#   'look',
#   'like',
#   'foam',
#   'wine',
#   'glass',
#   'suppose',
#   'enable',
#   'drinker',
#   'easily',
#   'acquire',
#   'aroma',
#   'one',
#   'heavy',
#   'adjunct',
#   'result',
#   'heavy',
#   'aroma',
#   'present',
#   'overwhelm',
#   'lover',
#   'thing',
#   'maple',
#   'syrup',
#   'enjoy',
#   'underneath',
#   'maple',
#   'get',
#   'pretty',
#   'standard',
#   'decent',
#   'stout',
#   'aroma',
#   'coffee',
#   'cocoa',
#   'roast',
#   'grain',
#   'maybe',
#   'mulberry',
#   'yeah',
#   'mulberry',
#   'aroma',
#   'subtle',
#   'rather',
#   'pleasant',
#   'addition',
#   'artificial',
#   'nose',
#   'much',
#   'kinda',
#   'like',
#   'someone',
#   'skip',
#   'basic',
#   'go',
#   'right',
#   'break',
#   'rule',
#   'could',
#   'go',
#   'length',
#   'fallacy',
#   'approach',
#   'taste',
#   'many',
#   'beer',
#   'learn',
#   'pay',
#   'attention',
#   'different',
#   'aspect',
#   'taste',
#   'found',
#   'review',
#   'front',
#   'back',
#   'finish',
#   'necessarily',
#   'pretentious',
#   'simply',
#   'many',
#   'reviewer',
#   'one',
#   'actually',
#   'kinda',
#   'consistent',
#   'nose',
#   'pretty',
#   'reliable',
#   'telegraph',
#   'initial',
#   'flavor',
#   'maple',
#   'maple',
#   'maple',
#   'yeah',
#   'real',
#   'maple',
#   'syrup',
#   'lot',
#   'definitely',
#   'cocoa',
#   'quite',
#   'possibly',
#   'vanilla',
#   'adjunct',
#   'present',
#   'go',
#   'trash',
#   'adjunct',
#   'knew',
#   'go',
#   'aggressive',
#   'dark',
#   'fruit',
#   'finish',
#   'abv',
#   'particular',
#   'adjunct',
#   'expect',
#   'boozy',
#   'heavy',
#   'little',
#   'carbonation',
#   'exactly',
#   'course',
#   'reflexively',
#   'say',
#   'high',
#   'rat',
#   'beer',
#   'overrate',
#   'case',
#   'agree',
#   'reactionary',
#   'approach',
#   'enjoyable',
#   'late',
#   'become',
#   'increasingly',
#   'skeptical',
#   'adjunct',
#   'stout',
#   'truly',
#   'think',
#   'quickly',
#   'use',
#   'experience',
#   'talent',
#   'produce',
#   'world',
#   'flavor',
#   'without',
#   'capriciously',
#   'toss',
#   'stuff',
#   'barrel',
#   'sum',
#   'score',
#   'ridiculously',
#   'high',
#   'score',
#   'protest'],
#  ['vintage',
#   'bottle',
#   'fuck',
#   'shit',
#   'kbbs',
#   'review',
#   'finally',
#   'legendary',
#   'absolutely',
#   'splurge',
#   'one',
#   'morbid',
#   'curiosity',
#   'get',
#   'well',
#   'ca',
#   'think',
#   'well',
#   'review',
#   'milestone',
#   'high',
#   'rat',
#   'whole',
#   'damn',
#   'world',
#   'love',
#   'maple',
#   'adjunct',
#   'cautiously',
#   'optimistic',
#   'one',
#   'guess',
#   'nothing',
#   'pop',
#   'open',
#   'huh',
#   'pours',
#   'completely',
#   'pitch',
#   'black',
#   'head',
#   'signature',
#   'brand',
#   'stemless',
#   'teku',
#   'thin',
#   'tan',
#   'ring',
#   'leaf',
#   'lacingthe',
#   'nose',
#   'maple',
#   'bomb',
#   'nice',
#   'subtlety',
#   'pick',
#   'aroma',
#   'real',
#   'maple',
#   'syrup',
#   'light',
#   'roast',
#   'coffee',
#   'sticky',
#   'caramel',
#   'pecan',
#   'pie',
#   'milk',
#   'chocolate',
#   'toast',
#   'oak',
#   'light',
#   'earthy',
#   'bourbonman',
#   'want',
#   'like',
#   'much',
#   'complex',
#   'thing',
#   'ever',
#   'goddamn',
#   'front',
#   'end',
#   'sip',
#   'taste',
#   'sticky',
#   'maple',
#   'syrup',
#   'caramel',
#   'candy',
#   'milk',
#   'chocolate',
#   'fruity',
#   'coffee',
#   'light',
#   'oak',
#   'toffee',
#   'raisin',
#   'swallow',
#   'brings',
#   'note',
#   'fruity',
#   'coffee',
#   'sticky',
#   'maple',
#   'spicy',
#   'bourbon',
#   'milk',
#   'chocolate',
#   'espresso',
#   'vanilla',
#   'ice',
#   'cream',
#   'pecan',
#   'pie',
#   'toast',
#   'oak',
#   'sublimea',
#   'medium',
#   'full',
#   'body',
#   'pair',
#   'gentle',
#   'tingle',
#   'carbonation',
#   'result',
#   'velvety',
#   'finish',
#   'surprisingly',
#   'dry',
#   'boozy',
#   'wonderful',
#   'sweetnessi',
#   'wo',
#   'even',
#   'play',
#   'around',
#   'fuck',
#   'amaze',
#   'top',
#   'world',
#   'amaze',
#   'definitely',
#   'crack',
#   'top',
#   'truly',
#   'lifetime',
#   'experience',
#   'likely',
#   'never',
#   'get',
#   'another',
#   'bottle',
#   'unless',
#   'make',
#   'trek',
#   'iowa',
#   'pru',
#   'allow',
#   'sip',
#   'review',
#   'cherish',
#   'every',
#   'sip',
#   'one',
#   'sum',
#   'part',
#   'cheer',
#   'ba'],
#  ['celebrate',
#   'buddy',
#   'rug',
#   'review',
#   'pours',
#   'almost',
#   'perfect',
#   'black',
#   'head',
#   'smell',
#   'lightly',
#   'maple',
#   'syrup',
#   'chocolate',
#   'first',
#   'sip',
#   'immediately',
#   'taste',
#   'chocolate',
#   'caramel',
#   'follow',
#   'maple',
#   'syrup',
#   'finish',
#   'syrup',
#   'flavor',
#   'lingers',
#   'department',
#   'stout',
#   'lack',
#   'feel',
#   'light',
#   'someone',
#   'fond',
#   'stout',
#   'lager',
#   'avid',
#   'fan',
#   'heavier',
#   'one',
#   'may',
#   'disappoint',
#   'great',
#   'glad',
#   'get',
#   'crack',
#   'open',
#   'bud'],
#  ['thick',
#   'syrupy',
#   'pour',
#   'mocha',
#   'head',
#   'aroma',
#   'boozy',
#   'maple',
#   'bittersweet',
#   'expectation',
#   'happy',
#   'heavy',
#   'syrupy',
#   'smooth',
#   'light',
#   'barrel',
#   'presence',
#   'flavor',
#   'blend',
#   'together',
#   'neatly'],
#  ['big', 'share', 'far', 'best', 'stout'],
#  ['fantastic',
#   'black',
#   'thick',
#   'great',
#   'tan',
#   'headsmell',
#   'maple',
#   'barreltaste',
#   'great',
#   'maple',
#   'coffee',
#   'barrel',
#   'tastefeel',
#   'full',
#   'body',
#   'creamy',
#   'light',
#   'carboverall',
#   'incredible',
#   'hype',
#   'much',
#   'maple'],
#  ['initial',
#   'nose',
#   'beautiful',
#   'maple',
#   'nice',
#   'barrel',
#   'maple',
#   'coffee',
#   'chocolate',
#   'rich',
#   'deserve',
#   'high',
#   'rating',
#   'slight',
#   'knock',
#   'viscosity'],
#  ['nightfall',
#   'appearance',
#   'present',
#   'class',
#   'shade',
#   'within',
#   'beard',
#   'iris',
#   'storm',
#   'though',
#   'arrive',
#   'predominance',
#   'peer',
#   'scheme',
#   'ayam',
#   'cemani',
#   'dyed',
#   'allocation',
#   'provoke',
#   'methodical',
#   'discharge',
#   'inasmuch',
#   'light',
#   'charcoal',
#   'late',
#   'repose',
#   'tone',
#   'cayuga',
#   'duck',
#   'give',
#   'dark',
#   'purple',
#   'aerate',
#   'exhales',
#   'conjunction',
#   'fallow',
#   'headpiece',
#   'brief',
#   'withstand',
#   'preservation',
#   'yet',
#   'justifiably',
#   'accent',
#   'address',
#   'beaver',
#   'tone',
#   'collapse',
#   'dutch',
#   'white',
#   'lip',
#   'minimal',
#   'adherence',
#   'upon',
#   'neck',
#   'fold',
#   'portrayal',
#   'come',
#   'balmy',
#   'goad',
#   'stride',
#   'notwithstanding',
#   'thermal',
#   'development',
#   'behind',
#   'tear',
#   'adequately',
#   'web',
#   'church',
#   'window',
#   'extent',
#   'scene',
#   'deep',
#   'optimization',
#   'intermission',
#   'malt',
#   'put',
#   'motion',
#   'characterize',
#   'lexicon',
#   'thick',
#   'trek',
#   'pure',
#   'maple',
#   'slight',
#   'roast',
#   'bite',
#   'aid',
#   'dimension',
#   'thereby',
#   'usher',
#   'dark',
#   'chocolate',
#   'sticky',
#   'toffee',
#   'puck',
#   'tamp',
#   'shot',
#   'back',
#   'pastiness',
#   'peripheral',
#   'fastens',
#   'bourbon',
#   'adhesion',
#   'coffee',
#   'bean',
#   'couple',
#   'aerate',
#   'basecoat',
#   'raisin',
#   'molasses',
#   'gem',
#   'stroll',
#   'cold',
#   'deciduous',
#   'forest',
#   'red',
#   'maple',
#   'birch',
#   'bark',
#   'circumference',
#   'pine',
#   'resin',
#   'barrel',
#   'interior',
#   'coat',
#   'fig',
#   'prune',
#   'beneath',
#   'malt',
#   'soothes',
#   'midriff',
#   'synergizing',
#   'cask',
#   'complexion',
#   'accordingly',
#   'caramel',
#   'crème',
#   'brûlée',
#   'middle',
#   'touch',
#   'praline',
#   'blend',
#   'put',
#   'notice',
#   'vanilla',
#   'oak',
#   'stave',
#   'furtherance',
#   'becomes',
#   'rightly',
#   'victimize',
#   'prolong',
#   'exposure',
#   'opportunity',
#   'pit',
#   'meaty',
#   'leather',
#   'tobacco',
#   'marshmallow',
#   'fondant',
#   'faint',
#   'barrel',
#   'derive',
#   'coconut',
#   'progress',
#   'sawn',
#   'wood',
#   'recoil',
#   'temperate',
#   'woodland',
#   'balminess',
#   'curb',
#   'brandy',
#   'dry',
#   'fruit',
#   'shift',
#   'hard',
#   'chime',
#   'interim',
#   'oak',
#   'sediment',
#   'lingers',
#   'dry',
#   'hop',
#   'bite',
#   'amongst',
#   'ricochet',
#   'malt',
#   'bourbon',
#   'pitch',
#   'flat',
#   'density',
#   'rhythm',
#   'behind',
#   'soft',
#   'tanninst',
#   'proactive',
#   'start',
#   'clean',
#   'maple',
#   'measure',
#   'light',
#   'bourbon',
#   'dictation',
#   'roast',
#   'grain',
#   'ester',
#   'serenely',
#   'interweave',
#   'blend',
#   'fondue',
#   'oak',
#   'atop',
#   'barhi',
#   'date',
#   'pain',
#   'aux',
#   'raisin',
#   'summersaulting',
#   'around',
#   'prune',
#   'pay',
#   'heed',
#   'lemberger',
#   'grape',
#   'aside',
#   'foretaste',
#   'mainly',
#   'situate',
#   'rich',
#   'ganache',
#   'maple',
#   'poffertjes',
#   'robust',
#   'earthiness',
#   'tends',
#   'juneberry',
#   'dark',
#   'rosin',
#   'cascade',
#   'open',
#   'malt',
#   'bready',
#   'dexterity',
#   'react',
#   'act',
#   'polymer',
#   'coalescence',
#   'chiefly',
#   'league',
#   'barrel',
#   'mechanic',
#   'besides',
#   'toast',
#   'grain',
#   'equidistant',
#   'hovers',
#   'around',
#   'caramelize',
#   'toffee',
#   'chocolate',
#   'cordial',
#   'struggle',
#   'progression',
#   'veers',
#   'fudge',
#   'fondant',
#   'complex',
#   'wooded',
#   'polymer',
#   'set',
#   'vanillin',
#   'stave',
#   'book',
#   'shelf',
#   'moreover',
#   'greenhouse',
#   'effect',
#   'becomes',
#   'prevalent',
#   'orchestration',
#   'defer',
#   'interval',
#   'light',
#   'oxygenate',
#   'restfully',
#   'across',
#   'hour',
#   'blend',
#   'incriminates',
#   'bual',
#   'madeira',
#   'region',
#   'suggests',
#   'char',
#   'fig',
#   'dry',
#   'marzipan',
#   'turn',
#   'distantly',
#   'place',
#   'roast',
#   'bite',
#   'incline',
#   'warm',
#   'degree',
#   'blend',
#   'anatomy',
#   'coda',
#   'tarry',
#   'skin',
#   'mozhee',
#   'extractionsm',
#   'level',
#   'fatness',
#   'rich',
#   'fluidity',
#   'levy',
#   'smooth',
#   'composited',
#   'viscosity',
#   'mechanic',
#   'attend',
#   'carbonation',
#   'cautiously',
#   'truncate',
#   'spectrum',
#   'warm',
#   'coordination',
#   'behind',
#   'glueyness',
#   'factor',
#   'roadmap',
#   'weigh',
#   'scale',
#   'vitrics',
#   'breath',
#   'open',
#   'air',
#   'course',
#   'dry',
#   'constitute',
#   'passing',
#   'approach',
#   'offer',
#   'adhesiveness',
#   'without',
#   'tax',
#   'saccharinity',
#   'protract',
#   'earthly',
#   'bite',
#   'waddle',
#   'exsiccation',
#   'light',
#   'caustic',
#   'tannin',
#   'physiqueso',
#   'framework',
#   'provide',
#   'eurythmic',
#   'nature',
#   'maple',
#   'backing',
#   'around',
#   'barrel',
#   'warmth',
#   'elusive',
#   'sense',
#   'earthy',
#   'livelihood',
#   'center',
#   'agenda',
#   'woody',
#   'hop',
#   'influence',
#   'remains',
#   'docile',
#   'gravity',
#   'behind',
#   'malt',
#   'blend',
#   'depth',
#   'yet',
#   'prompt',
#   'balance',
#   'refines',
#   'ester',
#   'institution',
#   'clocked',
#   'time',
#   'consequently',
#   'forest',
#   'fruit',
#   'backwoods',
#   'shroud',
#   'sense',
#   'heft',
#   'consciously',
#   'linger',
#   'palate',
#   'fondness',
#   'step'],
#  ['thanks', 'pour', 'azuelke'],
#  ['lot', 'maple', 'coffee', 'note', 'mild', 'barrel', 'presence'],
#  ['draft',
#   'pour',
#   'black',
#   'head',
#   'thick',
#   'nose',
#   'heavy',
#   'maple',
#   'coffee',
#   'really',
#   'pick',
#   'barrel',
#   'though',
#   'likewise',
#   'heavy',
#   'maple',
#   'coffee',
#   'chocolate',
#   'little',
#   'barrel',
#   'warm',
#   'medium',
#   'body',
#   'perfect',
#   'carbonation',
#   'thin',
#   'thick',
#   'standard',
#   'ba',
#   'breakfast',
#   'stout',
#   'great',
#   'hyped',
#   'ridiculous',
#   'pricing',
#   'glad',
#   'draft',
#   'pour',
#   'cost',
#   'less',
#   'per',
#   'oz',
#   'bottle',
#   'seem',
#   'almost',
#   'mornin',
#   'delight'],
#  ['vintage',
#   'drank',
#   'soon',
#   'bottle',
#   'open',
#   'rich',
#   'maple',
#   'chocolate',
#   'syrup',
#   'breakfast',
#   'glass',
#   'incredibly',
#   'smooth',
#   'ton',
#   'bourbon',
#   'flavor',
#   'alcohol',
#   'burn',
#   'thick',
#   'tg',
#   'stout',
#   'like',
#   'assassin',
#   'still',
#   'incredible',
#   'glad',
#   'chase',
#   'definitely',
#   'one',
#   'best'],
#  ['vintage',
#   'acquire',
#   'pandemic',
#   'everything',
#   'hop',
#   'would',
#   'worth',
#   'drive',
#   'track',
#   'wonderful',
#   'aroma',
#   'smooth',
#   'live',
#   'hype',
#   'one'],
#  ['well',
#   'stout',
#   'put',
#   'see',
#   'untappd',
#   'c',
#   'b',
#   'full',
#   'review',
#   'picture'],
#  ['long',
#   'time',
#   'wait',
#   'tick',
#   'one',
#   'say',
#   'pretty',
#   'underwhelmed',
#   'delicious',
#   'far',
#   'maple',
#   'syrup',
#   'go',
#   'lack',
#   'complexity',
#   'barrel',
#   'light',
#   'much',
#   'else',
#   'nice',
#   'mouth',
#   'long',
#   'finish'],
#  ['review',
#   'batch',
#   'bottle',
#   'number',
#   'taste',
#   'part',
#   'dinner',
#   'topple',
#   'goliath',
#   'pour',
#   'dinner',
#   'serve',
#   'thick',
#   'almost',
#   'black',
#   'allow',
#   'warm',
#   'enjoy',
#   'dessert',
#   'nose',
#   'bourbon',
#   'maple',
#   'syrup',
#   'thick',
#   'full',
#   'flavor',
#   'version',
#   'tap',
#   'compare',
#   'two',
#   'difficult',
#   'however',
#   'think',
#   'age',
#   'nicely',
#   'opinion',
#   'well',
#   'two'],
#  ['thick',
#   'overrate',
#   'typical',
#   'white',
#   'trash',
#   'dont',
#   'trade',
#   'ferment',
#   'maple',
#   'syrup',
#   'get',
#   'result'],
#  ['ca',
#   'perfect',
#   'guess',
#   'damn',
#   'look',
#   'marshmallow',
#   'handjee',
#   'look',
#   'awhile',
#   'look',
#   'cool',
#   'bottle',
#   'well',
#   'wine',
#   'mmmmm',
#   'see',
#   'ca',
#   'perfect',
#   'nose',
#   'gem',
#   'close',
#   'get',
#   'characteristic',
#   'dark',
#   'lord',
#   'depth',
#   'thing',
#   'go',
#   'easy',
#   'part',
#   'complex',
#   'fine',
#   'barrel',
#   'note',
#   'compete',
#   'earthy',
#   'black',
#   'malt',
#   'love',
#   'every',
#   'moment',
#   'struggle',
#   'oil',
#   'come',
#   'barley',
#   'would',
#   'fuel',
#   'surprise',
#   'telegraph',
#   'like',
#   'amateur',
#   'ali',
#   'vanilla',
#   'sweet',
#   'cocoa',
#   'gram',
#   'front',
#   'follow',
#   'bourbon',
#   'twist',
#   'chocolate',
#   'caramel',
#   'espresso',
#   'great',
#   'stout',
#   'like',
#   'chew',
#   'bubble',
#   'gum',
#   'never',
#   'get',
#   'boring',
#   'loses',
#   'flavor',
#   'heavy',
#   'like',
#   'punch',
#   'aforementioned',
#   'amateur',
#   'caught',
#   'jaw',
#   'though',
#   'sloooww',
#   'do',
#   'adjunct',
#   'stout',
#   'never',
#   'first',
#   'choice',
#   'do',
#   'right',
#   'get',
#   'something',
#   'like',
#   'like',
#   'well',
#   'straight',
#   'wws',
#   'simple',
#   'three',
#   'ingredient',
#   'brew',
#   'damn'],
#  ['pours',
#   'black',
#   'finger',
#   'khaki',
#   'foam',
#   'heavy',
#   'oily',
#   'leg',
#   'form',
#   'glass',
#   'swirl',
#   'aroma',
#   'marshmallow',
#   'brown',
#   'sugary',
#   'initially',
#   'overt',
#   'sugariness',
#   'break',
#   'away',
#   'reveal',
#   'roasty',
#   'toasty',
#   'malt',
#   'hearty',
#   'bitter',
#   'edge',
#   'underneath',
#   'bourbon',
#   'late',
#   'barrel',
#   'character',
#   'counteract',
#   'initial',
#   'sugary',
#   'note',
#   'flavor',
#   'profile',
#   'push',
#   'start',
#   'marshmallow',
#   'brown',
#   'sugar',
#   'addition',
#   'toffee',
#   'note',
#   'fade',
#   'hearty',
#   'barrel',
#   'bourbon',
#   'roasty',
#   'toasty',
#   'malt',
#   'reveal',
#   'latter',
#   'hearty',
#   'note',
#   'becomes',
#   'storyline',
#   'second',
#   'half',
#   'counter',
#   'initial',
#   'sugary',
#   'note',
#   'mouth',
#   'thick',
#   'velvety',
#   'smooth',
#   'full',
#   'texture',
#   'sugary',
#   'start',
#   'lead',
#   'dangerous',
#   'territory',
#   'follow',
#   'malt',
#   'barrel',
#   'note',
#   'balance',
#   'whole',
#   'experience',
#   'bottle',
#   'light',
#   'blue',
#   'wax',
#   'allow',
#   'warm',
#   'minute',
#   'room',
#   'temperature',
#   'removal',
#   'fridge',
#   'review',
#   'note'],
#  ['hunt',
#   'long',
#   'time',
#   'one',
#   'finally',
#   'land',
#   'little',
#   'taste',
#   'like',
#   'regular',
#   'darklord',
#   'fairly',
#   'sweet',
#   'generally',
#   'like',
#   'barrel',
#   'presence',
#   'compensates',
#   'enough',
#   'make',
#   'really',
#   'enjoyable',
#   'delivers',
#   'front',
#   'ton',
#   'vanilla',
#   'chocolate',
#   'note',
#   'heat',
#   'barrel',
#   'also',
#   'nice',
#   'thiccc'],
#  ['also',
#   'similar',
#   'fantastic',
#   'thick',
#   'black',
#   'great',
#   'thick',
#   'tan',
#   'head',
#   'big',
#   'roasty',
#   'malt',
#   'caramel',
#   'barrel',
#   'vanillataste',
#   'fantastic',
#   'vanilla',
#   'marshmallow',
#   'caramel',
#   'woody',
#   'barrelfeel',
#   'full',
#   'body',
#   'creamy',
#   'light',
#   'carboverall',
#   'incredible'],
#  ['bottle', 'courtesy', 'johnnyhops'],
#  ['brewing',
#   'pastry',
#   'stout',
#   'pastry',
#   'stout',
#   'cool',
#   'imperial',
#   'stout',
#   'dark',
#   'lord',
#   'use',
#   'trend',
#   'sweeter',
#   'sultry',
#   'heavier',
#   'strong',
#   'time',
#   'pass',
#   'double',
#   'bourbon',
#   'barrel',
#   'age',
#   'version',
#   'notorious',
#   'elixir',
#   'allow',
#   'time',
#   'finally',
#   'catch',
#   'thick',
#   'oily',
#   'onyx',
#   'look',
#   'pour',
#   'marshmallow',
#   'hanjee',
#   'share',
#   'barely',
#   'trickle',
#   'froth',
#   'fall',
#   'still',
#   'decadent',
#   'scent',
#   'vanilla',
#   'drift',
#   'gently',
#   'sweet',
#   'savory',
#   'roast',
#   'scent',
#   'espresso',
#   'cocoa',
#   'nuttiness',
#   'permeates',
#   'oxidize',
#   'aroma',
#   'sherry',
#   'port',
#   'soy',
#   'devilishly',
#   'sweet',
#   'early',
#   'cloy',
#   'nature',
#   'saturates',
#   'early',
#   'palate',
#   'molasses',
#   'sorghum',
#   'vanilla',
#   'cream',
#   'burnt',
#   'flavor',
#   'roll',
#   'along',
#   'middle',
#   'palate',
#   'full',
#   'lavish',
#   'saturation',
#   'tastebud',
#   'reveal',
#   'bold',
#   'complementary',
#   'flavor',
#   'espresso',
#   'bittersweet',
#   'chocolate',
#   'white',
#   'chocolate',
#   'sweet',
#   'wine',
#   'savory',
#   'sherry',
#   'port',
#   'madeira',
#   'hint',
#   'toward',
#   'soy',
#   'sauce',
#   'late',
#   'whisky',
#   'soak',
#   'bourbon',
#   'keep',
#   'complex',
#   'flavor',
#   'coconut',
#   'caramel',
#   'toast',
#   'oak',
#   'bourbon',
#   'spice',
#   'come',
#   'sip',
#   'rich',
#   'undeniably',
#   'cloy',
#   'sip',
#   'ale',
#   'oily',
#   'warm',
#   'palate',
#   'reserve',
#   'dinner',
#   'digestif',
#   'long',
#   'rich',
#   'fat',
#   'maltiness',
#   'cling',
#   'mouth',
#   'impossibly',
#   'long',
#   'spicy',
#   'aftertaste'],
#  ['like',
#   'slow',
#   'dance',
#   'aretha',
#   'franklin',
#   'one',
#   'soul',
#   'hot',
#   'damn',
#   'like',
#   'lasso',
#   'rex',
#   'uhhh',
#   'huh',
#   'hurdle',
#   'louis'],
#  ['vintage', 'consume'],
#  ['black',
#   'thick',
#   'copper',
#   'head',
#   'dissipates',
#   'smooth',
#   'licorice',
#   'molassestaste',
#   'ba',
#   'imperial',
#   'stout',
#   'best',
#   'right',
#   'balance',
#   'vanilla',
#   'bean',
#   'cinnamon',
#   'whiskey',
#   'dark',
#   'smooth',
#   'licorice',
#   'molasses',
#   'stout',
#   'chili',
#   'overpower',
#   'add',
#   'hint',
#   'flavor',
#   'without',
#   'overpower',
#   'smooth',
#   'thick',
#   'rich'],
#  ['exceptional', 'like', 'christmas', 'pudding', 'hint', 'chilli', 'bourbon'],
#  ['want',
#   'try',
#   'time',
#   'able',
#   'obtain',
#   'trade',
#   'fremont',
#   'pours',
#   'fairly',
#   'dark',
#   'blackish',
#   'brown',
#   'color',
#   'head',
#   'retention',
#   'considerable',
#   'lace',
#   'certainly',
#   'look',
#   'impressive',
#   'enough',
#   'nose',
#   'pick',
#   'vanilla',
#   'green',
#   'chili',
#   'pepper',
#   'chocolate',
#   'underlie',
#   'coffee',
#   'considerable',
#   'whiskey',
#   'flavor',
#   'profile',
#   'replicates',
#   'nose',
#   'pretty',
#   'closely',
#   'though',
#   'thought',
#   'bit',
#   'hot',
#   'finish',
#   'something',
#   'especially',
#   'noticeable',
#   'give',
#   'chili',
#   'flavor',
#   'say',
#   'barrel',
#   'age',
#   'seem',
#   'mute',
#   'base',
#   'flavor',
#   'somewhat',
#   'really',
#   'seem',
#   'blend',
#   'add',
#   'another',
#   'flavor',
#   'always',
#   'nice',
#   'whiskey',
#   'flavor',
#   'otherwise',
#   'seem',
#   'bring',
#   'lot',
#   'party',
#   'fairly',
#   'full',
#   'otherwise',
#   'alcohol',
#   'seem',
#   'pretty',
#   'integrate',
#   'flavor',
#   'profile',
#   'drinkability',
#   'pretty',
#   'though',
#   'hard',
#   'imagine',
#   'drinking',
#   'small',
#   'amount',
#   'nice',
#   'give',
#   'reputation',
#   'confess',
#   'expect',
#   'bit',
#   'glad',
#   'opportunity',
#   'try',
#   'probably',
#   'want',
#   'seek'],
#  ['outstanding'],
#  ['lucky',
#   'enough',
#   'try',
#   'one',
#   'xul',
#   'company',
#   'first',
#   'bottle',
#   'share',
#   'event',
#   'deep',
#   'black',
#   'nice',
#   'head',
#   'cover',
#   'nice',
#   'chocolate',
#   'caramel',
#   'mix',
#   'hint',
#   'cinnamon',
#   'barrel',
#   'present',
#   'strong',
#   'mostly',
#   'follow',
#   'except',
#   'bourbon',
#   'add',
#   'nice',
#   'little',
#   'kick',
#   'sip',
#   'molasses',
#   'seem',
#   'toward',
#   'middle',
#   'smooth',
#   'carbonation',
#   'thick',
#   'nice',
#   'first',
#   'class',
#   'stout',
#   'great',
#   'finish'],
#  ['appearance',
#   'pour',
#   'thick',
#   'black',
#   'color',
#   'dark',
#   'tan',
#   'head',
#   'body',
#   'could',
#   'block',
#   'nose',
#   'radiate',
#   'chocolate',
#   'spice',
#   'cinnamon',
#   'initially',
#   'like',
#   'boozy',
#   'chocolate',
#   'cinnamon',
#   'brought',
#   'mind',
#   'spicy',
#   'cinnamon',
#   'cooky',
#   'ancho',
#   'heat',
#   'note',
#   'raisin',
#   'juice',
#   'dark',
#   'fruit',
#   'follow',
#   'bit',
#   'warm',
#   'toward',
#   'back',
#   'linger',
#   'huge',
#   'smooth',
#   'body',
#   'little',
#   'may',
#   'exactly',
#   'expect',
#   'quite',
#   'nice'],
#  ['pours',
#   'dark',
#   'black',
#   'thin',
#   'tan',
#   'head',
#   'top',
#   'smell',
#   'cinnamon',
#   'toast',
#   'crunch',
#   'soak',
#   'bourbon',
#   'think',
#   'pretty',
#   'nice',
#   'cinnamon',
#   'touch',
#   'spice',
#   'along',
#   'vanilla',
#   'chocolate',
#   'nice',
#   'silky',
#   'burn',
#   'throat',
#   'mouth',
#   'adjunct',
#   'perfect',
#   'outstanding',
#   'fortunate',
#   'try',
#   'finally'],
#  ['big',
#   'time',
#   'grail',
#   'vintage',
#   'tap',
#   'bier',
#   'station',
#   'consume',
#   'review',
#   'october',
#   'black',
#   'finger',
#   'half',
#   'dark',
#   'caramel',
#   'foam',
#   'head',
#   'retention',
#   'aroma',
#   'spice',
#   'cinnamon',
#   'chocolate',
#   'toffee',
#   'caramel',
#   'molasses',
#   'roasty',
#   'toasty',
#   'malt',
#   'offer',
#   'firm',
#   'base',
#   'add',
#   'strong',
#   'malty',
#   'stout',
#   'backbone',
#   'whiff',
#   'sweetness',
#   'crescendo',
#   'peak',
#   'barrel',
#   'character',
#   'sweep',
#   'add',
#   'char',
#   'bourbon',
#   'bitterness',
#   'alcohol',
#   'remains',
#   'thought',
#   'allow',
#   'shine',
#   'forward',
#   'abv',
#   'load',
#   'first',
#   'whiff',
#   'last',
#   'sniff',
#   'flavor',
#   'profile',
#   'firm',
#   'stout',
#   'base',
#   'roasty',
#   'toasty',
#   'malt',
#   'form',
#   'foundation',
#   'cinnamon',
#   'spice',
#   'vanilla',
#   'caramel',
#   'molasses',
#   'toffee',
#   'cream',
#   'open',
#   'less',
#   'spicy',
#   'nose',
#   'finish',
#   'spicy',
#   'nose',
#   'say',
#   'dynamic',
#   'shape',
#   'contrast',
#   'mirror',
#   'caveat',
#   'mirror',
#   'image',
#   'barrel',
#   'character',
#   'note',
#   'char',
#   'bourbon',
#   'come',
#   'thru',
#   'end',
#   'drop',
#   'stout',
#   'octave',
#   'deeper',
#   'heartiness',
#   'despite',
#   'bourbon',
#   'character',
#   'pop',
#   'never',
#   'come',
#   'hot',
#   'mouth',
#   'thick',
#   'smooth',
#   'consistent',
#   'grit',
#   'uniform',
#   'front',
#   'back',
#   'incredible',
#   'depth',
#   'load',
#   'barrel',
#   'compliment',
#   'initial',
#   'spice',
#   'border',
#   'adhd',
#   'stout',
#   'spread',
#   'attention',
#   'spiderweb',
#   'direction',
#   'remains',
#   'cohesive',
#   'enough',
#   'form',
#   'intoxicate',
#   'pour'],
#  ['second',
#   'review',
#   'black',
#   'thick',
#   'syrupsmell',
#   'sweet',
#   'spice',
#   'chocolate',
#   'cinnamontaste',
#   'lot',
#   'spice',
#   'cinnamon',
#   'chocolate',
#   'nice',
#   'barrelfeel',
#   'thick',
#   'body',
#   'medium',
#   'carboverall',
#   'still',
#   'deliciousfirst',
#   'review',
#   'black',
#   'thick',
#   'nice',
#   'tan',
#   'rim',
#   'almost',
#   'head',
#   'fantastic',
#   'skim',
#   'much',
#   'barrel',
#   'great',
#   'balance',
#   'vanilla',
#   'cinnamon',
#   'chocolate',
#   'boozy',
#   'fantastic',
#   'blend',
#   'cinnamon',
#   'vanilla',
#   'chocolate',
#   'nice',
#   'woody',
#   'caramel',
#   'bba',
#   'boozy',
#   'full',
#   'body',
#   'creamy',
#   'slight',
#   'carb',
#   'incredible'],
#  ['bottle', 'courtesy'],
#  ['friend',
#   'surprise',
#   'excite',
#   'finally',
#   'give',
#   'try',
#   'black',
#   'body',
#   'brown',
#   'head',
#   'aroma',
#   'barrel',
#   'fuel',
#   'cinnamon',
#   'vanilla',
#   'cocoa',
#   'decent',
#   'height',
#   'pepper',
#   'rye',
#   'oak',
#   'linger',
#   'whiskey',
#   'barrel',
#   'merge',
#   'caramel',
#   'vanilla',
#   'cocoa',
#   'brown',
#   'sugar',
#   'cinnamon',
#   'pepper',
#   'rye',
#   'oak',
#   'provide',
#   'beautiful',
#   'contrast',
#   'wave',
#   'almost',
#   'hint',
#   'cola',
#   'warms',
#   'warm',
#   'sturdy',
#   'orignal',
#   'adjunct',
#   'texture',
#   'dull',
#   'bit',
#   'oak',
#   'pleasant',
#   'backbone',
#   'wonderful',
#   'admit',
#   'orignal',
#   'abraxas',
#   'still',
#   'first',
#   'heart',
#   'series'],
#  ['bottle',
#   'graciously',
#   'share',
#   'clark',
#   'peg',
#   'dark',
#   'brown',
#   'pour',
#   'light',
#   'brown',
#   'head',
#   'invite',
#   'vanilla',
#   'bean',
#   'coco',
#   'puff',
#   'aroma',
#   'sweet',
#   'delicious',
#   'vanilla',
#   'rich',
#   'caramel',
#   'decadent',
#   'chocolate',
#   'woody',
#   'note',
#   'heat',
#   'whiskey',
#   'overwhelm',
#   'backbeat',
#   'really',
#   'drink',
#   'like',
#   'er',
#   'smooth',
#   'complex',
#   'body',
#   'bravo'],
#  ['unofficially',
#   'last',
#   'top',
#   'trade',
#   'secure',
#   'change',
#   'make',
#   'calculation',
#   'make',
#   'short',
#   'glugs',
#   'bottle',
#   'super',
#   'thick',
#   'tar',
#   'black',
#   'finger',
#   'half',
#   'head',
#   'tight',
#   'thick',
#   'khaki',
#   'bubble',
#   'recedes',
#   'slowly',
#   'thin',
#   'film',
#   'collar',
#   'retain',
#   'throughout',
#   'leaf',
#   'nice',
#   'leg',
#   'glass',
#   'strong',
#   'aroma',
#   'boozy',
#   'bourbon',
#   'soften',
#   'sweet',
#   'vanilla',
#   'lightly',
#   'toast',
#   'marshmallow',
#   'fudgey',
#   'brownie',
#   'batter',
#   'brown',
#   'sugar',
#   'molasses',
#   'caramel',
#   'toast',
#   'coconut',
#   'char',
#   'oak',
#   'follow',
#   'hint',
#   'fig',
#   'linger',
#   'flavor',
#   'quite',
#   'bourbon',
#   'forward',
#   'round',
#   'smooth',
#   'like',
#   'scoop',
#   'real',
#   'vanilla',
#   'bean',
#   'ice',
#   'cream',
#   'topped',
#   'burnt',
#   'caramel',
#   'artisan',
#   'fudge',
#   'shot',
#   'high',
#   'end',
#   'bourbon',
#   'nothing',
#   'pop',
#   'much',
#   'except',
#   'maybe',
#   'bourbon',
#   'quite',
#   'mouth',
#   'thick',
#   'overly',
#   'slick',
#   'coat',
#   'mouth',
#   'linger',
#   'beg',
#   'take',
#   'another',
#   'sip',
#   'right',
#   'amount',
#   'touch',
#   'carbonation',
#   'bone',
#   'dry',
#   'slightly',
#   'boozy',
#   'finish',
#   'superb',
#   'absolute',
#   'pleasure',
#   'drink',
#   'worthy',
#   'one',
#   'last',
#   'list',
#   'blow',
#   'away',
#   'flavor',
#   'department',
#   'balance',
#   'roundedness',
#   'thing',
#   'hard',
#   'find',
#   'modern',
#   'ba',
#   'adjunct',
#   'stout',
#   'fact',
#   'could',
#   'easily',
#   'solo',
#   'dome',
#   'bottle',
#   'say',
#   'something'],
#  ['far',
#   'vanilla',
#   'barrel',
#   'age',
#   'stout',
#   'go',
#   'hard',
#   'name',
#   'well',
#   'one',
#   'sweet',
#   'short',
#   'cloy',
#   'huge',
#   'fudge',
#   'note',
#   'blend',
#   'perfectly',
#   'intense',
#   'vanilla',
#   'marshmallow',
#   'presence',
#   'miss',
#   'one',
#   'chance',
#   'get'],
#  ['bottle'],
#  ['bottle',
#   'room',
#   'tempwax',
#   'big',
#   'buggerinky',
#   'black',
#   'small',
#   'beige',
#   'head',
#   'much',
#   'brownie',
#   'batter',
#   'aroma',
#   'heat',
#   'bourbon',
#   'secondarynot',
#   'much',
#   'bitterness',
#   'roast',
#   'plenty',
#   'barrel',
#   'viscosity',
#   'motor',
#   'oil',
#   'bordering',
#   'chewy'],
#  ['top',
#   'thanks',
#   'orca',
#   'whalel',
#   'motor',
#   'oi',
#   'black',
#   'small',
#   'tan',
#   'head',
#   'deep',
#   'barrel',
#   'bit',
#   'vanilla',
#   'tobacco',
#   'vanilla',
#   'decent',
#   'amount',
#   'barrel',
#   'stout',
#   'vanilla',
#   'without',
#   'vanilla',
#   'takingf',
#   'thick',
#   'heavy',
#   'mouthfeelo',
#   'great',
#   'perfect',
#   'ba',
#   'vanilla',
#   'stout',
#   'happy',
#   'ot',
#   'finally',
#   'ticked',
#   'one'],
#  ['long',
#   'time',
#   'want',
#   'mine',
#   'vintage',
#   'unfortunately',
#   'cocoa',
#   'vanilla',
#   'cinnamon',
#   'fade',
#   'already',
#   'remains',
#   'apple',
#   'brandy',
#   'strong',
#   'ancho',
#   'chilies',
#   'spicy',
#   'burn',
#   'finish',
#   'sure',
#   'shell',
#   'former',
#   'self'],
#  ['bottle', 'share', 'thx'],
#  ['review', 'og', 'rerelease'],
#  ['amaze',
#   'combine',
#   'tobacco',
#   'pepper',
#   'vanilla',
#   'taste',
#   'like',
#   'brandy',
#   'quintessential',
#   'barrel',
#   'age',
#   'pours',
#   'perfectly',
#   'combine',
#   'amaze',
#   'carb'],
#  ['vintage',
#   'drank',
#   'note',
#   'tobacco',
#   'chocolatetaste',
#   'tobacco',
#   'power',
#   'one',
#   'begin',
#   'warms',
#   'pepper',
#   'take',
#   'unique',
#   'think',
#   'brandy',
#   'barrel',
#   'thin',
#   'expect',
#   'moreoverall',
#   'ba',
#   'expect',
#   'much',
#   'thin',
#   'note',
#   'pepper',
#   'overpower',
#   'yet',
#   'completely',
#   'unenjoyable',
#   'even',
#   'close',
#   'best',
#   'world',
#   'regardless',
#   'glad',
#   'gut',
#   'try',
#   'always',
#   'nice',
#   'see',
#   'hype',
#   'one',
#   'live'],
#  ['worth', 'idk', 'man'],
#  ['bottle',
#   'ot',
#   'thanks',
#   'jake',
#   'black',
#   'color',
#   'without',
#   'head',
#   'crazy',
#   'marshmallow',
#   'graham',
#   'cracker',
#   'nose',
#   'lot',
#   'cinnamon',
#   'chocolate',
#   'vanilla',
#   'light',
#   'spice',
#   'slight',
#   'fruity',
#   'brandy',
#   'caramel',
#   'taste',
#   'like',
#   'smores',
#   'cinnamon',
#   'toast',
#   'crunch',
#   'crazy',
#   'marshmallow',
#   'chocolate',
#   'cinnamon',
#   'dark',
#   'chocolate',
#   'vanilla',
#   'subtle',
#   'chile',
#   'spiciness',
#   'really',
#   'solid'],
#  ['spicy', 'thick'],
#  ['taste',
#   'double',
#   'barrel',
#   'age',
#   'multiple',
#   'time',
#   'multiple',
#   'year',
#   'excellent',
#   'stout',
#   'welcome',
#   'drinking',
#   'time',
#   'like',
#   'stout',
#   'however',
#   'simply',
#   'point',
#   'convince',
#   'score',
#   'result',
#   'score',
#   'local',
#   'employ',
#   'local',
#   'hype',
#   'none',
#   'less'],
#  ['stout',
#   'one',
#   'easily',
#   'top',
#   'bar',
#   'measure',
#   'ba',
#   'adjunct',
#   'stout',
#   'everything',
#   'spot',
#   'super',
#   'balance',
#   'adjunct',
#   'etc'],
#  ['thanks',
#   'new',
#   'friend',
#   'cycle',
#   'barrel',
#   'age',
#   'day',
#   'bottle',
#   'smooth',
#   'black',
#   'thin',
#   'tannish',
#   'head',
#   'fade',
#   'mix',
#   'barrel',
#   'booze',
#   'sweetness',
#   'chocolate',
#   'interest',
#   'mix',
#   'really',
#   'chocolate',
#   'barrel',
#   'coconut',
#   'hint',
#   'cinnamon',
#   'nothing',
#   'like',
#   'hunahpus',
#   'try',
#   'sweetness',
#   'barrel',
#   'give',
#   'nice',
#   'sharp',
#   'flavor',
#   'think',
#   'brandy',
#   'really',
#   'give',
#   'flavor',
#   'awesome',
#   'nice',
#   'thick',
#   'coat',
#   'lingers',
#   'full',
#   'body',
#   'little',
#   'fantastic',
#   'brew',
#   'cigar',
#   'city',
#   'definitely',
#   'one',
#   'kind',
#   'brew'],
#  ['fortunate',
#   'enough',
#   'multiple',
#   'time',
#   'time',
#   'impressed',
#   'look',
#   'part',
#   'fantasticly',
#   'craft',
#   'ipa',
#   'pale',
#   'yellow',
#   'color',
#   'nice',
#   'murkiness',
#   'chart',
#   'fresh',
#   'bursting',
#   'pine',
#   'citrus',
#   'like',
#   'nose',
#   'lot',
#   'pine',
#   'orange',
#   'zest',
#   'never',
#   'overly',
#   'bitter',
#   'dangerously',
#   'drinkable',
#   'even',
#   'though',
#   'bit',
#   'hefty',
#   'body',
#   'multiple',
#   'night',
#   'though',
#   'morning',
#   'touch',
#   'rough',
#   'regret',
#   'single',
#   'sip',
#   'worth',
#   'every',
#   'bit',
#   'praise',
#   'receives',
#   'opinion'],
#  ['finally',
#   'found',
#   'holy',
#   'grail',
#   'colorado',
#   'unexpectedly',
#   'sick',
#   'juice',
#   'neipas',
#   'neipa',
#   'style',
#   'pine',
#   'perfect',
#   'ipa',
#   'bought',
#   'go',
#   'end',
#   'memorial',
#   'day'],
#  ['dave',
#   'dave',
#   'erazo',
#   'vacation',
#   'new',
#   'england',
#   'brought',
#   'son',
#   'alchemist',
#   'brew',
#   'fresh',
#   'heady',
#   'topper',
#   'refrigerator',
#   'temperature',
#   'pour',
#   'glass',
#   'slightly',
#   'cloudy',
#   'pale',
#   'yellow',
#   'body',
#   'pure',
#   'white',
#   'cotton',
#   'candy',
#   'head',
#   'aroma',
#   'powerfully',
#   'hoppy',
#   'sort',
#   'reminiscent',
#   'pungent',
#   'ballantine',
#   'ale',
#   'newark',
#   'hop',
#   'flavor',
#   'aroma',
#   'accompany',
#   'last',
#   'flavorful',
#   'bitter',
#   'aftertaste',
#   'could',
#   'use',
#   'bit',
#   'malt',
#   'body',
#   'possibly',
#   'little',
#   'less',
#   'alcohol',
#   'memorable',
#   'modern',
#   'ipa',
#   'probably',
#   'best',
#   'one',
#   'taste'],
#  ['best',
#   'neipa',
#   'super',
#   'drinkable',
#   'around',
#   'delicious',
#   'light',
#   'sweetness',
#   'malt',
#   'balance',
#   'hearty',
#   'hop',
#   'bitterness',
#   'make',
#   'refresh',
#   'easy',
#   'drink',
#   'expect',
#   'great'],
#  ['little',
#   'month',
#   'old',
#   'try',
#   'prefer',
#   'drinking',
#   'glass',
#   'get',
#   'whiff',
#   'hop',
#   'take',
#   'drink',
#   'slightly',
#   'foggy',
#   'head',
#   'lace',
#   'nice',
#   'citrus',
#   'citrus',
#   'follow',
#   'pine',
#   'balance',
#   'doubt',
#   'live',
#   'hype'],
#  ['pour',
#   'small',
#   'amount',
#   'rock',
#   'glass',
#   'review',
#   'appearance',
#   'rest',
#   'stay',
#   'pour',
#   'nearly',
#   'one',
#   'finger',
#   'head',
#   'fine',
#   'white',
#   'cloudy',
#   'bubble',
#   'form',
#   'unfortunately',
#   'want',
#   'stick',
#   'around',
#   'lace',
#   'body',
#   'brilliant',
#   'hazy',
#   'golden',
#   'straw',
#   'still',
#   'translucent',
#   'largely',
#   'tropical',
#   'hop',
#   'aroma',
#   'note',
#   'subtle',
#   'dankness',
#   'light',
#   'belgian',
#   'yeast',
#   'influence',
#   'possibly',
#   'could',
#   'bright',
#   'dank',
#   'interest',
#   'definitely',
#   'well',
#   'hop',
#   'become',
#   'sweeter',
#   'tropical',
#   'maintain',
#   'nice',
#   'background',
#   'bitterness',
#   'really',
#   'malt',
#   'ok',
#   'drank',
#   'glass',
#   'kind',
#   'taste',
#   'like',
#   'another',
#   'neipa',
#   'honestly',
#   'amaze',
#   'fruity',
#   'evolution',
#   'go',
#   'pine',
#   'guava',
#   'earthy',
#   'almost',
#   'tart',
#   'lemon',
#   'touch',
#   'crackery',
#   'malt',
#   'finish',
#   'tie',
#   'together',
#   'quite',
#   'nicely',
#   'bitter',
#   'make',
#   'question',
#   'definition',
#   'carry',
#   'nuance',
#   'evolution',
#   'fun',
#   'smooth',
#   'bit',
#   'thick',
#   'refresh',
#   'easy',
#   'put',
#   'sort',
#   'way',
#   'sort',
#   'like',
#   'smoothie',
#   'head',
#   'literal',
#   'thickness',
#   'believe',
#   'adheres',
#   'purity',
#   'yes',
#   'exemplifies',
#   'neipa',
#   'bit',
#   'science',
#   'lot',
#   'flavor',
#   'work',
#   'together',
#   'honestly',
#   'bit',
#   'like',
#   'alchemy',
#   'almost',
#   'make',
#   'like',
#   'ipa',
#   'guy'],
#  ['feel',
#   'conflict',
#   'drinking',
#   'perhaps',
#   'less',
#   'heavily',
#   'analyze',
#   'even',
#   'get',
#   'nice',
#   'bright',
#   'citrusy',
#   'aroma',
#   'creamy',
#   'tangerine',
#   'mango',
#   'orange',
#   'blossom',
#   'balance',
#   'pine',
#   'bitterness',
#   'creamy',
#   'citrus',
#   'like',
#   'bitterness',
#   'soft',
#   'cool',
#   'dominant',
#   'loud',
#   'quite',
#   'present',
#   'finish',
#   'hold',
#   'sweetness',
#   'tangerine',
#   'mango',
#   'last',
#   'least',
#   'silky',
#   'see',
#   'many',
#   'try',
#   'many',
#   'fail'],
#  ['can', 'balance', 'tough', 'beat', 'clear', 'fav'],
#  ['amaze', 'unfortunately', 'pretty', 'hard', 'find', 'west', 'coast'],
#  ['nice',
#   'bitter',
#   'ipa',
#   'aggressive',
#   'clean',
#   'flavor',
#   'bit',
#   'piney',
#   'resinous',
#   'personal',
#   'preference'],
#  ['tremendous',
#   'dipa',
#   'quote',
#   'hoppy',
#   'goodness',
#   'palate',
#   'dense',
#   'hoppy',
#   'finish',
#   'mouth',
#   'sum',
#   'truly',
#   'great',
#   'brew'],
#  ['smell',
#   'fruity',
#   'like',
#   'peach',
#   'also',
#   'resinous',
#   'element',
#   'background',
#   'definitely',
#   'sweetness',
#   'bitterness',
#   'first',
#   'get',
#   'follow',
#   'really',
#   'balance',
#   'freshness',
#   'sweetness',
#   'malt',
#   'cut',
#   'resin',
#   'flavor',
#   'thin',
#   'medium',
#   'thin',
#   'little',
#   'foamy',
#   'carbonation',
#   'finish',
#   'sweet',
#   'like',
#   'half',
#   'second',
#   'long',
#   'epitome',
#   'ipa',
#   'hop',
#   'really',
#   'bold',
#   'balance',
#   'sweet',
#   'malt',
#   'give'],
#  ['finally', 'get', 'try', 'legend', 'life', 'status', 'wonderful'],
#  ['shiny',
#   'aluminum',
#   'pleasantly',
#   'hoppy',
#   'dank',
#   'juicytaste',
#   'platonic',
#   'ideal',
#   'neipa',
#   'instead',
#   'instance',
#   'ginormous',
#   'tropical',
#   'fruit',
#   'presence',
#   'get',
#   'pure',
#   'sequence',
#   'pithy',
#   'creamy',
#   'pillowy',
#   'recent',
#   'neipa',
#   'recipe',
#   'still',
#   'pretty',
#   'squishy',
#   'tiny',
#   'alcohol',
#   'burn',
#   'pure',
#   'classic',
#   'nothing',
#   'miss',
#   'nothing',
#   'consume'],
#  ['amaze',
#   'year',
#   'keep',
#   'go',
#   'everything',
#   'keep',
#   'right',
#   'place',
#   'unique',
#   'masterpiece',
#   'inspire',
#   'new',
#   'generation',
#   'craft'],
#  ['nearly',
#   'perfect',
#   'smell',
#   'refresh',
#   'light',
#   'citrusy',
#   'great',
#   'last',
#   'head',
#   'pour',
#   'say',
#   'perfect',
#   'ipa',
#   'flavor',
#   'little',
#   'alcoholic',
#   'side',
#   'technically',
#   'american',
#   'double',
#   'ipa',
#   'wave',
#   'wave',
#   'hoppy',
#   'goodness',
#   'drinkable',
#   'young',
#   'fresh',
#   'hazy'],
#  ['definitely', 'top', 'ipa', 'do'],
#  ['drank',
#   'today',
#   'can',
#   'brother',
#   'serve',
#   'ship',
#   'pack',
#   'nh',
#   'first',
#   'time',
#   'get',
#   'super',
#   'high',
#   'rat',
#   'disappoint',
#   'color',
#   'surprisingly',
#   'light',
#   'pour',
#   'frost',
#   'mug',
#   'instruction',
#   'low',
#   'mark',
#   'give',
#   'look',
#   'like',
#   'crap',
#   'lite',
#   'comparison',
#   'think',
#   'arrogant',
#   'bastard',
#   'sexiest',
#   'pour',
#   'guinness',
#   'draught',
#   'course',
#   'place',
#   'hay',
#   'field',
#   'high',
#   'summer',
#   'next',
#   'citrus',
#   'farm',
#   'pine',
#   'tree',
#   'plant',
#   'knew',
#   'get',
#   'punch',
#   'face',
#   'best',
#   'ever',
#   'taste',
#   'period',
#   'complex',
#   'drinkable',
#   'express',
#   'way',
#   'glass',
#   'head',
#   'right',
#   'amount',
#   'lace',
#   'thin',
#   'thick',
#   'absolutely',
#   'baby',
#   'bear',
#   'think',
#   'already',
#   'jumped',
#   'ahead',
#   'get',
#   'disappointed',
#   'suppose',
#   'follow',
#   'direction',
#   'drink',
#   'next',
#   'one',
#   'maybe',
#   'go',
#   'see',
#   'yankee',
#   'brotha',
#   'fall',
#   'grab',
#   'case',
#   'almost',
#   'enough',
#   'make',
#   'move',
#   'new',
#   'england'],
#  ['one', 'best', 'beer', 'ive', 'ever'],
#  ['batch'],
#  ['bottle',
#   'dark',
#   'jett',
#   'black',
#   'pour',
#   'fleeting',
#   'chocolate',
#   'head',
#   'entice',
#   'fudge',
#   'caramel',
#   'aroma',
#   'load',
#   'fudge',
#   'caramel',
#   'brown',
#   'sugar',
#   'highlight',
#   'vanilla',
#   'mild',
#   'bourbon',
#   'lowlights',
#   'roast',
#   'malt',
#   'way',
#   'back',
#   'somewhere',
#   'complex',
#   'wonderful',
#   'lace',
#   'fantastic',
#   'freakin'],
#  ['vintage', 'thanks', 'kevin'],
#  ['batch',
#   'man',
#   'high',
#   'rat',
#   'alaska',
#   'high',
#   'rat',
#   'ba',
#   'get',
#   'anchorage',
#   'beer',
#   'always',
#   'treat',
#   'expect',
#   'one',
#   'go',
#   'beyond',
#   'treat',
#   'let',
#   'pop',
#   'bad',
#   'boy',
#   'openpours',
#   'dark',
#   'muddy',
#   'brown',
#   'finger',
#   'reddish',
#   'dark',
#   'brown',
#   'head',
#   'immediately',
#   'fade',
#   'nothing',
#   'leaf',
#   'lace',
#   'decent',
#   'sheetingto',
#   'call',
#   'nose',
#   'decadent',
#   'would',
#   'massive',
#   'understatement',
#   'could',
#   'one',
#   'second',
#   'crack',
#   'aroma',
#   'fill',
#   'room',
#   'pick',
#   'aroma',
#   'sticky',
#   'caramel',
#   'thick',
#   'fudge',
#   'toast',
#   'coconut',
#   'sweet',
#   'bourbon',
#   'cinnamon',
#   'date',
#   'light',
#   'roast',
#   'coffee',
#   'nougat',
#   'touch',
#   'maplewhile',
#   'certainly',
#   'quite',
#   'reach',
#   'level',
#   'aroma',
#   'though',
#   'still',
#   'lot',
#   'go',
#   'front',
#   'end',
#   'sip',
#   'taste',
#   'chocolate',
#   'cake',
#   'black',
#   'cherry',
#   'sweet',
#   'coconut',
#   'spicy',
#   'whiskey',
#   'toast',
#   'oak',
#   'creamy',
#   'vanilla',
#   'burnt',
#   'caramel',
#   'touch',
#   'fudge',
#   'swallow',
#   'brings',
#   'note',
#   'chocolate',
#   'cake',
#   'toast',
#   'coconut',
#   'creamy',
#   'vanilla',
#   'sweet',
#   'bourbon',
#   'fresh',
#   'oak',
#   'fruity',
#   'coffee',
#   'date',
#   'burnt',
#   'caramela',
#   'full',
#   'body',
#   'pair',
#   'gentle',
#   'carbonation',
#   'result',
#   'rich',
#   'slick',
#   'finish',
#   'slightly',
#   'sticky',
#   'touch',
#   'boozy',
#   'heat',
#   'nothing',
#   'overbearingthis',
#   'truly',
#   'awesome',
#   'sure',
#   'many',
#   'complain',
#   'batch',
#   'well',
#   'stupid',
#   'shit',
#   'like',
#   'one',
#   'amaze',
#   'treat',
#   'cheer',
#   'ba'],
#  ['pour',
#   'fridge',
#   'temp',
#   'pours',
#   'jet',
#   'black',
#   'insanely',
#   'dark',
#   'brown',
#   'head',
#   'head',
#   'disappear',
#   'within',
#   'second',
#   'leave',
#   'array',
#   'small',
#   'coconut',
#   'chunk',
#   'float',
#   'top',
#   'look',
#   'nose',
#   'absolutely',
#   'insane',
#   'thick',
#   'layer',
#   'vanilla',
#   'coconut',
#   'bourbon',
#   'chocolate',
#   'toffee',
#   'marshmallow',
#   'touch',
#   'maple',
#   'fig',
#   'sweet',
#   'fudge',
#   'definitely',
#   'sweet',
#   'side',
#   'smell',
#   'thick',
#   'marvelous',
#   'addition',
#   'vanilla',
#   'fudge',
#   'coconut',
#   'bourbon',
#   'roast',
#   'malt',
#   'base',
#   'stout',
#   'come',
#   'marshmallow',
#   'dark',
#   'fruit',
#   'coconut',
#   'definitely',
#   'toast',
#   'side',
#   'least',
#   'come',
#   'burnt',
#   'toffee',
#   'touch',
#   'coffee',
#   'ground',
#   'oak',
#   'bitterness',
#   'back',
#   'end',
#   'hit',
#   'sens',
#   'make',
#   'great',
#   'ride',
#   'overly',
#   'sweet',
#   'thick',
#   'creamy',
#   'long',
#   'aftertaste',
#   'fantastic',
#   'ba',
#   'stout'],
#  ['dark',
#   'inky',
#   'body',
#   'opaque',
#   'carbonation',
#   'burbles',
#   'percolate',
#   'flat',
#   'crown',
#   'head',
#   'rich',
#   'powerful',
#   'aroma',
#   'fudge',
#   'milk',
#   'chocolate',
#   'roast',
#   'char',
#   'grain',
#   'moderate',
#   'sweetness',
#   'sweet',
#   'spicy',
#   'cocoa',
#   'milk',
#   'chocolate',
#   'vanilla',
#   'cinnamon',
#   'coconut',
#   'raisin',
#   'fig',
#   'fairly',
#   'bold',
#   'alcohol',
#   'presence',
#   'simmer',
#   'beneath',
#   'sweetness',
#   'heavy',
#   'body',
#   'slick',
#   'chewy',
#   'rich',
#   'residual',
#   'sugar',
#   'alcohol',
#   'warmth',
#   'note',
#   'increase',
#   'exudes',
#   'decadence',
#   'richness',
#   'sweetness',
#   'bit',
#   'overpower',
#   'think',
#   'alcohol',
#   'note',
#   'abv',
#   'rather',
#   'anything',
#   'barrel',
#   'age',
#   'lack',
#   'head',
#   'also',
#   'minus',
#   'still',
#   'overlook',
#   'dominate',
#   'sweetness',
#   'bad',
#   'imperial',
#   'stout',
#   'lack',
#   'depth',
#   'complexity',
#   'really',
#   'could',
#   'bit',
#   'balance',
#   'malt',
#   'coconut',
#   'vanilla',
#   'use',
#   'temperature',
#   'bottle',
#   'data',
#   'unknown',
#   'bottle',
#   'date',
#   'version',
#   'abv',
#   'list'],
#  ['batch',
#   'great',
#   'sweet',
#   'overly',
#   'chocolate',
#   'bomb',
#   'nose',
#   'opening',
#   'like',
#   'anchorage',
#   'much',
#   'barrel',
#   'seek'],
#  ['gold',
#   'label',
#   'amaze',
#   'nose',
#   'coconut',
#   'bourbon',
#   'chocolate',
#   'easy',
#   'drink',
#   'need',
#   'another',
#   'one'],
#  ['pitch', 'black', 'smooth', 'decadent', 'worth', 'hunt', 'sure'],
#  ['gold',
#   'label',
#   'sweetest',
#   'thing',
#   'drank',
#   'year',
#   'straight',
#   'cake',
#   'ice'],
#  ['black',
#   'thick',
#   'syrupsmell',
#   'coconut',
#   'chocolate',
#   'barreltaste',
#   'really',
#   'great',
#   'chocolate',
#   'coconut',
#   'barrel',
#   'like',
#   'smellfeel',
#   'thick',
#   'creamyovearll',
#   'fantastic',
#   'fudge',
#   'need',
#   'try',
#   'end',
#   'night',
#   'leave',
#   'share'],
#  ['time',
#   'try',
#   'bless',
#   'disappointed',
#   'taste',
#   'like',
#   'samoa',
#   'cooky',
#   'huge',
#   'note',
#   'chocolate',
#   'vanilla',
#   'toast',
#   'coconut',
#   'finish',
#   'warm',
#   'boozy',
#   'little',
#   'residual',
#   'bitterness'],
#  ['blood',
#   'old',
#   'god',
#   'pours',
#   'ichor',
#   'black',
#   'bottle',
#   'whisper',
#   'head',
#   'cling',
#   'glass',
#   'vapor',
#   'bourbon',
#   'vanilla',
#   'soak',
#   'coconut',
#   'creep',
#   'nostril',
#   'body',
#   'velvety',
#   'thick',
#   'adjunct',
#   'barely',
#   'restrain',
#   'barrel',
#   'backbone',
#   'cling',
#   'excess',
#   'intemperance',
#   'croon',
#   'weave',
#   'soul',
#   'mind',
#   'mouth',
#   'let',
#   'warm',
#   'truly'],
#  ['release',
#   'december',
#   'drank',
#   'roadrunner',
#   'brown',
#   'even',
#   'pour',
#   'yield',
#   'head',
#   'vanilla',
#   'smooth',
#   'bourbon',
#   'milk',
#   'chocolate',
#   'mild',
#   'coconut',
#   'note',
#   'thick',
#   'vanilla',
#   'cabernet',
#   'sauvignon',
#   'rich',
#   'milk',
#   'chocolate',
#   'flavor',
#   'front',
#   'smooth',
#   'mild',
#   'bourbon',
#   'heat',
#   'phenomenal',
#   'like',
#   'pastry',
#   'stout',
#   'enjoy',
#   'masterpiece'],
#  ['barrel', 'age', 'brownie', 'batter', 'bottle'],
#  ['devoutly',
#   'irreligious',
#   'still',
#   'name',
#   'perfectly',
#   'describes',
#   'living',
#   'season',
#   'life',
#   'well',
#   'life',
#   'far',
#   'deserve',
#   'certainly',
#   'luck',
#   'rather',
#   'god',
#   'truly',
#   'version',
#   'abv',
#   'unsurprisingly',
#   'sweet',
#   'ton',
#   'chocolate',
#   'bourbon',
#   'front',
#   'extremely',
#   'intense',
#   'robust',
#   'coconut',
#   'chime',
#   'finish',
#   'add',
#   'many',
#   'layer',
#   'strongly',
#   'earthy',
#   'vanilla',
#   'dark',
#   'fruit',
#   'caramel',
#   'nut',
#   'much',
#   'believe',
#   'say',
#   'ton',
#   'coconut',
#   'vanilla',
#   'never',
#   'taste',
#   'prominently',
#   'sweetness',
#   'never',
#   'relents',
#   'one',
#   'iota',
#   'body',
#   'extremely',
#   'thick',
#   'sticky',
#   'full',
#   'largely',
#   'still',
#   'fine',
#   'type',
#   'life',
#   'would',
#   'welcome',
#   'damn',
#   'delicious',
#   'wonderfully',
#   'silly'],
#  ['pours',
#   'thick',
#   'jet',
#   'black',
#   'head',
#   'stick',
#   'sweet',
#   'malt',
#   'coat',
#   'mouth',
#   'finally',
#   'let',
#   'dark',
#   'fruit',
#   'barrel',
#   'coconut',
#   'vanilla',
#   'amazingly',
#   'balance',
#   'discernible',
#   'alcohol',
#   'dessert',
#   'do',
#   'abc'],
#  ['head',
#   'milk',
#   'chocolate',
#   'syrup',
#   'know',
#   'make',
#   'think',
#   'chocolate',
#   'rich',
#   'bright',
#   'way',
#   'bourbon',
#   'forefront',
#   'much',
#   'need',
#   'welcome',
#   'undertone',
#   'kinda',
#   'candy',
#   'zero',
#   'bitterness',
#   'mostly',
#   'plus',
#   'like',
#   'push',
#   'carbonation',
#   'knock'],
#  ['ok',
#   'perfect',
#   'adjunct',
#   'stout',
#   'everything',
#   'really',
#   'balance',
#   'try',
#   'sp',
#   'dm',
#   'everyone',
#   'agree',
#   'bless',
#   'dm'],
#  ['compare',
#   'king',
#   'julius',
#   'offering',
#   'much',
#   'muddier',
#   'appearance',
#   'clearly',
#   'super',
#   'hop',
#   'saturate',
#   'also',
#   'certainly',
#   'citrus',
#   'nose',
#   'even',
#   'bolder',
#   'earthy',
#   'quality',
#   'third',
#   'potent',
#   'malt',
#   'backbone',
#   'heftier',
#   'downside',
#   'alcohol',
#   'poke',
#   'little',
#   'aggressively',
#   'odd',
#   'something',
#   'clock',
#   'go',
#   'regular',
#   'king',
#   'j',
#   'amped',
#   'version'],
#  ['definitely',
#   'one',
#   'best',
#   'hazies',
#   'ever',
#   'smooth',
#   'tropical',
#   'orange',
#   'mango',
#   'touch',
#   'bitterness',
#   'know',
#   'balance',
#   'beastly',
#   'beer'],
#  ['week',
#   'old',
#   'wine',
#   'pours',
#   'full',
#   'hazy',
#   'orange',
#   'pillowy',
#   'white',
#   'head',
#   'last',
#   'quite',
#   'dissipates',
#   'leave',
#   'lot',
#   'lace',
#   'mix',
#   'tropical',
#   'fruit',
#   'hint',
#   'mango',
#   'ripe',
#   'pineapple',
#   'guava',
#   'pair',
#   'subtle',
#   'citrusy',
#   'note',
#   'like',
#   'orange',
#   'tangerine',
#   'tropical',
#   'citrusy',
#   'sweet',
#   'bitter',
#   'hoppy',
#   'zesty',
#   'dry',
#   'finish',
#   'mango',
#   'orange',
#   'grapefruit',
#   'hint',
#   'pineapple',
#   'tangerine',
#   'somehow',
#   'grassy',
#   'full',
#   'creamy',
#   'sharp',
#   'hop',
#   'bite',
#   'medium',
#   'one',
#   'almost',
#   'perfect',
#   'point',
#   'nearly',
#   'spectacular',
#   'interplay',
#   'fruity',
#   'grassy',
#   'hop',
#   'note',
#   'everything',
#   'keep',
#   'pop',
#   'without',
#   'dominant',
#   'smooth',
#   'yet',
#   'complex',
#   'world',
#   'class'],
#  ['pours',
#   'cloudy',
#   'dark',
#   'orange',
#   'color',
#   'three',
#   'finger',
#   'yellowed',
#   'head',
#   'decent',
#   'retention',
#   'thick',
#   'soapy',
#   'cantaloupe',
#   'honeydew',
#   'top',
#   'nose',
#   'touch',
#   'orange',
#   'creamsicle',
#   'blend',
#   'underneath',
#   'maybe',
#   'hint',
#   'white',
#   'ripe',
#   'melon',
#   'come',
#   'strong',
#   'touch',
#   'orange',
#   'citrus',
#   'quite',
#   'light',
#   'comparison',
#   'fleeting',
#   'flash',
#   'spearmint',
#   'wintergreen',
#   'moderate',
#   'green',
#   'twiggy',
#   'bitterness',
#   'lingers',
#   'meld',
#   'cantaloupe',
#   'aftertaste',
#   'maybe',
#   'grass',
#   'maybe',
#   'herb',
#   'definitely',
#   'hop',
#   'body',
#   'milky',
#   'tight',
#   'soft',
#   'tasty',
#   'prefer',
#   'jjjuliuss'],
#  ['unreal', 'hoppiest', 'candy', 'nectar', 'get', 'much', 'april'],
#  ['date',
#   'classic',
#   'treehouse',
#   'turbid',
#   'gold',
#   'excellent',
#   'retention',
#   'lace',
#   'pure',
#   'nose',
#   'medium',
#   'body',
#   'soft',
#   'ripe',
#   'juicy',
#   'tropicals',
#   'palate',
#   'minimal',
#   'malt',
#   'bitterness',
#   'orange',
#   'peach',
#   'light',
#   'mango',
#   'finish',
#   'juicy',
#   'tropical'],
#  ['pours',
#   'hazy',
#   'orange',
#   'thin',
#   'creamy',
#   'white',
#   'head',
#   'heavy',
#   'amount',
#   'soapy',
#   'aroma',
#   'bursting',
#   'mango',
#   'tangerine',
#   'cantaloupe',
#   'mango',
#   'orange',
#   'cantaloupe',
#   'grapefruit',
#   'light',
#   'bready',
#   'malt',
#   'piney',
#   'medium',
# ...
#   'pour',
#   'light',
#   'floaties',
#   'head',
#   'thick',
#   'thick',
#   'thick',
#   'nose',
#   'naked',
#   'juice',
#   'mighty',
#   'mango',
#   'screwdriver',
#   'banana',
#   'scallion',
#   'white',
#   'pepper',
#   'alcohol',
#   'far',
#   'cleaner',
#   'expect',
#   'nose',
#   'tangerine',
#   'big',
#   'overly',
#   'sweet',
#   'much',
#   'way',
#   'tropical',
#   'note',
#   'least',
#   'early',
#   'warms',
#   'sweet',
#   'peach',
#   'peach',
#   'candy',
#   'becomes',
#   'prominent',
#   'thick',
#   'way',
#   'small',
#   'amount',
#   'prickly',
#   'carbonation',
#   'take',
#   'flavor',
#   'develop',
#   'warms',
#   'flavor',
#   'evolves',
#   'nicely'],
#  ['huge',
#   'tropical',
#   'hoppy',
#   'aroma',
#   'juicy',
#   'grapefruit',
#   'pineapple',
#   'little',
#   'sweetness',
#   'great',
#   'bitterness',
#   'awesome',
#   'brew'],
#  ['old',
#   'pour',
#   'color',
#   'creamy',
#   'haze',
#   'attractive',
#   'glow',
#   'big',
#   'initial',
#   'head',
#   'soapy',
#   'white',
#   'bubble',
#   'decent',
#   'retention',
#   'lot',
#   'sticky',
#   'lace',
#   'gorgeous',
#   'orange',
#   'pineapple',
#   'juicy',
#   'fruit',
#   'mango',
#   'apricot',
#   'peach',
#   'ruby',
#   'red',
#   'grapefruit',
#   'sweet',
#   'tropical',
#   'fruit',
#   'front',
#   'grassy',
#   'little',
#   'weedy',
#   'touch',
#   'pine',
#   'breast',
#   'malt',
#   'nice',
#   'creamsicle',
#   'twang',
#   'seediness',
#   'turn',
#   'oniony',
#   'warms',
#   'really',
#   'like',
#   'simultaneously',
#   'bright',
#   'little',
#   'often',
#   'case',
#   'th',
#   'hazies',
#   'profile',
#   'bit',
#   'letdown',
#   'nose',
#   'keep',
#   'still',
#   'incredibly',
#   'craft',
#   'drinkable',
#   'might',
#   'age',
#   'grassiness',
#   'much',
#   'pronounce',
#   'fruit',
#   'flavor',
#   'much',
#   'muddle',
#   'subdue',
#   'still',
#   'wonderful',
#   'note',
#   'orange',
#   'sweet',
#   'grapefruit',
#   'underripe',
#   'pineapple',
#   'red',
#   'berry',
#   'grape',
#   'lot',
#   'stone',
#   'fruit',
#   'tropical',
#   'fruit',
#   'juice',
#   'wash',
#   'around',
#   'underneath',
#   'go',
#   'awfully',
#   'easy',
#   'finish',
#   'pith',
#   'bitterness',
#   'balance',
#   'silky',
#   'coat'],
#  ['can',
#   'pours',
#   'cloudy',
#   'orange',
#   'color',
#   'finger',
#   'thick',
#   'creamy',
#   'beige',
#   'color',
#   'head',
#   'fade',
#   'slowly',
#   'left',
#   'lace',
#   'along',
#   'glass',
#   'go',
#   'dank',
#   'ripe',
#   'citrus',
#   'fruit',
#   'include',
#   'tangerine',
#   'grapefruit',
#   'pineapple',
#   'papaya',
#   'apricot',
#   'tropical',
#   'fruit',
#   'caramel',
#   'mild',
#   'spice',
#   'buttery',
#   'biscuit',
#   'complete',
#   'citrus',
#   'hop',
#   'bomb',
#   'brings',
#   'lot',
#   'fruity',
#   'note',
#   'together',
#   'complex',
#   'please',
#   'like',
#   'tangerine',
#   'orange',
#   'juice',
#   'tang',
#   'instant',
#   'drink',
#   'pineapple',
#   'grapefruit',
#   'melon',
#   'apricot',
#   'gummy',
#   'bear',
#   'peach',
#   'tropical',
#   'fruit',
#   'biscuit',
#   'tea',
#   'leaf',
#   'coriander',
#   'faint',
#   'piney',
#   'note',
#   'mango',
#   'orange',
#   'crush',
#   'soda',
#   'dry',
#   'chalky',
#   'yeast',
#   'razzle',
#   'candy',
#   'fade',
#   'dry',
#   'complex',
#   'many',
#   'fruity',
#   'flavor',
#   'yet',
#   'also',
#   'balance',
#   'enough',
#   'malty',
#   'backbone',
#   'go',
#   'smooth',
#   'hiding',
#   'abv',
#   'bitterness',
#   'nice',
#   'average',
#   'level',
#   'carbonation',
#   'mild',
#   'make',
#   'dipa',
#   'could',
#   'easily',
#   'session',
#   'really',
#   'damn',
#   'enjoyable'],
#  ['head',
#   'little',
#   'retention',
#   'almost',
#   'lace',
#   'look',
#   'like',
#   'pineapple',
#   'juice',
#   'darker',
#   'opaque',
#   'overly',
#   'hazy',
#   'turbid',
#   'pineapple',
#   'mango',
#   'orange',
#   'ripe',
#   'cantaloupe',
#   'juicy',
#   'fruit',
#   'jolly',
#   'pineapple',
#   'orange',
#   'peel',
#   'mango',
#   'greatfruit',
#   'noticable',
#   'finish',
#   'citrus',
#   'rind',
#   'bitter',
#   'finish',
#   'start',
#   'tropical',
#   'fruit',
#   'note',
#   'finish',
#   'bitter',
#   'rind',
#   'nice',
#   'balance',
#   'slick',
#   'low',
#   'carb',
#   'still',
#   'still',
#   'slightly',
#   'prickly',
#   'bit',
#   'oily',
#   'balance',
#   'abv',
#   'noticable',
#   'dangerously',
#   'drinkable'],
#  ['cradle',
#   'bottle',
#   'serve',
#   'decanter',
#   'sat',
#   'minute',
#   'serve',
#   'beautiful',
#   'gold',
#   'color',
#   'light',
#   'haziness',
#   'transparency',
#   'head',
#   'two',
#   'finger',
#   'white',
#   'foam',
#   'aroma',
#   'sherry',
#   'barrel',
#   'right',
#   'cusp',
#   'funky',
#   'stone',
#   'lemon',
#   'earthy',
#   'note',
#   'round',
#   'light',
#   'funky',
#   'nose',
#   'sherry',
#   'smooth',
#   'thing',
#   'elevate',
#   'whole',
#   'nose',
#   'base',
#   'deliver',
#   'strong',
#   'potent',
#   'note',
#   'dry',
#   'fruit',
#   'flavor',
#   'profile',
#   'build',
#   'nose',
#   'hit',
#   'sherry',
#   'barrel',
#   'character',
#   'first',
#   'stone',
#   'lemon',
#   'tangy',
#   'green',
#   'apple',
#   'earthy',
#   'note',
#   'round',
#   'sublime',
#   'twist',
#   'funky',
#   'tartness',
#   'give',
#   'whole',
#   'flavor',
#   'profile',
#   'additional',
#   'dimension',
#   'mouth',
#   'medium',
#   'thickness',
#   'texture',
#   'driven',
#   'consistent',
#   'smooth',
#   'even',
#   'texture',
#   'splendid',
#   'term',
#   'complexity',
#   'quaffability',
#   'thoughtfulness',
#   'season',
#   'bottle',
#   'date',
#   'serve',
#   'bottle',
#   'decant',
#   'review',
#   'note',
#   'first',
#   'pour',
#   'zenne',
#   'frontera'],
#  ['bottle',
#   'pour',
#   'dark',
#   'golden',
#   'color',
#   'lambic',
#   'medium',
#   'size',
#   'foamy',
#   'head',
#   'aroma',
#   'funky',
#   'ester',
#   'barnyard',
#   'note',
#   'woody',
#   'vinous',
#   'note',
#   'also',
#   'mix',
#   'vinous',
#   'note',
#   'funky',
#   'barnyard',
#   'note',
#   'oak',
#   'note',
#   'body',
#   'average',
#   'carbonation',
#   'great',
#   'lambic',
#   'expect',
#   'pedro',
#   'ximinez',
#   'barrel',
#   'apparent'],
#  ['bottle',
#   'generously',
#   'share',
#   'seth',
#   'clear',
#   'light',
#   'amber',
#   'pour',
#   'small',
#   'white',
#   'head',
#   'mild',
#   'funk',
#   'aroma',
#   'mellow',
#   'caramel',
#   'oak',
#   'note',
#   'give',
#   'way',
#   'mellow',
#   'horse',
#   'blanket',
#   'barnyard',
#   'backbeat',
#   'smooth',
#   'less',
#   'prickly',
#   'champaign',
#   'like',
#   'carbonation',
#   'body',
#   'simply',
#   'outstanding'],
#  ['bottle',
#   'la',
#   'palma',
#   'sour',
#   'fest',
#   'hazy',
#   'orange',
#   'color',
#   'small',
#   'white',
#   'head',
#   'holy',
#   'smoke',
#   'funky',
#   'ton',
#   'musty',
#   'damp',
#   'earthy',
#   'basement',
#   'mushroom',
#   'note',
#   'bright',
#   'lemon',
#   'green',
#   'grape',
#   'acidity',
#   'slight',
#   'apricot',
#   'sweetness',
#   'perhaps',
#   'hint',
#   'vanilla',
#   'really',
#   'nice',
#   'mineral',
#   'quality',
#   'pretty',
#   'citrusy',
#   'zesty',
#   'winner',
#   'usual'],
#  ['bottle', 'courtesy'],
#  ['capped',
#   'corked',
#   'batch',
#   'solera',
#   'bottle',
#   'stemware',
#   'share',
#   'barnyard',
#   'hay',
#   'cheese',
#   'lemon',
#   'zest',
#   'cobweb',
#   'funk',
#   'super',
#   'aromatic',
#   'crazy',
#   'funky',
#   'open',
#   'light',
#   'funk',
#   'get',
#   'note',
#   'hay',
#   'lemon',
#   'zest',
#   'oak',
#   'wet',
#   'wood',
#   'peat',
#   'hay',
#   'cobweb',
#   'middle',
#   'musty',
#   'straw',
#   'lemon',
#   'oak',
#   'finish',
#   'body',
#   'light',
#   'moderate',
#   'ample',
#   'carbonation',
#   'prickly',
#   'still',
#   'lively',
#   'palate',
#   'go',
#   'accent',
#   'sparkle',
#   'go',
#   'slightly',
#   'dry',
#   'linger',
#   'filmy',
#   'solid',
#   'pretty',
#   'impressed',
#   'definitely',
#   'worth'],
#  ['get', 'well'],
#  ['pours',
#   'slight',
#   'dark',
#   'gold',
#   'light',
#   'frost',
#   'transparency',
#   'head',
#   'couple',
#   'finger',
#   'plush',
#   'white',
#   'pleasant',
#   'quick',
#   'hit',
#   'tropical',
#   'fruit',
#   'citrus',
#   'mild',
#   'resin',
#   'grass',
#   'meld',
#   'together',
#   'sugary',
#   'hop',
#   'note',
#   'seamlessly',
#   'sticky',
#   'hop',
#   'dramatic',
#   'dynamic',
#   'aroma',
#   'light',
#   'bready',
#   'malt',
#   'adorn',
#   'back',
#   'aroma',
#   'profile',
#   'faint',
#   'comparison',
#   'hop',
#   'hop',
#   'never',
#   'loud',
#   'instead',
#   'land',
#   'mild',
#   'volume',
#   'six',
#   'scale',
#   'ten',
#   'high',
#   'instead',
#   'use',
#   'volume',
#   'hop',
#   'overlap',
#   'create',
#   'profile',
#   'light',
#   'tropical',
#   'fruit',
#   'citrus',
#   'onset',
#   'share',
#   'spotlight',
#   'resiny',
#   'grassy',
#   'piney',
#   'mild',
#   'herbal',
#   'floral',
#   'hop',
#   'dip',
#   'back',
#   'tropical',
#   'fruit',
#   'finish',
#   'pine',
#   'note',
#   'build',
#   'intensity',
#   'warms',
#   'refrain',
#   'cross',
#   'overly',
#   'sticky',
#   'heavy',
#   'never',
#   'overtly',
#   'sweet',
#   'carry',
#   'bitter',
#   'bite',
#   'end',
#   'west',
#   'coast',
#   'ipas',
#   'instead',
#   'end',
#   'marked',
#   'light',
#   'dryness',
#   'mark',
#   'end',
#   'hop',
#   'dryness',
#   'accompany',
#   'bready',
#   'consistent',
#   'crisp',
#   'texture',
#   'driven',
#   'mild',
#   'effervescence',
#   'thick',
#   'enough',
#   'drink',
#   'like',
#   'experience',
#   'less',
#   'like',
#   'parking',
#   'lot',
#   'tailgate',
#   'ipa',
#   'though',
#   'would',
#   'never',
#   'turn',
#   'pour',
#   'bottle',
#   'latter',
#   'embodies',
#   'wonderful',
#   'balance',
#   'along',
#   'thoughtful',
#   'nuance',
#   'create',
#   'dreamy',
#   'smooth',
#   'ipa',
#   'hop',
#   'pleasant',
#   'plump',
#   'forward',
#   'without',
#   'carry',
#   'force',
#   'ipas',
#   'one',
#   'marked',
#   'adorn',
#   'simplicity',
#   'spiegelau',
#   'tulip',
#   'bottle'],
#  ['draft',
#   'march',
#   'bottle',
#   'today',
#   'past',
#   'four',
#   'trip',
#   'decade',
#   'pliny',
#   'would',
#   'always',
#   'unmistakable',
#   'distinguish',
#   'character',
#   'cadillac',
#   'russian',
#   'river',
#   'time',
#   'call',
#   'server',
#   'sure',
#   'happy',
#   'hop',
#   'something',
#   'else',
#   'nope',
#   'young',
#   'acidic',
#   'lack',
#   'smooth',
#   'richness',
#   'piney',
#   'sticky',
#   'aftertaste',
#   'go',
#   'amaze',
#   'nose',
#   'sap',
#   'sweet',
#   'burnt',
#   'sugar',
#   'three',
#   'try',
#   'visit',
#   'one',
#   'pour',
#   'like',
#   'friend',
#   'stump',
#   'disappointed',
#   'vibe',
#   'visit',
#   'windsor',
#   'pleasant',
#   'take',
#   'self',
#   'guide',
#   'tour',
#   'wait',
#   'spring',
#   'sunshine',
#   'mere',
#   'three',
#   'half',
#   'hour',
#   'food',
#   'scrumptious',
#   'friend',
#   'share',
#   'bottle',
#   'refraction',
#   'collab',
#   'brooklyn',
#   'brewery',
#   'seem',
#   'offer',
#   'still',
#   'purchase',
#   'two',
#   'bottle',
#   'pty',
#   'go',
#   'give',
#   'another',
#   'shot',
#   'home',
#   'pour',
#   'four',
#   'ounce',
#   'glass',
#   'akin',
#   'serve',
#   'santa',
#   'rosa',
#   'vibe',
#   'get',
#   'four',
#   'pack',
#   'r',
#   'gift',
#   'shop',
#   'enjoy',
#   'ala'],
#  ['appearance',
#   'pour',
#   'clear',
#   'golden',
#   'color',
#   'visible',
#   'carbonation',
#   'white',
#   'earthy',
#   'pine',
#   'note',
#   'strong',
#   'nose',
#   'way',
#   'comparison',
#   'smell',
#   'like',
#   'amped',
#   'version',
#   'sample',
#   'pliny',
#   'elder',
#   'first',
#   'use',
#   'mean',
#   'comparison',
#   'young',
#   'seem',
#   'like',
#   'amped',
#   'version',
#   'elder',
#   'green',
#   'grass',
#   'hop',
#   'next',
#   'level',
#   'pine',
#   'note',
#   'left',
#   'little',
#   'room',
#   'sweetness',
#   'somewhat',
#   'backbone',
#   'pain',
#   'note',
#   'linger',
#   'body',
#   'imperial',
#   'carbonation',
#   'scrub',
#   'away',
#   'sweetness',
#   'allow',
#   'bitterness',
#   'glad',
#   'get',
#   'try',
#   'thanks'],
#  ['reason',
#   'rat',
#   'high',
#   'pty',
#   'load',
#   'citrus',
#   'aroma',
#   'flavor',
#   'smooth'],
#  ['golden',
#   'mostly',
#   'clear',
#   'nice',
#   'white',
#   'head',
#   'rimmingsmell',
#   'citrus',
#   'tangerine',
#   'slight',
#   'pinetaste',
#   'bitter',
#   'citrus',
#   'slight',
#   'creamy',
#   'little',
#   'caramelfeel',
#   'full',
#   'body',
#   'lighter',
#   'carboverall',
#   'fantastic',
#   'straight',
#   'west',
#   'coast'],
#  ['welp',
#   'year',
#   'hunt',
#   'elusive',
#   'brew',
#   'ever',
#   'since',
#   'find',
#   'craft',
#   'sam',
#   'adam',
#   'early',
#   'college',
#   'day',
#   'ultimate',
#   'sasquatch',
#   'spent',
#   'year',
#   'east',
#   'coast',
#   'college',
#   'arizona',
#   'never',
#   'take',
#   'trip',
#   'northern',
#   'california',
#   'finally',
#   'living',
#   'san',
#   'diego',
#   'decide',
#   'send',
#   'keg',
#   'incredible',
#   'find',
#   'random',
#   'google',
#   'search',
#   'turn',
#   'owner',
#   'fathom',
#   'bistro',
#   'bar',
#   'know',
#   'vinnie',
#   'figure',
#   'would',
#   'similar',
#   'best',
#   'beer',
#   'different',
#   'perfect',
#   'west',
#   'coast',
#   'hoppy',
#   'amplify',
#   'super',
#   'resinous',
#   'dry',
#   'dank',
#   'amaze',
#   'finish',
#   'body',
#   'smooth',
#   'flavor',
#   'obviously',
#   'chart',
#   'worth',
#   'hype'],
#  ['blind', 'donkey'],
#  ['reviewer',
#   'pretty',
#   'much',
#   'hit',
#   'everything',
#   'say',
#   'except',
#   'get',
#   'drunk',
#   'three',
#   'four',
#   'bias',
#   'review',
#   'area',
#   'go',
#   'srjc',
#   'matter',
#   'one',
#   'best',
#   'beer',
#   'buy',
#   'world'],
#  ['non',
#   'ba',
#   'sweet',
#   'ba',
#   'definitely',
#   'cut',
#   'dessert',
#   'stout',
#   'aspect',
#   'balance',
#   'time',
#   'favorite',
#   'dessert',
#   'stout'],
#  ['one',
#   'pours',
#   'dark',
#   'black',
#   'color',
#   'small',
#   'head',
#   'smell',
#   'strongly',
#   'coconut',
#   'load',
#   'milk',
#   'dark',
#   'chocolate',
#   'slight',
#   'roast',
#   'light',
#   'bourbon',
#   'lot',
#   'creamy',
#   'definitely',
#   'sweet',
#   'honestly',
#   'sweet',
#   'expect',
#   'really',
#   'meet',
#   'hype',
#   'garner',
#   'exactly',
#   'want',
#   'high',
#   'quality',
#   'pastry',
#   'coconut',
#   'do',
#   'bright',
#   'vibrant',
#   'plain',
#   'tasty',
#   'little',
#   'bit',
#   'barrel',
#   'help',
#   'anchor',
#   'slightly',
#   'vanilla',
#   'also',
#   'do',
#   'layer',
#   'top',
#   'tasty',
#   'creamy',
#   'base',
#   'creamy',
#   'rich',
#   'real',
#   'booziness',
#   'almost',
#   'want',
#   'one',
#   'always',
#   'like',
#   'angry',
#   'chair',
#   'hyped',
#   'fortunately',
#   'unfortunately',
#   'honestly',
#   'awesome',
#   'best',
#   'angry',
#   'chair',
#   'ever'],
#  ['bottle',
#   'dark',
#   'brown',
#   'pour',
#   'chocolate',
#   'head',
#   'huge',
#   'chocolate',
#   'cake',
#   'bouquet',
#   'shit',
#   'chocolate',
#   'treat',
#   'get',
#   'wrong',
#   'bad',
#   'boy',
#   'uber',
#   'sweet',
#   'exactly',
#   'advertised',
#   'literally',
#   'liquid',
#   'version',
#   'chocolate',
#   'cake',
#   'warms',
#   'bourbon',
#   'oak',
#   'vanilla',
#   'start',
#   'show',
#   'really',
#   'body'],
#  ['deliver', 'cake', 'tasty', 'worth', 'try', 'chance', 'definitely', 'one'],
#  ['stout',
#   'angry',
#   'chair',
#   'guess',
#   'bottle',
#   'nice',
#   'guy',
#   'sit',
#   'table',
#   'next',
#   'offer',
#   'pour',
#   'bottle',
#   'share',
#   'friend',
#   'wife',
#   'needle',
#   'say',
#   'drank',
#   'pour',
#   'jet',
#   'black',
#   'color',
#   'little',
#   'bit',
#   'foam',
#   'smell',
#   'like',
#   'chocolate',
#   'light',
#   'bourbon',
#   'note',
#   'best',
#   'chocolate',
#   'ever',
#   'taste',
#   'stout',
#   'rich',
#   'sweet',
#   'chocolate',
#   'balance',
#   'perfectly',
#   'slight',
#   'bourbon',
#   'also',
#   'perfect',
#   'coat',
#   'tongue',
#   'blew',
#   'away',
#   'non',
#   'ba',
#   'version',
#   'year',
#   'ago',
#   'league',
#   'best',
#   'pastry',
#   'stout',
#   'ever',
#   'first',
#   'perfect',
#   'score',
#   'ever',
#   'give',
#   'advocate'],
#  ['tap',
#   'tbbw',
#   'sorta',
#   'rad',
#   'event',
#   'vintage',
#   'viscosity',
#   'thick',
#   'lot',
#   'angry',
#   'chair',
#   'get',
#   'awesome',
#   'samoa',
#   'vibe',
#   'strong',
#   'coconut',
#   'chocolate',
#   'really',
#   'barrel',
#   'awesome'],
#  ['right',
#   'bottle',
#   'look',
#   'amaze',
#   'great',
#   'mouth',
#   'like',
#   'drinking',
#   'brownie',
#   'batter',
#   'like',
#   'many',
#   'ac',
#   'stout',
#   'sweet',
#   'barrel',
#   'help',
#   'keep',
#   'sweetness'],
#  ['amaze', 'barrel', 'sweetness', 'nothing', 'dominates', 'goooood'],
#  ['short', 'mouth', 'thick', 'v', 'thin', 'barrel', 'character'],
#  ['tap',
#   'gorgeous',
#   'nose',
#   'rich',
#   'bitter',
#   'dark',
#   'chocolate',
#   'dark',
#   'fruit',
#   'roast',
#   'luxurious',
#   'barrel',
#   'character',
#   'structure',
#   'oak',
#   'richness',
#   'coconut',
#   'vanilla',
#   'pleasant',
#   'warmth',
#   'bourbon',
#   'big',
#   'purpose',
#   'restrain',
#   'sweetness',
#   'enables',
#   'balance',
#   'actually',
#   'drinkable',
#   'softly',
#   'carbonate',
#   'fruity',
#   'dark',
#   'chocolate',
#   'mild',
#   'licorice',
#   'finish',
#   'fantastic'],
#  ['awesome',
#   'minute',
#   'pour',
#   'minute',
#   'chocolate',
#   'note',
#   'barrel',
#   'bourbon',
#   'note',
#   'stickiness',
#   'palette',
#   'masterpiece',
#   'big',
#   'developed',
#   'blend',
#   'age',
#   'drink',
#   'closer',
#   'f',
#   'wonderful',
#   'note',
#   'come',
#   'load',
#   'chocolate',
#   'caramel',
#   'vanilla',
#   'note',
#   'slight',
#   'tannin',
#   'oak',
#   'hint',
#   'bourbon',
#   'linger',
#   'let',
#   'enjoy',
#   'flavor',
#   'savor',
#   'nothing',
#   'balance',
#   'love']]

# %%
import gensim
from gensim import corpora

# %%
gensim_terms = corpora.Dictionary(top3)

# %%
top_matrix = [gensim_terms.doc2bow(w) for w in top3]

# %%
lda = gensim.models.ldamodel.LdaModel

# %%
lda_model = lda(top_matrix, num_topics=3, id2word=gensim_terms, random_state=0)

# %%
lda_model.print_topics(num_words=5)
# Out:
# [(0,
#   '0.013*"maple" + 0.010*"chocolate" + 0.009*"barrel" + 0.007*"flavor" + 0.007*"coffee"'),
#  (1,
#   '0.008*"hop" + 0.007*"like" + 0.006*"balance" + 0.006*"head" + 0.006*"fruit"'),
#  (2,
#   '0.010*"note" + 0.009*"like" + 0.009*"head" + 0.008*"thick" + 0.007*"sweet"')]

# %% [markdown]
# ### worst15

# %%
worst3 = []

for d in worst2:
    d1 = my_tokenizer(d)
    worst3.append(d1)

worst3
# Out:
# [['hold',
#   'review',
#   'one',
#   'go',
#   'back',
#   'forth',
#   'consider',
#   'straight',
#   'light',
#   'rat',
#   'jut',
#   'poor',
#   'high',
#   'end',
#   'extremely',
#   'watery',
#   'flat',
#   'taste',
#   'rank',
#   'low',
#   'calorie',
#   'brew',
#   'solely',
#   'would',
#   'rank',
#   'halfway',
#   'poor',
#   'average'],
#  ['ever',
#   'use',
#   'found',
#   'ground',
#   'kid',
#   'smell',
#   'fizzy',
#   'watery',
#   'literally',
#   'reminiscent',
#   'tonic',
#   'water',
#   'soda',
#   'bad',
#   'bubbly',
#   'carbonate',
#   'pallette',
#   'feel',
#   'like',
#   'caloric',
#   'intake',
#   'name',
#   'make',
#   'diet',
#   'restricts',
#   'many',
#   'calorie',
#   'consume',
#   'decent',
#   'replacement',
#   'regular',
#   'light',
#   'miller',
#   'lite',
#   'bud',
#   'light',
#   'coors',
#   'light',
#   'review',
#   'beer',
#   'let',
#   'know',
#   'substitute',
#   'beer',
#   'really',
#   'water',
#   'though'],
#  ['one',
#   'golf',
#   'course',
#   'great',
#   'well',
#   'thought',
#   'would',
#   'enough',
#   'short',
#   'review',
#   'review',
#   'pretty',
#   'much',
#   'indistinguishable',
#   'miller',
#   'sort',
#   'impressive',
#   'consider',
#   'caloric',
#   'lightness',
#   'beer',
#   'michelob',
#   'ultra',
#   'miller',
#   'create',
#   'weird',
#   'aroma',
#   'like',
#   'dirty',
#   'sock',
#   'grainy',
#   'start',
#   'hoppy',
#   'finish',
#   'light',
#   'still',
#   'discernibly',
#   'hoppy',
#   'totally',
#   'drinkable'],
#  ['super',
#   'straw',
#   'yellow',
#   'color',
#   'usual',
#   'mixture',
#   'ton',
#   'water',
#   'little',
#   'barley',
#   'flimsy',
#   'white',
#   'head',
#   'prop',
#   'hit',
#   'brick',
#   'right',
#   'quick',
#   'aroma',
#   'almost',
#   'almost',
#   'nothing',
#   'highly',
#   'carbonate',
#   'watery',
#   'plus',
#   'side',
#   'drink',
#   'hydrate',
#   'without',
#   'worry',
#   'water',
#   'quality',
#   'world',
#   'shithole',
#   'come',
#   'across',
#   'guess',
#   'flavor',
#   'term',
#   'ca',
#   'dock',
#   'hard',
#   'mouth',
#   'jeez',
#   'overly',
#   'carbonate',
#   'water',
#   'shitty',
#   'spill'],
#  ['bottle',
#   'pour',
#   'pint',
#   'glass',
#   'cold',
#   'beerappearance',
#   'light',
#   'yellow',
#   'big',
#   'white',
#   'foamaroma',
#   'scent',
#   'malt',
#   'nothing',
#   'elsetaste',
#   'really',
#   'great',
#   'waterymouth',
#   'carbonatedoverall',
#   'repeat',
#   'nodrank'],
#  ['awful',
#   'know',
#   'even',
#   'rating',
#   'beat',
#   'genesee',
#   'light',
#   'milwaukee',
#   'best',
#   'light',
#   'kirkland',
#   'signature',
#   'light',
#   'bad'],
#  ['like',
#   'water',
#   'every',
#   'aspect',
#   'mgd',
#   'already',
#   'pretty',
#   'sketchy',
#   'want',
#   'want',
#   'water',
#   'water',
#   'palest',
#   'straw',
#   'color',
#   'aroma',
#   'barely',
#   'felt',
#   'like',
#   'water'],
#  ['canquest',
#   'tm',
#   'originally',
#   'take',
#   'place',
#   'one',
#   'believe',
#   'review',
#   'previously',
#   'anything',
#   'support',
#   'canquest',
#   'let',
#   'say',
#   'first',
#   'hit',
#   'market',
#   'back',
#   'huge',
#   'fan',
#   'unleaded',
#   'version',
#   'regular',
#   'much',
#   'well',
#   'high',
#   'life',
#   'counterpart',
#   'beat',
#   'lite',
#   'six',
#   'way',
#   'sunday',
#   'tour',
#   'miller',
#   'plant',
#   'mke',
#   'first',
#   'time',
#   'hooked',
#   'today',
#   'let',
#   'see',
#   'outset',
#   'similarity',
#   'contrast',
#   'lead',
#   'version',
#   'mgd',
#   'get',
#   'nice',
#   'couple',
#   'finger',
#   'head',
#   'lousy',
#   'retention',
#   'color',
#   'paler',
#   'shade',
#   'clarity',
#   'close',
#   'nose',
#   'still',
#   'fill',
#   'adjunct',
#   'especially',
#   'corn',
#   'prevalent',
#   'pretty',
#   'much',
#   'watery',
#   'real',
#   'innocuous',
#   'wonder',
#   'bother',
#   'finish',
#   'mighty',
#   'tasteless',
#   'strip',
#   'fabric',
#   'color',
#   'water',
#   'feh',
#   'might',
#   'water',
#   'least',
#   'caloric',
#   'intake',
#   'low',
#   'one',
#   'may',
#   'jeopardy'],
#  ['picked',
#   'bud',
#   'select',
#   'gas',
#   'station',
#   'cent',
#   'piece',
#   'time',
#   'find',
#   'even',
#   'adjunct',
#   'low',
#   'price',
#   'buy',
#   'diamond',
#   'rough',
#   'drank',
#   'would',
#   'much',
#   'metallic',
#   'bad',
#   'cereal',
#   'grain',
#   'touch',
#   'grape',
#   'slightly',
#   'bready',
#   'light',
#   'watery',
#   'body',
#   'flat',
#   'bother'],
#  ['alright', 'great', 'make', 'mistake', 'either'],
#  ['eberhard',
#   'adolphus',
#   'roll',
#   'grave',
#   'would',
#   'first',
#   'destroyed',
#   'say',
#   'say',
#   'counting',
#   'calorie',
#   'drink',
#   'water',
#   'switch',
#   'vodka'],
#  ['thin', 'flavorless', 'odd', 'worried', 'drink', 'water', 'taste', 'lover'],
#  ['like',
#   'light',
#   'beer',
#   'watch',
#   'calorie',
#   'realize',
#   'lot',
#   'people',
#   'hat',
#   'surprised',
#   'taste',
#   'light',
#   'crisp',
#   'guilty',
#   'drinking',
#   'couple',
#   'drink',
#   'lot',
#   'work',
#   'hard',
#   'find',
#   'bottle',
#   'pack',
#   'popular',
#   'find',
#   'can',
#   'work',
#   'bumper'],
#  ['bottle',
#   'review',
#   'notesjust',
#   'water',
#   'bud',
#   'lite',
#   'basically',
#   'abv',
#   'make',
#   'scratch',
#   'head',
#   'absolute',
#   'bewilderment',
#   'tarnation',
#   'near',
#   'near',
#   'beeri',
#   'get'],
#  ['possibly',
#   'bad',
#   'ever',
#   'light',
#   'frothy',
#   'sour',
#   'actually',
#   'make',
#   'queasy',
#   'side',
#   'abv',
#   'meaning',
#   'would',
#   'drink',
#   'twice',
#   'many',
#   'get',
#   'feel',
#   'make',
#   'even',
#   'poorer',
#   'choice',
#   'sure',
#   'low',
#   'carbs',
#   'calorie',
#   'give',
#   'break',
#   'rather',
#   'drink',
#   'na',
#   'taste',
#   'say',
#   'never',
#   'buy',
#   'call',
#   'lager',
#   'travesty'],
#  ['light'],
#  ['unfairly',
#   'rat',
#   'want',
#   'clear',
#   'thing',
#   'keto',
#   'long',
#   'time',
#   'low',
#   'carb',
#   'extremely',
#   'watery',
#   'think',
#   'la',
#   'croix',
#   'flavor',
#   'however',
#   'like',
#   'seltzer',
#   'water',
#   'watch',
#   'calorie',
#   'carbs',
#   'allows',
#   'kick',
#   'em',
#   'back',
#   'game',
#   'buddy',
#   'get',
#   'carb',
#   'highly',
#   'recommend',
#   'carb',
#   'calorie',
#   'conscious',
#   'yea',
#   'gon',
#   'na',
#   'blow',
#   'mind',
#   'hoppy',
#   'flavor',
#   'happy',
#   'option',
#   'like'],
#  ['mean',
#   'think',
#   'great',
#   'ore',
#   'even',
#   'like',
#   'drink',
#   'case',
#   'easily',
#   'wake',
#   'feel',
#   'like',
#   'drink',
#   'speak',
#   'personal',
#   'experience',
#   'love',
#   'anything',
#   'special'],
#  ['think',
#   'bud',
#   'light',
#   'water',
#   'straight',
#   'piss',
#   'water',
#   'rain',
#   'run',
#   'filter',
#   'old',
#   'coin',
#   'extremely',
#   'light',
#   'definitely',
#   'crushable',
#   'honestly',
#   'much'],
#  ['decent',
#   'example',
#   'low',
#   'calorie',
#   'low',
#   'carb',
#   'pours',
#   'pale',
#   'yellow',
#   'color',
#   'little',
#   'head',
#   'aroma',
#   'malt',
#   'something',
#   'vaguely',
#   'thin',
#   'watery',
#   'calorie',
#   'light',
#   'clean',
#   'thin',
#   'finish',
#   'great',
#   'beat',
#   'drinking',
#   'water'],
#  ['surprisingly',
#   'faint',
#   'isnt',
#   'suprising',
#   'dosent',
#   'strong',
#   'certainly',
#   'bad',
#   'especially',
#   'calorie',
#   'could',
#   'improve',
#   'lot',
#   'addition',
#   'lime',
#   'flavor',
#   'could',
#   'achieve',
#   'add',
#   'slice',
#   'lime',
#   'super',
#   'crisp',
#   'bad',
#   'aftertaste',
#   'beer',
#   'mean',
#   'nice',
#   'long',
#   'session',
#   'try',
#   'watch',
#   'calorie'],
#  ['oz',
#   'clear',
#   'bottle',
#   'freshest',
#   'purchase',
#   'cold',
#   'single',
#   'pour',
#   'oz',
#   'mug',
#   'l',
#   'liquid',
#   'fizzy',
#   'white',
#   'head',
#   'pour',
#   'immediately',
#   'collapse',
#   'thin',
#   'collar',
#   'jerking',
#   'glass',
#   'fro',
#   'leave',
#   'brief',
#   'streak',
#   'lace',
#   'immediately',
#   'slide',
#   'aways',
#   'faint',
#   'honeyish',
#   'malt',
#   'syrup',
#   'little',
#   'else',
#   'maybe',
#   'grain',
#   'husk',
#   'neuter',
#   'flour',
#   'product',
#   'carbonic',
#   'bitter',
#   'finish',
#   'odd',
#   'cereal',
#   'aftertaste',
#   'pretty',
#   'damn',
#   'bone',
#   'dry',
#   'mild',
#   'essence',
#   'palatef',
#   'restrain',
#   'sudsy',
#   'sizzle',
#   'shapeless',
#   'body',
#   'finish',
#   'rather',
#   'notable',
#   'tailor',
#   'body',
#   'drynesso',
#   'rather',
#   'drain',
#   'flavor',
#   'emaciate',
#   'body',
#   'note',
#   'quite',
#   'natty',
#   'ice'],
#  ['spend',
#   'long',
#   'day',
#   'beach',
#   'everything',
#   'refresh',
#   'flavor',
#   'nothing',
#   'high',
#   'calorie',
#   'alcohol',
#   'snob',
#   'hater',
#   'let',
#   'hate'],
#  ['well', 'water', 'low', 'carb', 'diet'],
#  ['review',
#   'year',
#   'ago',
#   'tough',
#   'keep',
#   'track',
#   'review',
#   'go',
#   'many',
#   'online',
#   'place',
#   'day',
#   'difficult',
#   'entity',
#   'overmod',
#   'pours',
#   'similar',
#   'color',
#   'see',
#   'clear',
#   'bottle',
#   'lot',
#   'grain',
#   'get',
#   'ta',
#   'count',
#   'calorie',
#   'concentrate',
#   'urine',
#   'color',
#   'thin',
#   'head',
#   'eviscerates',
#   'range',
#   'barely',
#   'discernable',
#   'grain',
#   'quality',
#   'nose',
#   'lager',
#   'yeast',
#   'highly',
#   'carbonate',
#   'light',
#   'grain',
#   'meet',
#   'mineral',
#   'water',
#   'quality',
#   'go',
#   'hard',
#   'even',
#   'average',
#   'amount',
#   'hop',
#   'sure',
#   'use',
#   'super',
#   'high',
#   'alpha',
#   'acid',
#   'flavor',
#   'kind',
#   'flavor',
#   'per',
#   'se',
#   'definitely',
#   'lack',
#   'flavor',
#   'almost',
#   'make',
#   'wonder',
#   'point',
#   'nonetheless',
#   'seem',
#   'accomplish',
#   'go',
#   'ugh',
#   'one',
#   'double',
#   'digit',
#   'positive',
#   'rate',
#   'deviation',
#   'care',
#   'oh'],
#  ['pretty',
#   'bad',
#   'ice',
#   'cold',
#   'prefer',
#   'many',
#   'peer',
#   'segment',
#   'metallic',
#   'sweet',
#   'overly',
#   'cheap',
#   'taste',
#   'honest',
#   'also',
#   'nothing',
#   'count',
#   'id',
#   'rather',
#   'little',
#   'adjuncty',
#   'character',
#   'slightly',
#   'appreciable',
#   'lager',
#   'yeast',
#   'element',
#   'flavor',
#   'thats',
#   'drink',
#   'fast',
#   'warms',
#   'like',
#   'garbage',
#   'definitely',
#   'bad',
#   'beer',
#   'even',
#   'watery',
#   'light',
#   'high',
#   'carbonation',
#   'help',
#   'wouldnt',
#   'make',
#   'day',
#   'one',
#   'isolation',
#   'fine',
#   'start',
#   'like',
#   'little',
#   'bit',
#   'towards',
#   'bottom',
#   'decide',
#   'absence',
#   'hop',
#   'even',
#   'style',
#   'really',
#   'cant',
#   'hate',
#   'hard',
#   'one',
#   'thing',
#   'like',
#   'sort',
#   'like',
#   'classic',
#   'bud',
#   'albeit',
#   'little',
#   'lesser',
#   'version',
#   'tell',
#   'family',
#   'lager',
#   'find',
#   'appeal',
#   'reason',
#   'sip',
#   'pounder',
#   'anything',
#   'bad',
#   'everyone',
#   'say'],
#  ['seltzer', 'water', 'slight', 'flavor'],
#  ['flavor', 'seltzer', 'water', 'palate', 'cleanser'],
#  ['review',
#   'note',
#   'take',
#   'year',
#   'ago',
#   'run',
#   'per',
#   'oz',
#   'clear',
#   'bottle',
#   'bought',
#   'carbohydrate'],
#  ['bought',
#   'single',
#   'old',
#   'pale',
#   'gold',
#   'small',
#   'head',
#   'light',
#   'grain',
#   'weird',
#   'malt',
#   'hop',
#   'profile',
#   'thank',
#   'goodness',
#   'light',
#   'offer',
#   'positive',
#   'surprise',
#   'light',
#   'rather',
#   'inoffensive',
#   'grainy',
#   'hint',
#   'hint',
#   'bitterness',
#   'well',
#   'michelob',
#   'ultra'],
#  ['love',
#   'full',
#   'flavor',
#   'full',
#   'body',
#   'say',
#   'drink',
#   'like',
#   'year',
#   'old',
#   'anymore',
#   'health',
#   'issue',
#   'boot',
#   'bottom',
#   'line',
#   'wo',
#   'kill',
#   'low',
#   'alcohol',
#   'content',
#   'allows',
#   'cut',
#   'alcohol',
#   'intake',
#   'bud',
#   'look',
#   'smell',
#   'taste',
#   'enough',
#   'like',
#   'make',
#   'work',
#   'happy'],
#  ['ounce',
#   'lager',
#   'glass',
#   'best',
#   'pours',
#   'crystal',
#   'clear',
#   'medium',
#   'golden',
#   'yellow',
#   'color',
#   'small',
#   'fairly',
#   'dense',
#   'fluffy',
#   'white',
#   'head',
#   'decent',
#   'retention',
#   'reduces',
#   'ring',
#   'lace',
#   'lingers',
#   'light',
#   'spotty',
#   'lace',
#   'cling',
#   'glass',
#   'fair',
#   'amount',
#   'stream',
#   'carbonation',
#   'appearance',
#   'aroma',
#   'cracker',
#   'white',
#   'bread',
#   'dough',
#   'lightly',
#   'toast',
#   'biscuit',
#   'light',
#   'caramel',
#   'earthiness',
#   'nice',
#   'pleasant',
#   'aroma',
#   'pale',
#   'malt',
#   'light',
#   'earthy',
#   'hop',
#   'note',
#   'solid',
#   'strength',
#   'cracker',
#   'white',
#   'bread',
#   'dough',
#   'lightly',
#   'toast',
#   'biscuit',
#   'light',
#   'caramel',
#   'earthiness',
#   'herbal',
#   'grassy',
#   'spicy',
#   'bitterness',
#   'finish',
#   'linger',
#   'note',
#   'cracker',
#   'white',
#   'bread',
#   'dough',
#   'lightly',
#   'toast',
#   'biscuit',
#   'light',
#   'caramel',
#   'earthiness',
#   'short',
#   'bit',
#   'solid',
#   'robustness',
#   'pale',
#   'malt',
#   'light',
#   'earthy',
#   'hop',
#   'flavor',
#   'nice',
#   'balance',
#   'zero',
#   'flavor',
#   'finish',
#   'finish',
#   'perfectly',
#   'clean',
#   'lager',
#   'flavor',
#   'zero',
#   'note',
#   'medium',
#   'carbonation',
#   'light',
#   'body',
#   'smooth',
#   'fairly',
#   'okay',
#   'bland',
#   'finish',
#   'zero',
#   'warm',
#   'alcohol',
#   'expect',
#   'solid',
#   'light',
#   'lager',
#   'around',
#   'solid',
#   'robustness',
#   'pale',
#   'malt',
#   'light',
#   'earthy',
#   'hop',
#   'flavor',
#   'smooth',
#   'crisp',
#   'clean',
#   'refresh',
#   'drink',
#   'pretty',
#   'impressive',
#   'ultra',
#   'light',
#   'thing',
#   'consider',
#   'adjunct',
#   'regular',
#   'version',
#   'clean',
#   'pale',
#   'malt',
#   'solid',
#   'earthy',
#   'hop',
#   'presence',
#   'style',
#   'enjoyable',
#   'make',
#   'offering'],
#  ['great',
#   'truly',
#   'look',
#   'light',
#   'calorie',
#   'alcohol',
#   'content',
#   'pretty',
#   'perfect',
#   'long',
#   'day',
#   'sun',
#   'want',
#   'dehydrate',
#   'two',
#   'beer'],
#  ['year',
#   'since',
#   'graduate',
#   'college',
#   'none',
#   'u',
#   'really',
#   'thought',
#   'year',
#   'yet',
#   'natty',
#   'light',
#   'possession',
#   'one',
#   'ever',
#   'consider',
#   'know',
#   'buy',
#   'need',
#   'volume',
#   'budget',
#   'change',
#   'since',
#   'last',
#   'consume',
#   'carbonate',
#   'water',
#   'filter',
#   'old',
#   'penny',
#   'absolutely',
#   'light',
#   'easy',
#   'drink',
#   'instantly',
#   'fill',
#   'regret',
#   'thought',
#   'job',
#   'drinking',
#   'enter',
#   'head',
#   'take',
#   'metallic',
#   'piss',
#   'water'],
#  ['ounce',
#   'pour',
#   'tumbler',
#   'style',
#   'pint',
#   'crystal',
#   'clear',
#   'pale',
#   'straw',
#   'one',
#   'plus',
#   'inch',
#   'stark',
#   'white',
#   'foam',
#   'last',
#   'minute',
#   'recede',
#   'open',
#   'nice',
#   'large',
#   'grain',
#   'aroma',
#   'settle',
#   'floral',
#   'hop',
#   'lesser',
#   'grain',
#   'aroma',
#   'nose',
#   'mostly',
#   'disappears',
#   'head',
#   'occasional',
#   'wet',
#   'little',
#   'flavor',
#   'light',
#   'toast',
#   'grainy',
#   'malt',
#   'floral',
#   'hop',
#   'aftertaste',
#   'bit',
#   'highly',
#   'carbonate',
#   'open',
#   'crisp',
#   'bite',
#   'astringent',
#   'mouth',
#   'coat',
#   'quality',
#   'thin',
#   'average',
#   'style',
#   'opinion'],
#  ['time',
#   'place',
#   'cheap',
#   'house',
#   'never',
#   'time',
#   'place',
#   'natty',
#   'friend',
#   'house',
#   'something',
#   'fizzy',
#   'drink',
#   'rancid',
#   'stuff',
#   'give',
#   'bud',
#   'light',
#   'coors',
#   'miller',
#   'corona',
#   'yuengling',
#   'light',
#   'anything',
#   'junk',
#   'day',
#   'without',
#   'flavor',
#   'flavor',
#   'putrid'],
#  ['plain',
#   'simple',
#   'crack',
#   'open',
#   'drink',
#   'repeat',
#   'superior',
#   'drinkability',
#   'decent',
#   'flavor',
#   'best',
#   'price',
#   'find',
#   'anywhere',
#   'sure',
#   'guy',
#   'gigantic',
#   'gut',
#   'chug',
#   'triple',
#   'hopped',
#   'session',
#   'hazy',
#   'nitro',
#   'cold',
#   'ferment',
#   'ipa',
#   'rate',
#   'know',
#   'gettin',
#   'rack'],
#  ['gross'],
#  ['actually',
#   'like',
#   'go',
#   'easy',
#   'nice',
#   'clean',
#   'usually',
#   'anything',
#   'ab',
#   'really',
#   'like',
#   'nat',
#   'stuff',
#   'finish',
#   'mow',
#   'yard',
#   'take',
#   'rest'],
#  ['citrus',
#   'mild',
#   'pine',
#   'load',
#   'grapefruit',
#   'pine',
#   'mild',
#   'yeast',
#   'character',
#   'malt',
#   'seem',
#   'yeast',
#   'citra',
#   'nice',
#   'bitterness',
#   'back',
#   'palate',
#   'encompass',
#   'soft',
#   'pillowy',
#   'mfovr'],
#  ['majority',
#   'craft',
#   'brew',
#   'loser',
#   'upvote',
#   'disgust',
#   'adjunct',
#   'stout',
#   'ipa',
#   'shit',
#   'easily',
#   'drinkable',
#   'affordable',
#   'quality',
#   'ready',
#   'kid',
#   'move',
#   'nonsense',
#   'let',
#   'craft',
#   'fad',
#   'die',
#   'time',
#   'lager',
#   'extremely',
#   'drinkable',
#   'cheap',
#   'u',
#   'prefer',
#   'dollar',
#   'pack',
#   'lactose',
#   'infuse',
#   'ipa',
#   'shit',
#   'go',
#   'blow',
#   'as',
#   'die',
#   'ukraine',
#   'need',
#   'blood',
#   'cashcows',
#   'sign',
#   'urself',
#   'loser'],
#  ['gon',
#   'na',
#   'get',
#   'say',
#   'natty',
#   'light',
#   'best',
#   'world',
#   'drink',
#   'natty',
#   'light',
#   'taste',
#   'great',
#   'job',
#   'pretty',
#   'damn',
#   'cheap',
#   'crush',
#   'hot',
#   'day',
#   'hang',
#   'like',
#   'nostalgia'],
#  ['know',
#   'would',
#   'anyone',
#   'discus',
#   'body',
#   'aroma',
#   'nuance',
#   'natural',
#   'light',
#   'sure',
#   'go',
#   'rank',
#   'ipa',
#   'german',
#   'maibachs',
#   'suppose',
#   'type',
#   'like',
#   'miller',
#   'light',
#   'bud',
#   'light',
#   'michelob',
#   'light',
#   'etc',
#   'kind',
#   'cheap',
#   'grab',
#   'hot',
#   'day',
#   'mow',
#   'grass',
#   'low',
#   'abv',
#   'light',
#   'crisp',
#   'go',
#   'quick',
#   'easy',
#   'basic',
#   'thirst',
#   'quench',
#   'nothing',
#   'wrong',
#   'keep',
#   'garage',
#   'fridge',
#   'need',
#   'quick',
#   'start',
#   'weedwacking',
#   'moment',
#   'embarrasses',
#   'put',
#   'coozie'],
#  ['best'],
#  ['oz',
#   'pour',
#   'imperial',
#   'pint',
#   'glasslook',
#   'light',
#   'straw',
#   'lot',
#   'bubble',
#   'three',
#   'finger',
#   'head',
#   'quickly',
#   'dissipates',
#   'thin',
#   'foam',
#   'lacingsmell',
#   'maltiness',
#   'sweet',
#   'thoughtaste',
#   'pretty',
#   'straight',
#   'forward',
#   'lager',
#   'style',
#   'little',
#   'water',
#   'little',
#   'bitter',
#   'finishmouthfeel',
#   'carbonation',
#   'light',
#   'mouthfeeloverall',
#   'pretty',
#   'average',
#   'want',
#   'something',
#   'cold',
#   'taste',
#   'like',
#   'find',
#   'nearly',
#   'gas',
#   'station',
#   'break',
#   'bank',
#   'give',
#   'best',
#   'light',
#   'bit',
#   'worry',
#   'food',
#   'pairing',
#   'one',
#   'simple',
#   'overthink'],
#  ['grocery',
#   'outlet',
#   'pale',
#   'clear',
#   'golden',
#   'fizzy',
#   'foamy',
#   'head',
#   'head',
#   'look',
#   'promising',
#   'poof',
#   'go',
#   'grainy',
#   'aroma',
#   'adjunct',
#   'grain',
#   'corn',
#   'sweet',
#   'grainy',
#   'flavor',
#   'slight',
#   'vegetal',
#   'character',
#   'hop',
#   'provide',
#   'quick',
#   'sting',
#   'fade',
#   'nothingness',
#   'certainly',
#   'would',
#   'want',
#   'flavor',
#   'linger'],
#  ['suck'],
#  ['yeccchhh'],
#  ['beer',
#   'like',
#   'always',
#   'three',
#   'great',
#   'thing',
#   'god',
#   'green',
#   'earth',
#   'snob',
#   'wussies',
#   'go',
#   'back',
#   'trash',
#   'trash',
#   'make',
#   'football',
#   'watch',
#   'simpleton',
#   'renaissance',
#   'man',
#   'artisanal',
#   'aficionado',
#   'pity',
#   'anybody',
#   'dumb',
#   'enough',
#   'enjoy',
#   'meh',
#   'would',
#   'ask',
#   'several',
#   'year',
#   'back',
#   'take',
#   'would',
#   'squarely',
#   'camp',
#   'firmly',
#   'camp',
#   'need',
#   'review',
#   'go',
#   'color',
#   'aroma',
#   'subtle',
#   'flavor',
#   'nuance',
#   'anyone',
#   'site',
#   'know',
#   'something',
#   'like',
#   'early',
#   'drinking',
#   'year',
#   'long',
#   'first',
#   'imperial',
#   'fizzy',
#   'refresh',
#   'corn',
#   'water',
#   'know',
#   'nothing',
#   'wrong',
#   'go',
#   'amaze',
#   'quirkiness',
#   'unexpected',
#   'depth',
#   'flavor',
#   'damn',
#   'refresh',
#   'hot',
#   'summer',
#   'day',
#   'complete',
#   'hard',
#   'workout',
#   'suppose',
#   'people',
#   'genuinely',
#   'like',
#   'flavor',
#   'fair',
#   'hater',
#   'like',
#   'blasphemy',
#   'consider',
#   'natty',
#   'light',
#   'category',
#   'favorite',
#   'bourbon',
#   'barrel',
#   'age',
#   'stout',
#   'need',
#   'lighten',
#   'time',
#   'place',
#   'every',
#   'one',
#   'exception'],
#  ['george',
#   'washington',
#   'drank',
#   'cross',
#   'delaware',
#   'would',
#   'gotten',
#   'day',
#   'earlier',
#   'light',
#   'refresh',
#   'official',
#   'south',
#   'carolina',
#   'go',
#   'well',
#   'haul',
#   'fish',
#   'side',
#   'boat',
#   'day',
#   'snob',
#   'drink',
#   'skunky',
#   'ipas',
#   'get',
#   'dude',
#   'unhook',
#   'fish',
#   'icky'],
#  ['third',
#   'light',
#   'list',
#   'price',
#   'great',
#   'summer',
#   'want',
#   'keep',
#   'lighter',
#   'underrated',
#   'need',
#   'enjoy',
#   'judged'],
#  ['natural',
#   'light',
#   'stop',
#   'say',
#   'price',
#   'point',
#   'buy',
#   'anything',
#   'else',
#   'pack',
#   'price',
#   'beat',
#   'period',
#   'rate'],
#  ['natural',
#   'light',
#   'one',
#   'purest',
#   'lite',
#   'beer',
#   'market',
#   'balance',
#   'blend'],
#  ['ok',
#   'make',
#   'point',
#   'post',
#   'natural',
#   'light',
#   'compare',
#   'awesome',
#   'hazy',
#   'ipa',
#   'ne',
#   'ipa',
#   'anything',
#   'else',
#   'like',
#   'mass',
#   'produce',
#   'american',
#   'light',
#   'completely',
#   'story',
#   'short',
#   'brother',
#   'drinking',
#   'top',
#   'notch',
#   'hazy',
#   'ne',
#   'ipas',
#   'coozie',
#   'around',
#   'notice',
#   'singular',
#   'natural',
#   'light',
#   'mini',
#   'fridge',
#   'pool',
#   'table',
#   'left',
#   'son',
#   'lark',
#   'replace',
#   'brother',
#   'top',
#   'notch',
#   'brew',
#   'natural',
#   'light',
#   'watch',
#   'take',
#   'drink',
#   'look',
#   'strange',
#   'keep',
#   'drinking',
#   'expect',
#   'spit',
#   'long',
#   'story',
#   'shorty',
#   'laugh',
#   'say',
#   'thin',
#   'enjoy',
#   'flavor',
#   'sip',
#   'agree',
#   'wow',
#   'suppose',
#   'garbage',
#   'time',
#   'since',
#   'friend',
#   'mine',
#   'pack',
#   'drinking',
#   'one',
#   'bought',
#   'pack',
#   'first',
#   'time',
#   'year',
#   'cook',
#   'brat',
#   'anyway',
#   'loss',
#   'nasty',
#   'bottom',
#   'line',
#   'tho',
#   'actually',
#   'pretty',
#   'rat',
#   'american',
#   'brew',
#   'alternative',
#   'miller',
#   'lite',
#   'certainly',
#   'well',
#   'coors',
#   'light',
#   'something',
#   'go',
#   'rate',
#   'base',
#   'relation',
#   'beer'],
#  ['water', 'color', 'barely', 'aroma', 'flavor'],
#  ['note',
#   'look',
#   'like',
#   'miller',
#   'smell',
#   'like',
#   'miller',
#   'taste',
#   'like',
#   'miller',
#   'water',
#   'chaser',
#   'another',
#   'water',
#   'wash',
#   'feel',
#   'light',
#   'count',
#   'know',
#   'thing'],
#  ['think',
#   'would',
#   'anything',
#   'say',
#   'damn',
#   'site',
#   'well',
#   'even',
#   'low',
#   'alcohol',
#   'brew',
#   'really',
#   'like',
#   'ca',
#   'get',
#   'past'],
#  ['bottle',
#   'ran',
#   'lack',
#   'flavour',
#   'amber',
#   'malt',
#   'malt',
#   'malt',
#   'drinkable',
#   'nice',
#   'albeit',
#   'shallow',
#   'flavour',
#   'dependable',
#   'nonalcoholic',
#   'something',
#   'anyone',
#   'would',
#   'likely',
#   'crave',
#   'probably',
#   'well',
#   'odoul',
#   'really',
#   'care',
#   'high',
#   'c',
#   'average'],
#  ['oz',
#   'pours',
#   'clear',
#   'pale',
#   'straw',
#   'yellow',
#   'decent',
#   'white',
#   'head',
#   'lace',
#   'little',
#   'much',
#   'maybe',
#   'grain',
#   'adjunct',
#   'corn',
#   'much',
#   'something',
#   'hint',
#   'towards',
#   'grain',
#   'odd',
#   'something',
#   'brief',
#   'terribly',
#   'fizzy',
#   'crisp',
#   'tonic',
#   'much',
#   'well',
#   'na',
#   'brew',
#   'virtually',
#   'nothing',
#   'except',
#   'water',
#   'clean',
#   'palate',
#   'congest',
#   'mild',
#   'even',
#   'macro',
#   'na',
#   'adjunct',
#   'lager'],
#  ['murky',
#   'yellow',
#   'lot',
#   'fizzy',
#   'malty',
#   'sweet',
#   'malty',
#   'bit',
#   'like',
#   'pear',
#   'cider',
#   'taste',
#   'like',
#   'flat',
#   'apple',
#   'juice',
#   'malt',
#   'corn'],
#  ['pours',
#   'yellow',
#   'color',
#   'lot',
#   'carbonation',
#   'nice',
#   'head',
#   'grain',
#   'mostly',
#   'corn',
#   'mouthful',
#   'watery',
#   'ok',
#   'ok',
#   'drink',
#   'bit',
#   'water'],
#  ['non',
#   'alcohol',
#   'course',
#   'real',
#   'picky',
#   'much',
#   'price',
#   'paid',
#   'change',
#   'pack',
#   'can',
#   'get',
#   'job',
#   'do'],
#  ['come',
#   'weak',
#   'as',
#   'straw',
#   'yellow',
#   'see',
#   'bandy',
#   'several',
#   'incarnation',
#   'miller',
#   'brewing',
#   'top',
#   'see',
#   'something',
#   'ca',
#   'retain',
#   'head',
#   'whatsoever',
#   'aroma',
#   'heat',
#   'press',
#   'can',
#   'vegetable',
#   'slightest',
#   'amount',
#   'row',
#   'give',
#   'water',
#   'anything',
#   'hop',
#   'yeast',
#   'barely',
#   'perceptible',
#   'best',
#   'part',
#   'non',
#   'alcoholic',
#   'bitterness',
#   'almost',
#   'heat',
#   'like',
#   'make',
#   'think',
#   'harsh',
#   'drank',
#   'hot',
#   'yeah',
#   'get',
#   'ta',
#   'say',
#   'smoke'],
#  ['pour',
#   'oz',
#   'pilsner',
#   'glass',
#   'poor',
#   'pilsner',
#   'glass',
#   'gate',
#   'golden',
#   'carbonate',
#   'lack',
#   'head',
#   'malt',
#   'maybe',
#   'veggie',
#   'like',
#   'barely',
#   'carrot',
#   'dipped',
#   'glass',
#   'water',
#   'thank',
#   'thin',
#   'bad',
#   'na',
#   'quite'],
#  ['think',
#   'style',
#   'could',
#   'bad',
#   'try',
#   'one',
#   'wife',
#   'hand',
#   'honestly',
#   'consider'],
#  ['straw',
#   'color',
#   'slight',
#   'head',
#   'slight',
#   'malt',
#   'follow',
#   'nose',
#   'slight',
#   'malt',
#   'light',
#   'body',
#   'carbonate',
#   'decent'],
#  ['fabulously',
#   'bad',
#   'hardly',
#   'taste',
#   'like',
#   'taste',
#   'though',
#   'someone',
#   'put',
#   'sweet',
#   'yeast',
#   'roll',
#   'blender',
#   'cup',
#   'water',
#   'pulverize',
#   'stuff',
#   'drinkable',
#   'three',
#   'u',
#   'domestic',
#   'na',
#   'brew',
#   'try',
#   'one',
#   'offend',
#   'palate',
#   'enough',
#   'wo',
#   'give',
#   'second',
#   'try'],
#  ['least', 'favorite', 'na', 'beer'],
#  ['appearance',
#   'pours',
#   'pale',
#   'pale',
#   'straw',
#   'yellow',
#   'color',
#   'bordering',
#   'clear',
#   'head',
#   'finger',
#   'tall',
#   'actually',
#   'stay',
#   'around',
#   'unlike',
#   'coors',
#   'try',
#   'last',
#   'night',
#   'lace',
#   'left',
#   'side',
#   'mash',
#   'carrot',
#   'yam',
#   'pea',
#   'potato',
#   'faint',
#   'bit',
#   'plastic',
#   'mostly',
#   'vegetal',
#   'smell',
#   'faint',
#   'bit',
#   'mash',
#   'veggie',
#   'disappears',
#   'rather',
#   'quickly',
#   'develops',
#   'roast',
#   'fire',
#   'corn',
#   'flavor',
#   'faint',
#   'club',
#   'soda',
#   'brown',
#   'potato',
#   'skin',
#   'finish',
#   'bit',
#   'present',
#   'coors',
#   'last',
#   'night',
#   'carbonate',
#   'heavy',
#   'side',
#   'light',
#   'body',
#   'end',
#   'sparkle',
#   'like',
#   'club',
#   'absolutely',
#   'horrid',
#   'could',
#   'possibly',
#   'get',
#   'use',
#   'cheap',
#   'heal',
#   'yeast',
#   'overgrowth',
#   'soon',
#   'actual',
#   'review',
#   'time',
#   'explore',
#   'world'],
#  ['would', 'expect'],
#  ['try',
#   'snobby',
#   'come',
#   'rather',
#   'try',
#   'meet',
#   'term',
#   'craft',
#   'beer',
#   'try',
#   'depth',
#   'complexity',
#   'deliciousness',
#   'hold',
#   'elevate',
#   'standard',
#   'meant',
#   'great',
#   'experience',
#   'different',
#   'much',
#   'like',
#   'fast',
#   'food',
#   'fine',
#   'din',
#   'macro',
#   'design',
#   'cheap',
#   'plain',
#   'inoffensive',
#   'macro',
#   'include',
#   'one',
#   'white',
#   'bread',
#   'mineral',
#   'flavor',
#   'real',
#   'head',
#   'hop',
#   'profile',
#   'highly',
#   'carbonate',
#   'refresh',
#   'cold',
#   'course',
#   'bad',
#   'beer',
#   'cheap',
#   'category',
#   'one',
#   'fail',
#   'boring',
#   'instead',
#   'gross',
#   'steel',
#   'reserve',
#   'instance',
#   'brew',
#   'keystone',
#   'light',
#   'serf',
#   'purpose',
#   'casual',
#   'beverage',
#   'much',
#   'like',
#   'tea',
#   'soda',
#   'lot',
#   'less',
#   'sugar',
#   'probably',
#   'well',
#   'soda',
#   'actually',
#   'unless',
#   'kill',
#   'come',
#   'home',
#   'long',
#   'day',
#   'work',
#   'like',
#   'write',
#   'taste',
#   'note',
#   'look',
#   'china',
#   'cabinet',
#   'right',
#   'glass',
#   'happily',
#   'knock',
#   'back',
#   'can',
#   'maybe',
#   'miller',
#   'lite',
#   'decent',
#   'buzz',
#   'deeper',
#   'sleep',
#   'thing',
#   'place',
#   'universe'],
#  ['low', 'calorie', 'great', 'price', 'cant', 'beat'],
#  ['drink'],
#  ['non',
#   'offensive',
#   'taste',
#   'like',
#   'water',
#   'coors',
#   'lite',
#   'would',
#   'buy'],
#  ['say',
#   'watery',
#   'taste',
#   'like',
#   'mineral',
#   'water',
#   'go',
#   'real',
#   'easy',
#   'especially',
#   'hot',
#   'summer',
#   'day',
#   'recommend',
#   'quick',
#   'water',
#   'mineral',
#   'hint',
#   'corn',
#   'much',
#   'else',
#   'almost',
#   'like',
#   'water',
#   'coors',
#   'light',
#   'go',
#   'figure',
#   'haha'],
#  ['drink', 'alot', 'cheap', 'complaint', 'probably', 'bad', 'ever', 'drank'],
#  ['use',
#   'drink',
#   'college',
#   'keg',
#   'could',
#   'purchase',
#   'certain',
#   'gas',
#   'station',
#   'make',
#   'cost',
#   'effective',
#   'like',
#   'water',
#   'metallic',
#   'like',
#   'coors',
#   'light',
#   'keystone',
#   'brew',
#   'coors',
#   'sweet',
#   'smell',
#   'light',
#   'golden',
#   'color',
#   'always',
#   'left',
#   'headache',
#   'bottom',
#   'barrel',
#   'coors',
#   'cant',
#   'imagine',
#   'anyone',
#   'would',
#   'still',
#   'drinking',
#   'high',
#   'school',
#   'college'],
#  ['date',
#   'june',
#   'think',
#   'pour',
#   'tulip',
#   'appearance',
#   'expect',
#   'pale',
#   'straw',
#   'yellow',
#   'style',
#   'inch',
#   'white',
#   'head',
#   'low',
#   'retention',
#   'aroma',
#   'also',
#   'expect',
#   'sorta',
#   'sweet',
#   'soft',
#   'grain',
#   'almost',
#   'noticeable',
#   'tongue',
#   'bland',
#   'basic',
#   'body',
#   'expect',
#   'thin',
#   'watery',
#   'typifies',
#   'style',
#   'expect',
#   'fine',
#   'quick',
#   'lawnmower',
#   'much',
#   'know',
#   'surprise',
#   'ticker'],
#  ['keystone',
#   'light',
#   'make',
#   'coors',
#   'brewing',
#   'packaging',
#   'pretty',
#   'unique',
#   'vibrant',
#   'expensive',
#   'pack',
#   'highly',
#   'recommend',
#   'get',
#   'ice',
#   'version',
#   'give',
#   'nasty',
#   'alcohol',
#   'standard',
#   'flavor',
#   'pretty',
#   'light',
#   'almost',
#   'like',
#   'water',
#   'aftertaste',
#   'really',
#   'light',
#   'scent',
#   'nothing',
#   'stink',
#   'recommend',
#   'price',
#   'insignificant',
#   'easy',
#   'drink',
#   'price'],
#  ['best',
#   'money',
#   'buy',
#   'absolutely',
#   'change',
#   'mind',
#   'every',
#   'time',
#   'crack',
#   'like',
#   'sit',
#   'summit',
#   'tallest',
#   'mountain',
#   'rockies'],
#  ['drank',
#   'keystone',
#   'light',
#   'year',
#   'regular',
#   'go',
#   'average',
#   'key',
#   'factor',
#   'many',
#   'year',
#   'simply',
#   'volume',
#   'consume',
#   'v',
#   'price',
#   'stuff',
#   'least',
#   'around',
#   'get',
#   'buck',
#   'pack',
#   'compare',
#   'many',
#   'domestic',
#   'budget',
#   'beer',
#   'range',
#   'pack',
#   'drinking',
#   'ever',
#   'drinking',
#   'excessive',
#   'amount',
#   'daily',
#   'basis',
#   'understand',
#   'current',
#   'score',
#   'get',
#   'say',
#   'much',
#   'well',
#   'bonfire',
#   'drunk',
#   'door',
#   'party',
#   'footin',
#   'bill',
#   'tab'],
#  ['say', 'one'],
#  ['drink',
#   'possibly',
#   'raid',
#   'metallic',
#   'bite',
#   'ever',
#   'taste',
#   'chill',
#   'enough',
#   'make',
#   'drinkable'],
#  ['come',
#   'hyped',
#   'let',
#   'guess',
#   'pbr',
#   'best',
#   'unknown',
#   'secret',
#   'hard',
#   'compare',
#   'full',
#   'body',
#   'pbr',
#   'competition',
#   'drink',
#   'pbr',
#   'bro',
#   'aka',
#   'pabst',
#   'blue',
#   'ribbon'],
#  ['definitely',
#   'bad',
#   'expect',
#   'nearly',
#   'icehouse',
#   'direct',
#   'comparison',
#   'okay',
#   'malt',
#   'sweet',
#   'bready',
#   'note',
#   'flavor',
#   'aftertaste',
#   'bit',
#   'bothersome',
#   'metallic',
#   'dry',
#   'otherwise',
#   'drinkable'],
#  ['pours',
#   'look',
#   'like',
#   'american',
#   'style',
#   'lager',
#   'head',
#   'fade',
#   'quickly',
#   'nose',
#   'insanely',
#   'sweet',
#   'taste',
#   'like',
#   'bitter',
#   'sugar',
#   'maybe',
#   'gummi',
#   'turn',
#   'bad',
#   'would',
#   'recommend',
#   'anyone',
#   'like',
#   'guess',
#   'sens',
#   'go',
#   'dormant',
#   'want',
#   'cold',
#   'high',
#   'alcohol',
#   'beverage'],
#  ['natty',
#   'ice',
#   'yes',
#   'even',
#   'anheuser',
#   'busch',
#   'website',
#   'refers',
#   'natural',
#   'ice',
#   'natty',
#   'ice',
#   'budget',
#   'friendly',
#   'bottom',
#   'tank',
#   'drank',
#   'ice',
#   'cold',
#   'meant',
#   'class',
#   'craft',
#   'brew',
#   'stand',
#   'par',
#   'high',
#   'price',
#   'american',
#   'adjunts',
#   'high',
#   'price',
#   'ice',
#   'drank',
#   'cold',
#   'like',
#   'mention',
#   'one',
#   'best',
#   'ice',
#   'beer',
#   'drink'],
#  ['silo',
#   'appearance',
#   'clear',
#   'yellow',
#   'gold',
#   'head',
#   'first',
#   'fizzle',
#   'little',
#   'barley',
#   'seltzer',
#   'mild',
#   'sweetness',
#   'fruitiness',
#   'like',
#   'grape',
#   'apple',
#   'reminds',
#   'drinking',
#   'mediocre',
#   'high',
#   'abv',
#   'finish',
#   'nondescript',
#   'picked',
#   'silo',
#   'curiosity',
#   'cheap',
#   'lager',
#   'kick',
#   'football',
#   'saturday',
#   'little',
#   'well',
#   'expect',
#   'icehouse',
#   'mickey',
#   'cheapo'],
#  ['pour',
#   'oz',
#   'pale',
#   'yellow',
#   'color',
#   'actually',
#   'sizable',
#   'head',
#   'retention',
#   'mostly',
#   'dissipates',
#   'corn',
#   'syrup',
#   'tad',
#   'bit',
#   'funkiness',
#   'alcohol',
#   'come',
#   'warm',
#   'drank',
#   'cold',
#   'taste',
#   'like',
#   'adjunct',
#   'light',
#   'slightly',
#   'sweet',
#   'subtle',
#   'malty',
#   'finish',
#   'however',
#   'warms',
#   'really',
#   'nasty',
#   'particular',
#   'booziness',
#   'really',
#   'come',
#   'rough',
#   'reminiscent',
#   'gasoline',
#   'drink',
#   'light',
#   'body',
#   'high',
#   'carbonation',
#   'boozy',
#   'type',
#   'despite',
#   'fact',
#   'write',
#   'full',
#   'review',
#   'natty',
#   'ice',
#   'really',
#   'meant',
#   'analyze',
#   'cold',
#   'drink',
#   'like',
#   'adjunct',
#   'lager',
#   'get',
#   'want',
#   'quicker',
#   'however',
#   'sit',
#   'around',
#   'start',
#   'try',
#   'pick',
#   'flavor',
#   'start',
#   'get',
#   'nasty',
#   'bottom',
#   'line',
#   'suppose'],
#  ['ice',
#   'beer',
#   'favorite',
#   'think',
#   'context',
#   'natural',
#   'ice',
#   'get',
#   'drunk',
#   'quick',
#   'scheme',
#   'best',
#   'ice',
#   'cheap',
#   'get',
#   'party',
#   'start'],
#  ['know', 'rat', 'low', 'price', 'cheap', 'buzz'],
#  ['pours',
#   'gold',
#   'generous',
#   'quickly',
#   'dissipate',
#   'head',
#   'lightly',
#   'carbonate',
#   'chill',
#   'mid',
#   'pale',
#   'malt',
#   'touch',
#   'corn',
#   'dominate',
#   'nose',
#   'though',
#   'visibly',
#   'carbonate',
#   'fine',
#   'bubbly',
#   'fizzation',
#   'tongue',
#   'much',
#   'akin',
#   'champ',
#   'mightily',
#   'crisp',
#   'clean',
#   'refresh',
#   'quite',
#   'satisfy',
#   'quencher',
#   'far',
#   'enjoyable',
#   'anticipate',
#   'buck',
#   'oz',
#   'buck',
#   'bit',
#   'overvalue',
#   'nonetheless',
#   'enjoy',
#   'curiosity',
#   'power',
#   'goof'],
#  ['taste',
#   'amaze',
#   'strong',
#   'rich',
#   'amber',
#   'color',
#   'smooth',
#   'upon',
#   'contact',
#   'mouth',
#   'bit',
#   'pricey',
#   'worth',
#   'every',
#   'penny',
#   'ok',
#   'computer',
#   'beer'],
#  ['phenomenal',
#   'love',
#   'smooth',
#   'sessionable',
#   'mild',
#   'lager',
#   'price',
#   'unbeatable',
#   'go',
#   'wrong',
#   'natural',
#   'ice',
#   'book'],
#  ['taste',
#   'basic',
#   'beernot',
#   'much',
#   'flavor',
#   'still',
#   'nice',
#   'light',
#   'flavornice',
#   'refresh'],
#  ['really',
#   'great',
#   'stop',
#   'think',
#   'kind',
#   'make',
#   'analyze',
#   'like',
#   'average',
#   'main',
#   'stream',
#   'comedy',
#   'movie',
#   'rude',
#   'much',
#   'blue',
#   'collar',
#   'construction',
#   'worker',
#   'get',
#   'home',
#   'legitimately',
#   'want',
#   'get',
#   'nice',
#   'buzz',
#   'hard',
#   'work',
#   'week'],
#  ['first',
#   'month',
#   'know',
#   'mean',
#   'sit',
#   'apartment',
#   'porch',
#   'lawn',
#   'chair',
#   'enjoy',
#   'best',
#   'louis',
#   'offer',
#   'decide',
#   'go',
#   'oz',
#   'format',
#   'time',
#   'like',
#   'deserve',
#   'walk',
#   'back',
#   'cumberland',
#   'farm',
#   'bought',
#   'first',
#   'pour',
#   'glass',
#   'display',
#   'beautiful',
#   'golden',
#   'color',
#   'kind',
#   'golden',
#   'hue',
#   'grandmother',
#   'teeth',
#   'head',
#   'quickly',
#   'disipates',
#   'liquid',
#   'gold',
#   'settle',
#   'quite',
#   'invite',
#   'metallic',
#   'must',
#   'even',
#   'though',
#   'scent',
#   'evolve',
#   'alcoholic',
#   'fill',
#   'room',
#   'flavor',
#   'bit',
#   'underwhelming',
#   'essentially',
#   'bark',
#   'bite',
#   'hint',
#   'spoil',
#   'apple',
#   'aluminum',
#   'compliment',
#   'stogie',
#   'rip',
#   'gem',
#   'light',
#   'dry',
#   'like',
#   'work',
#   'ethic',
#   'rate',
#   'solid',
#   'wait',
#   'next',
#   'month',
#   'treat'],
#  ['pours',
#   'piss',
#   'yellow',
#   'inch',
#   'white',
#   'head',
#   'lot',
#   'bubble',
#   'much',
#   'little',
#   'malt',
#   'straw',
#   'actually',
#   'pretty',
#   'complex',
#   'try',
#   'break',
#   'full',
#   'body',
#   'quite',
#   'nice',
#   'light',
#   'pretty',
#   'high',
#   'carbonation',
#   'easy',
#   'session',
#   'say',
#   'least',
#   'highly',
#   'underrated',
#   'affordable',
#   'definitely',
#   'drinking',
#   'future'],
#  ['bad',
#   'adjunct',
#   'lager',
#   'go',
#   'pretty',
#   'light',
#   'smooth',
#   'mildly',
#   'bitter',
#   'mildly',
#   'sweet',
#   'note',
#   'corn',
#   'grain',
#   'apparent',
#   'guess',
#   'mild',
#   'refresh',
#   'enjoyable',
#   'would',
#   'come',
#   'back'],
#  ['bottle',
#   'steal',
#   'uncle',
#   'fridgethis',
#   'light',
#   'barely',
#   'light',
#   'scent',
#   'badly',
#   'burn',
#   'corn',
#   'maybe',
#   'ethereal',
#   'kiss',
#   'hop',
#   'like',
#   'tell',
#   'actually',
#   'smell',
#   'taste',
#   'bust',
#   'diet',
#   'many',
#   'optionsbad',
#   'even',
#   'consider'],
#  ['great',
#   'watch',
#   'calorie',
#   'carbs',
#   'best',
#   'taste',
#   'yet',
#   'drink',
#   'even',
#   'watch',
#   'weight',
#   'love',
#   'loses',
#   'nothing',
#   'flavor',
#   'crisp'],
#  ['estfort',
#   'myers',
#   'beach',
#   'flpoured',
#   'pint',
#   'glasslook',
#   'straw',
#   'yellow',
#   'srm',
#   'bright',
#   'white',
#   'sparkle',
#   'ocean',
#   'foam',
#   'head',
#   'lace',
#   'head',
#   'retention',
#   'faint',
#   'hint',
#   'isolated',
#   'oat',
#   'shadow',
#   'traditional',
#   'miller',
#   'characteristic',
#   'present',
#   'light',
#   'watery',
#   'delicate',
#   'one',
#   'could',
#   'think',
#   'drinking',
#   'would',
#   'like',
#   'drinking',
#   'drinking',
#   'calorie',
#   'cut',
#   'abv',
#   'opposite',
#   'high',
#   'intrusive',
#   'abv'],
#  ['flavorful', 'bottle', 'water'],
#  ['change', 'size', 'fit', 'cooler', 'ya', 'twit'],
#  ['ever',
#   'since',
#   'miller',
#   'brewery',
#   'come',
#   'low',
#   'alcohol',
#   'excite',
#   'able',
#   'great',
#   'without',
#   'negative',
#   'effect',
#   'experience',
#   'miller',
#   'lite',
#   'also',
#   'take',
#   'medication',
#   'heartburn',
#   'etc',
#   'hard',
#   'time',
#   'understand',
#   'trouble',
#   'get',
#   'miller',
#   'please',
#   'stop',
#   'distribute',
#   'miller',
#   'pasco',
#   'county',
#   'florida',
#   'tampa',
#   'bay',
#   'area'],
#  ['top', 'favorite', 'beer', 'especially', 'hot', 'weather', 'hard', 'find'],
#  ['favorite',
#   'availableat',
#   'many',
#   'liquor',
#   'store',
#   'area',
#   'alot',
#   'friend',
#   'drink',
#   'also',
#   'private',
#   'club',
#   'cant',
#   'even',
#   'go',
#   'miller',
#   'company'],
#  ['fave',
#   'sad',
#   'barely',
#   'find',
#   'bottle',
#   'expensive',
#   'pack',
#   'jam',
#   'wait',
#   'ice',
#   'cold',
#   'nice',
#   'refresh',
#   'also',
#   'great',
#   'someone',
#   'tends',
#   'drink',
#   'fast',
#   'chug',
#   'everything',
#   'drink',
#   'help',
#   'keep',
#   'mind',
#   'focus',
#   'still',
#   'get',
#   'enjoy',
#   'fun'],
#  ['understand',
#   'hat',
#   'site',
#   'decent',
#   'available',
#   'u',
#   'like',
#   'able',
#   'beer',
#   'social',
#   'event',
#   'remain',
#   'unimpaired',
#   'miller',
#   'great'],
#  ['ever',
#   'get',
#   'feel',
#   'product',
#   'last',
#   'time',
#   'day',
#   'numbered',
#   'production',
#   'line',
#   'millerseltzer',
#   'gentrify',
#   'neighborhood',
#   'tomorrow',
#   'never',
#   'come',
#   'know',
#   'much',
#   'meh',
#   'dang',
#   'color',
#   'clear',
#   'bottle',
#   'dude',
#   'spill',
#   'light',
#   'water',
#   'go',
#   'hard',
#   'carbonation',
#   'fizz',
#   'upward',
#   'pour',
#   'retention',
#   'like',
#   'raineer',
#   'wolfcastle',
#   'comedy',
#   'joke',
#   'aroma',
#   'lack',
#   'component',
#   'one',
#   'water',
#   'suppose',
#   'aromatic',
#   'best',
#   'concerned',
#   'almost',
#   'afterthought',
#   'meant',
#   'something',
#   'wet',
#   'consume',
#   'run',
#   'mile',
#   'marathon',
#   'something',
#   'maybe',
#   'make',
#   'as',
#   'drink',
#   'need',
#   'keep',
#   'check',
#   'thing',
#   'notion',
#   'malt',
#   'hop',
#   'yeast',
#   'completely',
#   'lose',
#   'make',
#   'miller',
#   'lite',
#   'especially',
#   'high',
#   'life',
#   'seem',
#   'like',
#   'imperial',
#   'stout',
#   'comparison',
#   'upside',
#   'really',
#   'anything',
#   'way',
#   'flavor',
#   'lack',
#   'flavor',
#   'part',
#   'mouth',
#   'heavy'],
#  ['appearance',
#   'clear',
#   'light',
#   'gold',
#   'small',
#   'light',
#   'sweetness',
#   'corn',
#   'dryness',
#   'friend',
#   'fridge',
#   'one',
#   'review',
#   'bad',
#   'light',
#   'basically',
#   'taste',
#   'like',
#   'water',
#   'miller',
#   'lite'],
#  ['oz',
#   'clear',
#   'bottle',
#   'purchase',
#   'cold',
#   'single',
#   'pour',
#   'stella',
#   'artois',
#   'glass',
#   'l',
#   'pale',
#   'gold',
#   'liquid',
#   'initially',
#   'curiously',
#   'last',
#   'glisten',
#   'sponge',
#   'foam',
#   'leave',
#   'long',
#   'broad',
#   'crystalline',
#   'band',
#   'lace',
#   'top',
#   'urinal',
#   'cake',
#   'delicate',
#   'overtone',
#   'grain',
#   'aroma',
#   'like',
#   'rye',
#   'flour',
#   'like',
#   'high',
#   'life',
#   'strip',
#   'substance',
#   'meant',
#   'smell',
#   'bite',
#   'atop',
#   'floury',
#   'grain',
#   'flavor',
#   'subtle',
#   'flash',
#   'cereal',
#   'grain',
#   'finish',
#   'little',
#   'malt',
#   'definition',
#   'altogether',
#   'nearly',
#   'bone',
#   'dry',
#   'moderate',
#   'peppery',
#   'phenolic',
#   'spice',
#   'left',
#   'hum',
#   'palatef',
#   'definition',
#   'thin',
#   'body',
#   'mildly',
#   'sharp',
#   'spritzy',
#   'remarkably',
#   'dry',
#   'soft',
#   'spicy',
#   'warmth',
#   'lingeringo',
#   'could',
#   'glass',
#   'alter',
#   'presentation',
#   'aroma',
#   'regardless',
#   'wonderfully',
#   'dry',
#   'parch',
#   'refresh',
#   'drink',
#   'virtually',
#   'flavorless',
#   'come',
#   'territory',
#   'one',
#   'really',
#   'abstain',
#   'one',
#   'reduce'],
#  ['step',
#   'red',
#   'dog',
#   'say',
#   'much',
#   'least',
#   'cut',
#   'calorie',
#   'solid',
#   'go',
#   'michelob',
#   'available',
#   'miller',
#   'budweiser',
#   'seem',
#   'well',
#   'time',
#   'like'],
#  ['first', 'drain', 'pour', 'quite'],
#  ['much',
#   'flavor',
#   'make',
#   'excellent',
#   'golfing',
#   'right',
#   'amount',
#   'light',
#   'low',
#   'alcohol',
#   'throw',
#   'perfect',
#   'bogie',
#   'game',
#   'still',
#   'drinking',
#   'real',
#   'instead',
#   'soda',
#   'water',
#   'dig',
#   'gon',
#   'na',
#   'staple',
#   'fridge',
#   'outdoor',
#   'style',
#   'fit'],
#  ['sippy',
#   'cup',
#   'drinker',
#   'put',
#   'cap',
#   'bottle',
#   'left',
#   'night',
#   'hour',
#   'later',
#   'still',
#   'bubbling',
#   'less',
#   'beer',
#   'enjoyable',
#   'room',
#   'beer',
#   'sensitive',
#   'like',
#   'soft',
#   'red',
#   'apple',
#   'brown',
#   'rot',
#   'do',
#   'enjoy',
#   'leave',
#   'slice',
#   'apple',
#   'without',
#   'corona',
#   'lime',
#   'add',
#   'many',
#   'beer',
#   'budlight',
#   'garbage',
#   'can'],
#  ['light',
#   'remember',
#   'reminiscent',
#   'miller',
#   'lite',
#   'subtle',
#   'savory',
#   'soapy',
#   'flavor',
#   'make',
#   'special',
#   'sober',
#   'start',
#   'much',
#   'water',
#   'swear',
#   'thirst',
#   'quencher',
#   'three',
#   'look',
#   'forward'],
#  ['expect', 'much', 'taste', 'like', 'drinking', 'water', 'would', 'pay'],
#  ['dude',
#   'light',
#   'cheapest',
#   'one',
#   'since',
#   'light',
#   'taste',
#   'popular',
#   'one',
#   'year',
#   'ago',
#   'recession',
#   'hit',
#   'close',
#   'shortly',
#   'sell',
#   'start',
#   'call',
#   'millionaire',
#   'cause',
#   'everyone',
#   'pretend',
#   'rich',
#   'buying',
#   'round',
#   'everyone'],
#  ['thrown',
#   'due',
#   'alcohol',
#   'life',
#   'culprit',
#   'stink',
#   'urine',
#   'taste',
#   'like',
#   'urine',
#   'stir',
#   'sweaty',
#   'gym',
#   'sock',
#   'leaf',
#   'heaviest',
#   'nasty',
#   'hangover',
#   'ever',
#   'suffer',
#   'avoid',
#   'cost',
#   'bad',
#   'excuse',
#   'alcoholic',
#   'beverage',
#   'ever',
#   'misfortune',
#   'imbibe'],
#  ['ice', 'get', 'actually'],
#  ['usually',
#   'would',
#   'never',
#   'give',
#   'low',
#   'score',
#   'always',
#   'remember',
#   'reason',
#   'college',
#   'consistently',
#   'drank',
#   'weekly',
#   'usually',
#   'adjunct',
#   'lager',
#   'even',
#   'bad',
#   'unpalatable',
#   'even',
#   'drank',
#   'bmc',
#   'beer',
#   'reg',
#   'thought',
#   'couple',
#   'friend',
#   'pick',
#   'game',
#   'pong',
#   'college',
#   'left',
#   'sit',
#   'corner',
#   'garage',
#   'awful',
#   'try',
#   'say',
#   'bad',
#   'ever',
#   'make'],
#  ['bust',
#   'party',
#   'kid',
#   'drinking',
#   'stuff',
#   'smell',
#   'like',
#   'old',
#   'garbage',
#   'fart',
#   'one',
#   'kid',
#   'say',
#   'paid',
#   'pack',
#   'cheaper',
#   'natty',
#   'light',
#   'underage',
#   'pour',
#   'back',
#   'house',
#   'week',
#   'later',
#   'another',
#   'underage',
#   'party',
#   'grass',
#   'dead',
#   'spot',
#   'pour',
#   'last',
#   'week',
#   'batch',
#   'avoid',
#   'swill'],
#  ['note',
#   'brew',
#   'brew',
#   'dirty',
#   'gym',
#   'sock',
#   'pigfeed',
#   'pair',
#   'industrial',
#   'cleaner',
#   'strengthen',
#   'effecta',
#   'bold',
#   'drink',
#   'new',
#   'generation',
#   'trailer',
#   'trash',
#   'college',
#   'kid',
#   'moneymay',
#   'mistook',
#   'grape',
#   'soda',
#   'due',
#   'ridiculous',
#   'purple',
#   'trick',
#   'accidentally',
#   'drinking'],
#  ['know',
#   'everyone',
#   'bashing',
#   'shit',
#   'cost',
#   'like',
#   'pack',
#   'expect',
#   'golden',
#   'ambrosia',
#   'serve',
#   'chalice',
#   'angel',
#   'whistle',
#   'dong',
#   'less',
#   'think',
#   'bad',
#   'perfect',
#   'game',
#   'casual',
#   'drinking',
#   'take',
#   'bud',
#   'light',
#   'day',
#   'week',
#   'connoisseur',
#   'hell',
#   'make',
#   'get',
#   'person',
#   'buzz',
#   'save',
#   'buck',
#   'carbonation',
#   'remind',
#   'miller',
#   'lite',
#   'coors',
#   'light',
#   'lean',
#   'towards',
#   'coors',
#   'slight',
#   'aftertaste',
#   'experience',
#   'pricier',
#   'pisswater',
#   'range',
#   'honestly',
#   'stop',
#   'notice',
#   'second',
#   'smell',
#   'look',
#   'like',
#   'cheap',
#   'right',
#   'light',
#   'like',
#   'say',
#   'somewhere',
#   'miller',
#   'coors',
#   'slightly',
#   'sweeter',
#   'short',
#   'dirty',
#   'aftertaste',
#   'course',
#   'price',
#   'tag',
#   'red',
#   'dog',
#   'even',
#   'cheap',
#   'time',
#   'one',
#   'two',
#   'beer',
#   'along',
#   'side',
#   'pocket',
#   'undrinkable',
#   'sweet',
#   'nasty',
#   'one',
#   'amount',
#   'money',
#   'area',
#   'boxer',
#   'lose',
#   'lake',
#   'red',
#   'dog',
#   'side',
#   'pocket',
#   'hg',
#   'product',
#   'icehouse',
#   'etc',
#   'support',
#   'wisconsin',
#   'brewery',
#   'save',
#   'buck',
#   'next',
#   'drinking',
#   'game',
#   'record',
#   'fav',
#   'beer',
#   'alaskan',
#   'amber',
#   'wisconsin',
#   'brewery',
#   'porter',
#   'joe'],
#  ['golden',
#   'fine',
#   'stale',
#   'open',
#   'night',
#   'faintly',
#   'stale',
#   'undrinkable',
#   'somewhat',
#   'great',
#   'overly',
#   'carbonate',
#   'feel',
#   'iowa',
#   'illinois',
#   'pack',
#   'extremely',
#   'cheap',
#   'great',
#   'party',
#   'supply',
#   'vein',
#   'keystone',
#   'light',
#   'little',
#   'cheaper',
#   'far',
#   'superior',
#   'thing',
#   'consider',
#   'see',
#   'people',
#   'get',
#   'use',
#   'cause',
#   'cost',
#   'flavor',
#   'get',
#   'past',
#   'stale'],
#  ['really', 'cheap'],
#  ['drink',
#   'literally',
#   'nothing',
#   'else',
#   'well',
#   'mike',
#   'hard',
#   'smooth',
#   'though'],
#  ['say',
#   'smooooth',
#   'want',
#   'wan',
#   'na',
#   'think',
#   'sip',
#   'hot',
#   'day',
#   'work',
#   'outside',
#   'go',
#   'solid',
#   'light'],
#  ['light',
#   'money',
#   'pretty',
#   'easy',
#   'drink',
#   'like',
#   'miller',
#   'lite',
#   'easy',
#   'wallet',
#   'rate',
#   'close',
#   'genny',
#   'light',
#   'hand',
#   'well',
#   'natural',
#   'light'],
#  ['like',
#   'original',
#   'fan',
#   'one',
#   'like',
#   'mb',
#   'ice',
#   'little',
#   'sweet',
#   'go',
#   'go',
#   'easy',
#   'though',
#   'sweetness',
#   'aside',
#   'much',
#   'way',
#   'memorable',
#   'flavor'],
#  ['oz',
#   'aluminum',
#   'plastic',
#   'oz',
#   'cup',
#   'faint',
#   'aroma',
#   'surprisingly',
#   'decent',
#   'head',
#   'foam',
#   'appearance',
#   'bubble',
#   'highly',
#   'carbonate',
#   'can',
#   'bought',
#   'local',
#   'supermarket',
#   'slight',
#   'sweetness',
#   'hint',
#   'malt',
#   'grain',
#   'back',
#   'throat',
#   'clean',
#   'crisp',
#   'go',
#   'easily',
#   'low',
#   'abw',
#   'make',
#   'perfect',
#   'drinking',
#   'session',
#   'refresh',
#   'low',
#   'calorie',
#   'might',
#   'everyone',
#   'choice',
#   'though',
#   'give',
#   'bias',
#   'call',
#   'macro',
#   'brew',
#   'think',
#   'deserves',
#   'solid',
#   'b'],
#  ['bought',
#   'can',
#   'quijotelight',
#   'malt',
#   'smellclear',
#   'light',
#   'golden',
#   'colorlight',
#   'mouthfeelmedium',
#   'carbonationslightly',
#   'sweet',
#   'light',
#   'malt',
#   'flavoroverall',
#   'would',
#   'expect',
#   'cheap',
#   'light',
#   'much',
#   'could',
#   'easily',
#   'drink',
#   'lot'],
#  ['awful',
#   'sure',
#   'people',
#   'like',
#   'love',
#   'hamm',
#   'pessimistic',
#   'one',
#   'still',
#   'awful',
#   'taste',
#   'brew',
#   'taste',
#   'like',
#   'someone',
#   'filter',
#   'garbage',
#   'cooked',
#   'strain',
#   'use',
#   'plant',
#   'matter',
#   'smell',
#   'taste',
#   'like',
#   'yeast',
#   'fart'],
#  ['attract',
#   'one',
#   'price',
#   'alcohol',
#   'count',
#   'ratio',
#   'two',
#   'dollar',
#   'per',
#   'case',
#   'genny',
#   'light',
#   'cheapest',
#   'light',
#   'area',
#   'high',
#   'alcohol',
#   'content',
#   'few',
#   'calorie',
#   'akin',
#   'pricier',
#   'cousin',
#   'miller',
#   'lite',
#   'decent',
#   'lighter',
#   'color',
#   'miller',
#   'lite',
#   'similar',
#   'foamy',
#   'head',
#   'diminishes',
#   'quickly',
#   'cling',
#   'pilsner',
#   'glass',
#   'well',
#   'busch',
#   'keystone',
#   'almost',
#   'budget',
#   'light',
#   'nothing',
#   'seriously',
#   'smell',
#   'like',
#   'water',
#   'pour',
#   'glass',
#   'contain',
#   'win',
#   'award',
#   'grainy',
#   'cheap',
#   'aal',
#   'way',
#   'offensive',
#   'cooked',
#   'veggie',
#   'decent',
#   'malt',
#   'backbone',
#   'light',
#   'absolutely',
#   'zero',
#   'hop',
#   'flavor',
#   'make',
#   'less',
#   'complex',
#   'miller',
#   'lite',
#   'pretty',
#   'much',
#   'well',
#   'keystone',
#   'compete',
#   'shine',
#   'almost',
#   'miller',
#   'high',
#   'life',
#   'kinda',
#   'way',
#   'excellent',
#   'carbonation',
#   'retention',
#   'way',
#   'contribute',
#   'clingy',
#   'head',
#   'slick',
#   'oily',
#   'finish',
#   'get',
#   'busch',
#   'almost',
#   'easy',
#   'drink',
#   'price',
#   'point',
#   'tough',
#   'resist',
#   'well',
#   'alternative'],
#  ['l',
#   'pours',
#   'straw',
#   'yellow',
#   'color',
#   'head',
#   'retention',
#   'lace',
#   'pale',
#   'macro',
#   'light',
#   'sweet',
#   'malt',
#   'corn',
#   'little',
#   'hop',
#   'predictably',
#   'less',
#   'strong',
#   'scent',
#   'beast',
#   'ice',
# ...
#   'initially',
#   'surprised',
#   'somewhat',
#   'relatable',
#   'miller',
#   'lite',
#   'however',
#   'bit',
#   'sweet',
#   'hint',
#   'ricey',
#   'wax',
#   'exhale',
#   'always',
#   'turnoff',
#   'light',
#   'lager'],
#  ['pours',
#   'horse',
#   'piss',
#   'pale',
#   'yellow',
#   'white',
#   'head',
#   'smell',
#   'hay',
#   'barn',
#   'funk',
#   'horse',
#   'piss',
#   'corn',
#   'also',
#   'faint',
#   'amount',
#   'like',
#   'water',
#   'hint',
#   'actually',
#   'drinkable',
#   'high',
#   'carbonation',
#   'light',
#   'body',
#   'crushable',
#   'worthy',
#   'session',
#   'bang',
#   'buck',
#   'overstatement'],
#  ['appearance',
#   'clear',
#   'light',
#   'yellow',
#   'ok',
#   'head',
#   'fizzle',
#   'mild',
#   'corn',
#   'mild',
#   'corn',
#   'fizzy',
#   'fell',
#   'definitely',
#   'light',
#   'want',
#   'light',
#   'slightly',
#   'warmer',
#   'weekend',
#   'picked',
#   'busch',
#   'light',
#   'nothing',
#   'offensive',
#   'lot',
#   'flavor',
#   'well',
#   'bud',
#   'light',
#   'understand',
#   'common',
#   'isu',
#   'tailgate',
#   'easy',
#   'drinking',
#   'stuff'],
#  ['look',
#   'beeradvocate',
#   'help',
#   'decide',
#   'busch',
#   'light',
#   'worth',
#   'try',
#   'probably',
#   'go',
#   'quality',
#   'make',
#   'review',
#   'flavor',
#   'somewhat',
#   'like',
#   'take',
#   'pilsner',
#   'urquell',
#   'cut',
#   'tap',
#   'water',
#   'tonic',
#   'water',
#   'dash',
#   'baking',
#   'soda',
#   'high',
#   'note',
#   'low',
#   'note',
#   'imagine',
#   'anyone',
#   'regularly',
#   'drink',
#   'busch',
#   'light',
#   'even',
#   'know',
#   'term',
#   'mean',
#   'kind',
#   'point',
#   'make',
#   'share',
#   'pack',
#   'friend',
#   'maybe',
#   'sit',
#   'around',
#   'bonfire',
#   'pretty',
#   'sure',
#   'talk',
#   'anyone',
#   'busch',
#   'marketing',
#   'department',
#   'told',
#   'internet',
#   'review',
#   'product',
#   'response',
#   'would',
#   'type',
#   'drink',
#   'busch',
#   'light',
#   'trust',
#   'review',
#   'type',
#   'read',
#   'drinking',
#   'busch',
#   'rating',
#   'look',
#   'like',
#   'smell',
#   'like',
#   'taste',
#   'like',
#   'feel',
#   'like',
#   'say'],
#  ['call',
#   'god',
#   'nectar',
#   'nothing',
#   'taste',
#   'perfect',
#   'corn',
#   'right',
#   'amount',
#   'carbonation',
#   'incredibly',
#   'easy',
#   'drink',
#   'pack',
#   'disappear',
#   'quickly'],
#  ['basic',
#   'light',
#   'much',
#   'flavor',
#   'still',
#   'nice',
#   'light',
#   'flavor',
#   'nice',
#   'refresh'],
#  ['pours',
#   'light',
#   'fizzy',
#   'slight',
#   'head',
#   'crisp',
#   'light',
#   'lager',
#   'abv',
#   'bottomless',
#   'brew',
#   'happy',
#   'face',
#   'simi',
#   'valley',
#   'music',
#   'well',
#   'sparkle',
#   'water',
#   'bottom',
#   'cheer'],
#  ['drunk',
#   'trip',
#   'silao',
#   'guanajuato',
#   'méxico',
#   'normal',
#   'pale',
#   'yellow',
#   'translucid',
#   'cm',
#   'white',
#   'head',
#   'leave',
#   'citric',
#   'citric',
#   'also',
#   'light',
#   'tastefeel',
#   'light',
#   'body',
#   'medium',
#   'carbonationovearll',
#   'normal',
#   'brew'],
#  ['taste', 'like', 'water'],
#  ['pure', 'swill'],
#  ['pale',
#   'straw',
#   'expect',
#   'super',
#   'light',
#   'sweet',
#   'corn',
#   'mash',
#   'drank',
#   'number',
#   'able',
#   'accept',
#   'light',
#   'watery',
#   'honestly',
#   'drink',
#   'regular',
#   'calorie',
#   'carbs',
#   'think',
#   'bad',
#   'beer',
#   'drink'],
#  ['bought',
#   'lcbo',
#   'ontario',
#   'one',
#   'brew',
#   'canada',
#   'labbats',
#   'brewery',
#   'great',
#   'kick',
#   'plain',
#   'skunky',
#   'light',
#   'average',
#   'would',
#   'never',
#   'buy'],
#  ['friend',
#   'already',
#   'enjoy',
#   'first',
#   'time',
#   'dinner',
#   'arrive',
#   'order',
#   'ultra',
#   'second',
#   'since',
#   'several',
#   'others',
#   'table',
#   'order',
#   'best',
#   'way',
#   'describe',
#   'flavor',
#   'white',
#   'claw',
#   'sure',
#   'many',
#   'people',
#   'drank',
#   'dinner',
#   'much',
#   'rather',
#   'sip',
#   'multiple'],
#  ['fancy', 'craft', 'brew', 'never', 'claimed'],
#  ['unlike',
#   'pretentious',
#   'snob',
#   'give',
#   'fair',
#   'rating',
#   'light',
#   'lager',
#   'backbone',
#   'common',
#   'drinker',
#   'nothing',
#   'beat',
#   'refresh',
#   'cold',
#   'crisp',
#   'light',
#   'hot',
#   'summer',
#   'day',
#   'golfing',
#   'drinking',
#   'real',
#   'beer',
#   'go',
#   'crusher',
#   'mic',
#   'ultra'],
#  ['overprice',
#   'domestic',
#   'light',
#   'light',
#   'hot',
#   'day',
#   'though',
#   'right',
#   'manly',
#   'man',
#   'hand',
#   'butch',
#   'lesbian',
#   'bottle',
#   'maybe',
#   'slim',
#   'line',
#   'can'],
#  ['really',
#   'pale',
#   'yellow',
#   'clear',
#   'massive',
#   'white',
#   'head',
#   'lacingsmell',
#   'barley',
#   'grain',
#   'citrustaste',
#   'slgiht',
#   'grain',
#   'citrus',
#   'light',
#   'tastefeel',
#   'light',
#   'body',
#   'medium',
#   'carbovearll',
#   'dirty',
#   'water'],
#  ['well',
#   'awful',
#   'well',
#   'pretty',
#   'much',
#   'every',
#   'american',
#   'macro',
#   'light',
#   'lager'],
#  ['easy',
#   'drink',
#   'extremely',
#   'light',
#   'almost',
#   'flavor',
#   'profile',
#   'yet',
#   'say',
#   'amongst',
#   'american',
#   'mass',
#   'produce',
#   'light',
#   'beer',
#   'one',
#   'top',
#   'list'],
#  ['organic',
#   'michelob',
#   'ultra',
#   'gold',
#   'favorite',
#   'michelob',
#   'ultra',
#   'okay',
#   'different',
#   'product',
#   'despite',
#   'similar',
#   'name',
#   'taste',
#   'dirtier',
#   'gold',
#   'gmos',
#   'sucker',
#   'extra',
#   'light',
#   'lager',
#   'alcohol',
#   'carbs',
#   'pretty',
#   'cool',
#   'mainstream',
#   'avoid',
#   'gmos',
#   'cost',
#   'instacart',
#   'shopper',
#   'get',
#   'mistake',
#   'reason',
#   'review',
#   'stick',
#   'michelob',
#   'ultra',
#   'gold',
#   'appreciate',
#   'light',
#   'lager',
#   'skip'],
#  ['undrinkable', 'cold', 'enough', 'pretty', 'much', 'crap'],
#  ['pour',
#   'pint',
#   'glassappearance',
#   'pours',
#   'murky',
#   'tomato',
#   'juice',
#   'color',
#   'almost',
#   'head',
#   'would',
#   'expect',
#   'nose',
#   'heavy',
#   'tomato',
#   'juice',
#   'clamato',
#   'mixed',
#   'aroma',
#   'light',
#   'graininess',
#   'touch',
#   'start',
#   'quite',
#   'sweet',
#   'salty',
#   'clamato',
#   'little',
#   'bit',
#   'light',
#   'breadiness',
#   'pretty',
#   'much',
#   'sum',
#   'majority',
#   'throughout',
#   'clamato',
#   'brew',
#   'slightly',
#   'thicker',
#   'chewier',
#   'low',
#   'nope',
#   'go',
#   'back',
#   'one',
#   'sometimes',
#   'like',
#   'clamato',
#   'light',
#   'lager',
#   'top',
#   'clamato',
#   'way',
#   'much',
#   'way',
#   'sweet',
#   'salty',
#   'go'],
#  ['ounce',
#   'julian',
#   'date',
#   'feb',
#   'stamp',
#   'bottom',
#   'sure',
#   'can',
#   'best',
#   'date',
#   'serve',
#   'pint',
#   'glass',
#   'pours',
#   'hazy',
#   'color',
#   'inch',
#   'pink',
#   'head',
#   'fizzle',
#   'away',
#   'pretty',
#   'quick',
#   'much',
#   'lace',
#   'brew',
#   'smell',
#   'like',
#   'tomato',
#   'juice',
#   'clamato',
#   'salt',
#   'bit',
#   'lime',
#   'similar',
#   'aroma',
#   'mineral',
#   'peppery',
#   'flavor',
#   'noticeable',
#   'medium',
#   'bit',
#   'coat',
#   'smooth',
#   'enjoyable',
#   'drink',
#   'truthfully',
#   'longer',
#   'drink',
#   'like',
#   'know',
#   'clamato',
#   'big',
#   'improvement',
#   'modelo',
#   'chelada',
#   'earlier',
#   'today',
#   'definitely',
#   'buy',
#   'one'],
#  ['share',
#   'amongst',
#   'friend',
#   'review',
#   'notesi',
#   'ca',
#   'understand',
#   'like',
#   'much',
#   'guess',
#   'big',
#   'clamato',
#   'either',
#   'spoil',
#   'clamato',
#   'rotgut',
#   'vodka',
#   'dominate',
#   'flavor'],
#  ['get',
#   'bud',
#   'light',
#   'michelada',
#   'everybody',
#   'people',
#   'enjoy',
#   'micheladas',
#   'reason',
#   'line',
#   'micheladas',
#   'keep',
#   'grow',
#   'half',
#   'dozen',
#   'bad',
#   'review',
#   'obviously',
#   'people',
#   'dislike',
#   'micheladas',
#   'find',
#   'humorous',
#   'absurd',
#   'would',
#   'drink',
#   'sour',
#   'stout',
#   'think',
#   'great',
#   'hate',
#   'style',
#   'lmao',
#   'cmon',
#   'snob',
#   'use',
#   'common',
#   'sense'],
#  ['picked',
#   'liquor',
#   'store',
#   'tall',
#   'boy',
#   'pour',
#   'tulip',
#   'thick',
#   'bright',
#   'scarlet',
#   'sort',
#   'opaqueness',
#   'pale',
#   'rust',
#   'head',
#   'disappears',
#   'nearly',
#   'clam',
#   'gasoline',
#   'mineral',
#   'almost',
#   'like',
#   'salt',
#   'slight',
#   'rice',
#   'heavy',
#   'ethanol',
#   'lime',
#   'note',
#   'lead',
#   'way',
#   'even',
#   'heavier',
#   'clam',
#   'flavor',
#   'though',
#   'barely',
#   'noticeable',
#   'rice',
#   'wheat',
#   'present',
#   'black',
#   'pepper',
#   'viscous',
#   'barely',
#   'could',
#   'make',
#   'flavor',
#   'first',
#   'thing',
#   'come',
#   'head',
#   'fuck',
#   'drink',
#   'sake',
#   'fair',
#   'everything',
#   'drink',
#   'recognition',
#   'likely',
#   'acquire',
#   'drank',
#   'whole',
#   'thing',
#   'two',
#   'half',
#   'glass',
#   'pours',
#   'first',
#   'bad',
#   'get',
#   'way',
#   'bad',
#   'first',
#   'think',
#   'taste',
#   'like',
#   'clamato',
#   'lime',
#   'like',
#   'really',
#   'bloody',
#   'mary',
#   'note',
#   'bloody',
#   'mary',
#   'cocktail',
#   'really',
#   'thing',
#   'get',
#   'appeal',
#   'would',
#   'definitely',
#   'well',
#   'heat',
#   'lot',
#   'black',
#   'pepper',
#   'maybe',
#   'celery',
#   'wo',
#   'buy',
#   'worth',
#   'give',
#   'try'],
#  ['lot',
#   'people',
#   'judging',
#   'michelada',
#   'fairly',
#   'great',
#   'michelada',
#   'high',
#   'abv',
#   'micheladas',
#   'market',
#   'clamato',
#   'add',
#   'great',
#   'flavor',
#   'profile',
#   'refresh',
#   'delicious',
#   'complaint',
#   'could',
#   'use',
#   'lime',
#   'flavor',
#   'sometimes',
#   'add',
#   'slice',
#   'lime',
#   'make',
#   'even',
#   'well'],
#  ['typically',
#   'drinker',
#   'bloody',
#   'mary',
#   'see',
#   'lot',
#   'people',
#   'drinking',
#   'store',
#   'bought',
#   'buy',
#   'alway',
#   'het',
#   'fl',
#   'oz',
#   'bud',
#   'light',
#   'cheladas',
#   'start',
#   'drinking',
#   'time',
#   'love',
#   'em',
#   'make',
#   'pack',
#   'even',
#   'case',
#   'would',
#   'buy',
#   'want',
#   'one'],
#  ['frank',
#   'look',
#   'bad',
#   'fizzy',
#   'milky',
#   'reddish',
#   'orange',
#   'appeal',
#   'clamato',
#   'appeal',
#   'however',
#   'reminiscent',
#   'bloody',
#   'mary',
#   'tangy',
#   'herbalness',
#   'tomato',
#   'come',
#   'hint',
#   'umami',
#   'bad',
#   'really',
#   'beery',
#   'either',
#   'interest',
#   'quite',
#   'bubbly',
#   'thick',
#   'way',
#   'coat',
#   'mouth',
#   'hard',
#   'sure',
#   'think',
#   'interest',
#   'sure',
#   'mood',
#   'kind',
#   'flavor',
#   'go',
#   'bloody',
#   'mary'],
#  ['clamato',
#   'look',
#   'together',
#   'old',
#   'red',
#   'draw',
#   'guy',
#   'smell',
#   'like',
#   'clamato',
#   'bad',
#   'thing',
#   'taste',
#   'stuff',
#   'clamato',
#   'fan',
#   'fantastic',
#   'clamato',
#   'quite',
#   'enjoyable',
#   'clamato',
#   'fan',
#   'however',
#   'picante',
#   'version',
#   'would',
#   'preference',
#   'concoction',
#   'undated',
#   'ounce'],
#  ['definitely',
#   'acquire',
#   'like',
#   'tomato',
#   'juice',
#   'spicy',
#   'stuff',
#   'bloody',
#   'mary',
#   'go',
#   'love',
#   'skeptical',
#   'give',
#   'try',
#   'become',
#   'glass',
#   'get',
#   'sense',
#   'dread',
#   'ever',
#   'hospital',
#   'look',
#   'drain',
#   'grandma',
#   'hip',
#   'replacement',
#   'look',
#   'like',
#   'pours',
#   'pale',
#   'opaque',
#   'red',
#   'quickly',
#   'dissipate',
#   'head',
#   'smell',
#   'tomato',
#   'highly',
#   'carbonate',
#   'spicy',
#   'taste',
#   'bloody',
#   'mary',
#   'know',
#   'everyone',
#   'love',
#   'stuff'],
#  ['world',
#   'strangely',
#   'give',
#   'two',
#   'tomato',
#   'flavor',
#   'reason',
#   'find',
#   'question',
#   'integrity',
#   'even',
#   'drinking',
#   'rating',
#   'strange',
#   'creature',
#   'world',
#   'short',
#   'pull',
#   'bloody',
#   'mary',
#   'like',
#   'never',
#   'huge',
#   'stab',
#   'wrong',
#   'direction',
#   'macro',
#   'world',
#   'taste',
#   'like',
#   'dirty',
#   'sock',
#   'work',
#   'dipped',
#   'tomato',
#   'lime',
#   'gut',
#   'refresh',
#   'dog',
#   'as',
#   'scorch',
#   'hot',
#   'day'],
#  ['thing',
#   'bad',
#   'bud',
#   'light',
#   'bud',
#   'light',
#   'clamato',
#   'chelada',
#   'guess',
#   'get',
#   'veggie',
#   'serving',
#   'day',
#   'liquid',
#   'lunch',
#   'would',
#   'serve',
#   'purpose',
#   'reason',
#   'stay',
#   'clear'],
#  ['go',
#   'memory',
#   'since',
#   'available',
#   'korea',
#   'pours',
#   'pink',
#   'vomit',
#   'like',
#   'color',
#   'head',
#   'retention',
#   'strictly',
#   'speak',
#   'lager',
#   'salty',
#   'strong',
#   'hint',
#   'faint',
#   'whiff',
#   'clam',
#   'strong',
#   'alcohol',
#   'oddly',
#   'enough',
#   'little',
#   'way',
#   'aroma',
#   'inspires',
#   'sickly',
#   'feel',
#   'already',
#   'imagine',
#   'pour',
#   'flat',
#   'expire',
#   'tomato',
#   'juice',
#   'add',
#   'pinch',
#   'juice',
#   'rotten',
#   'lime',
#   'anyone',
#   'would',
#   'drink',
#   'stuff',
#   'mystery',
#   'thin',
#   'expect',
#   'aftertaste',
#   'reminds',
#   'water',
#   'bloody',
#   'mary',
#   'use',
#   'get',
#   'little',
#   'rock',
#   'airport',
#   'except',
#   'use',
#   'get',
#   'drunk',
#   'get',
#   'disappointed',
#   'save',
#   'money',
#   'sanity',
#   'buy',
#   'real',
#   'least',
#   'uncorrupted',
#   'bud',
#   'light',
#   'give',
#   'awful',
#   'abomination',
#   'hard',
#   'pas'],
#  ['dense',
#   'red',
#   'liquid',
#   'quickly',
#   'vanish',
#   'head',
#   'mostly',
#   'lime',
#   'clamato',
#   'lime',
#   'pepper',
#   'slight',
#   'medium',
#   'carbonation',
#   'finish',
#   'wet',
#   'heat',
#   'quick',
#   'refresh',
#   'meal',
#   'would',
#   'well',
#   'couple',
#   'piece',
#   'celery'],
#  ['thirsty',
#   'left',
#   'laundromat',
#   'grabbed',
#   'tax',
#   'know',
#   'anybody',
#   'could',
#   'make',
#   'regular',
#   'diet',
#   'stuff',
#   'rather',
#   'buy',
#   'fresh',
#   'prepared',
#   'horseradish',
#   'tomato',
#   'juice',
#   'stuff',
#   'celery',
#   'pricey',
#   'cheap',
#   'vodka',
#   'gin',
#   'make',
#   'horseradish',
#   'worcestershire',
#   'sauce',
#   'mexican',
#   'hot',
#   'sauce',
#   'last',
#   'ever',
#   'fridge'],
#  ['group',
#   'play',
#   'golf',
#   'day',
#   'one',
#   'guy',
#   'brought',
#   'enough',
#   'everyone',
#   'try',
#   'people',
#   'actually',
#   'drink',
#   'stuff',
#   'thing',
#   'say',
#   'certain',
#   'tomato',
#   'juice',
#   'next',
#   'time',
#   'say',
#   'thanks'],
#  ['pours',
#   'nice',
#   'red',
#   'finger',
#   'pink',
#   'foamy',
#   'head',
#   'sweet',
#   'tomato',
#   'real',
#   'nice',
#   'clamato',
#   'salt',
#   'celery',
#   'lime',
#   'flavor',
#   'catch',
#   'flavor',
#   'hop',
#   'malt',
#   'etc',
#   'light',
#   'crisp',
#   'much',
#   'write',
#   'home',
#   'chelada',
#   'bad',
#   'kind',
#   'like',
#   'one',
#   'probably',
#   'much',
#   'regular',
#   'bud',
#   'chelada'],
#  ['ounce',
#   'pint',
#   'glass',
#   'can',
#   'pours',
#   'moderately',
#   'reddish',
#   'color',
#   'fairly',
#   'dense',
#   'rocky',
#   'white',
#   'head',
#   'great',
#   'retention',
#   'reduces',
#   'small',
#   'cap',
#   'lingers',
#   'nice',
#   'spotty',
#   'soapy',
#   'lace',
#   'cling',
#   'glass',
#   'fair',
#   'amount',
#   'stream',
#   'carbonation',
#   'cling',
#   'bubble',
#   'glass',
#   'aroma',
#   'big',
#   'tomato',
#   'juice',
#   'lime',
#   'salt',
#   'garlic',
#   'onion',
#   'celery',
#   'chili',
#   'pepper',
#   'peppercorn',
#   'brown',
#   'sugar',
#   'lighter',
#   'note',
#   'clam',
#   'vinegar',
#   'cracker',
#   'white',
#   'bread',
#   'earthiness',
#   'damn',
#   'nice',
#   'aroma',
#   'great',
#   'balance',
#   'complexity',
#   'lime',
#   'clamato',
#   'salt',
#   'pale',
#   'malt',
#   'note',
#   'great',
#   'strength',
#   'big',
#   'tomato',
#   'juice',
#   'lime',
#   'salt',
#   'garlic',
#   'onion',
#   'celery',
#   'chili',
#   'pepper',
#   'peppercorn',
#   'brown',
#   'sugar',
#   'lighter',
#   'note',
#   'clam',
#   'vinegar',
#   'cracker',
#   'white',
#   'bread',
#   'earthiness',
#   'mild',
#   'herbal',
#   'bitterness',
#   'peppery',
#   'spiciness',
#   'finish',
#   'linger',
#   'note',
#   'tomato',
#   'juice',
#   'lime',
#   'salt',
#   'garlic',
#   'onion',
#   'celery',
#   'chili',
#   'pepper',
#   'peppercorn',
#   'brown',
#   'sugar',
#   'clam',
#   'vinegar',
#   'cracker',
#   'white',
#   'bread',
#   'earthiness',
#   'finish',
#   'bit',
#   'nice',
#   'complexity',
#   'robustness',
#   'balance',
#   'lime',
#   'clamato',
#   'salt',
#   'pale',
#   'malt',
#   'flavor',
#   'great',
#   'balance',
#   'cloy',
#   'flavor',
#   'finish',
#   'lightly',
#   'increase',
#   'dryness',
#   'linger',
#   'carbonation',
#   'medium',
#   'body',
#   'smooth',
#   'moderately',
#   'fairly',
#   'crisp',
#   'lightly',
#   'tomato',
#   'fantastic',
#   'zero',
#   'warm',
#   'alcohol',
#   'expect',
#   'mildly',
#   'increase',
#   'linger',
#   'pepper',
#   'heat',
#   'glass',
#   'pleasant',
#   'overwhelm',
#   'delicious',
#   'around',
#   'nice',
#   'complexity',
#   'robustness',
#   'balance',
#   'lime',
#   'clamato',
#   'salt',
#   'pale',
#   'malt',
#   'flavor',
#   'smooth',
#   'crisp',
#   'refresh',
#   'drink',
#   'mildly',
#   'finish',
#   'far',
#   'exceed',
#   'expectation',
#   'definitely',
#   'one',
#   'best',
#   'category',
#   'cheladas',
#   'heavy',
#   'tomato',
#   'perfect',
#   'balance',
#   'bud',
#   'light',
#   'clamato',
#   'flavor',
#   'nice',
#   'malt',
#   'presence',
#   'style',
#   'enjoyable',
#   'offering',
#   'outstanding',
#   'style',
#   'example'],
#  ['awesome', 'combination', 'poor', 'ice', 'enjoy']]

# %%
gensim_terms = corpora.Dictionary(worst3)

# %%
worst_matrix = [gensim_terms.doc2bow(w) for w in worst3]

# %%
lda = gensim.models.ldamodel.LdaModel

# %%
lda_model = lda(worst_matrix, num_topics=4, id2word=gensim_terms, random_state=0)

# %%
lda_model.print_topics(num_words=5)
# Out:
# [(0,
#   '0.034*"light" + 0.018*"like" + 0.010*"flavor" + 0.010*"one" + 0.009*"water"'),
#  (1,
#   '0.013*"like" + 0.012*"flavor" + 0.008*"light" + 0.008*"drink" + 0.007*"would"'),
#  (2,
#   '0.009*"drink" + 0.007*"water" + 0.007*"like" + 0.007*"bad" + 0.007*"best"'),
#  (3,
#   '0.018*"light" + 0.011*"like" + 0.010*"drink" + 0.009*"head" + 0.008*"malt"')]

# %% [markdown]
# ### Korean brands

# %% [markdown]
# ### Kloud

# %%
kloud2 = []

for d in kloud:
    d1 = my_tokenizer(d)
    kloud2.append(d1)

kloud2
# Out:
# [['fl',
#   'oz',
#   'store',
#   'englewood',
#   'village',
#   'colorado',
#   'abv',
#   'malt',
#   'classic',
#   'whatever',
#   'mean',
#   'premium',
#   'quality',
#   'lager',
#   'website',
#   'kloud',
#   'make',
#   'ferment',
#   'concentrate',
#   'without',
#   'dilution',
#   'water',
#   'use',
#   'original',
#   'gravity',
#   'method',
#   'make',
#   'raw',
#   'material',
#   'chosen',
#   'strict',
#   'selection',
#   'process',
#   'provide',
#   'authentic',
#   'flavor',
#   'name',
#   'kloud',
#   'composite',
#   'k',
#   'korea',
#   'cloud',
#   'similar',
#   'appearance',
#   'foam',
#   'hope',
#   'provide',
#   'represent',
#   'korea',
#   'express',
#   'product',
#   'name',
#   'appearance',
#   'look',
#   'filter',
#   'carbonate',
#   'slightly',
#   'foamy',
#   'head',
#   'vibrant',
#   'look',
#   'innocuous',
#   'bit',
#   'insipid',
#   'aroma',
#   'slightly',
#   'doughy',
#   'slighty',
#   'raw',
#   'malty',
#   'sweetness',
#   'heavy',
#   'across',
#   'board',
#   'honeyed',
#   'sweetness',
#   'hint',
#   'cidery',
#   'cane',
#   'sugar',
#   'hop',
#   'aromatics',
#   'yeast',
#   'aromatics',
#   'texture',
#   'honeyed',
#   'malt',
#   'sweetness',
#   'cheap',
#   'malt',
#   'simple',
#   'shallow',
#   'boasting',
#   'bit',
#   'robust',
#   'palate',
#   'expect',
#   'budget',
#   'lager',
#   'smooth',
#   'wet',
#   'unrefreshing',
#   'carbonate',
#   'guess',
#   'expect',
#   'watery',
#   'thin',
#   'deal',
#   'body',
#   'guess',
#   'rich',
#   'quality',
#   'label',
#   'inoffensive',
#   'albeit',
#   'oversweet',
#   'budget',
#   'lager',
#   'bit',
#   'body',
#   'japanese',
#   'chinese',
#   'taiwanese',
#   'import',
#   'competition',
#   'sneak',
#   'suspicion',
#   'pet',
#   'bottle',
#   'sell',
#   'korea',
#   'deal',
#   'cheaper',
#   'fl',
#   'oz',
#   'much',
#   'well',
#   'price',
#   'point',
#   'could',
#   'see',
#   'swill',
#   'kimchi',
#   'seoul',
#   'seek',
#   'would',
#   'bother',
#   'outside',
#   'recommend'],
#  ['cloudy',
#   'golden',
#   'body',
#   'sudsy',
#   'white',
#   'head',
#   'thick',
#   'lace',
#   'sweet',
#   'nose',
#   'cereal',
#   'malt',
#   'lead',
#   'whisper',
#   'lemon',
#   'zest',
#   'contrast',
#   'well',
#   'cereal',
#   'malt',
#   'bread',
#   'dough',
#   'light',
#   'ester',
#   'pear',
#   'add',
#   'complexity',
#   'finish',
#   'kiss',
#   'floral',
#   'hop',
#   'grain',
#   'relieve',
#   'palate',
#   'sweetness',
#   'bloat',
#   'sweet',
#   'corn',
#   'malt',
#   'textured',
#   'yet',
#   'highly',
#   'carbonate',
#   'heavier',
#   'style',
#   'still'],
#  ['bottle',
#   'pour',
#   'averbode',
#   'nice',
#   'colour',
#   'lightly',
#   'weak',
#   'light',
#   'aroma',
#   'pilsner',
#   'great',
#   'slightly',
#   'tart',
#   'nothing',
#   'outstanding',
#   'decent',
#   'lighter',
#   'would',
#   'order'],
#  ['pours',
#   'standard',
#   'translucent',
#   'gold',
#   'white',
#   'head',
#   'nice',
#   'malt',
#   'slightly',
#   'spicy',
#   'floral',
#   'hop',
#   'smell',
#   'follow',
#   'nose',
#   'slightly',
#   'honey',
#   'sweet',
#   'front',
#   'bad',
#   'memorable'],
#  ['first',
#   'experienced',
#   'context',
#   'yet',
#   'another',
#   'asian',
#   'lager',
#   'meh',
#   'something',
#   'tease',
#   'tastebud',
#   'tug',
#   'memory',
#   'hit',
#   'kölsch',
#   'kölsch',
#   'climb',
#   'ordinary',
#   'purdy',
#   'durn',
#   'gud',
#   'da',
#   'schau',
#   'du',
#   'schreck',
#   'fell',
#   'place',
#   'since',
#   'become',
#   'goto',
#   'especially',
#   'local',
#   'market',
#   'put',
#   'sale',
#   'every',
#   'week',
#   'yeasty',
#   'hit',
#   'breadiness',
#   'light',
#   'hop',
#   'abv',
#   'even',
#   'look',
#   'kölsch',
#   'stange',
#   'alles',
#   'kommt',
#   'zusammen',
#   'ordenung',
#   'prost'],
#  ['option', 'restaurant', 'go', 'meal', 'wo', 'buying', 'store'],
#  ['enjoy',
#   'ice',
#   'cold',
#   'large',
#   'quantity',
#   'well',
#   'american',
#   'light',
#   'beer',
#   'say',
#   'much',
#   'best',
#   'serve',
#   'frigid',
#   'bottle',
#   'glass',
#   'friend',
#   'pinch',
#   'can',
#   'convenience',
#   'store'],
#  ['get',
#   'one',
#   'jeong',
#   'daepo',
#   'seoul',
#   'bad',
#   'bit',
#   'hoppy',
#   'go',
#   'bbq',
#   'also',
#   'would',
#   'great',
#   'hot',
#   'weather'],
#  ['bottle',
#   'restaurant',
#   'seoul',
#   'golden',
#   'color',
#   'fluffy',
#   'white',
#   'head',
#   'smell',
#   'grain',
#   'grassy',
#   'hop',
#   'light',
#   'body',
#   'light',
#   'malt',
#   'flavor',
#   'corn',
#   'grassy',
#   'hop',
#   'one',
#   'well',
#   'beer',
#   'south',
#   'korea',
#   'although',
#   'say',
#   'much'],
#  ['pleasant',
#   'surprise',
#   'macro',
#   'beer',
#   'pretty',
#   'lame',
#   'kloud',
#   'body',
#   'flavor',
#   'color',
#   'comparable',
#   'best',
#   'american',
#   'mexican',
#   'lager']]

# %%
gensim_terms = corpora.Dictionary(kloud2)

# %%
kloud_matrix = [gensim_terms.doc2bow(w) for w in kloud2]

# %%
lda = gensim.models.ldamodel.LdaModel
lda_model = lda(kloud_matrix, num_topics=1, id2word=gensim_terms, random_state=0)
lda_model.print_topics(num_words=5)
# Out:
# [(0,
#   '0.014*"malt" + 0.011*"light" + 0.011*"hop" + 0.009*"body" + 0.009*"slightly"')]

# %% [markdown]
# ### Cass

# %%
cass2 = []

for d in cass:
    d1 = my_tokenizer(d)
    cass2.append(d1)

cass2
# Out:
# [['bottle',
#   'prince',
#   'korea',
#   'town',
#   'los',
#   'feel',
#   'straight',
#   'pretty',
#   'flat',
#   'van',
#   'gogh',
#   'zoloft',
#   'like',
#   'lot',
#   'go',
#   'vincent',
#   'dull',
#   'blank',
#   'face',
#   'sad',
#   'even',
#   'suppose',
#   'wild',
#   'spirit',
#   'one',
#   'hurray',
#   'ok'],
#  ['hey',
#   'come',
#   'definitely',
#   'awful',
#   'yeah',
#   'know',
#   'adjunct',
#   'cr',
#   'p',
#   'yeah',
#   'water',
#   'aftertaste',
#   'quite',
#   'bad',
#   'feel',
#   'well',
#   'japanese',
#   'beer',
#   'japan',
#   'lager',
#   'always',
#   'well',
#   'mention',
#   'go',
#   'food',
#   'even'],
#  ['ml',
#   'bottle',
#   'green',
#   'pea',
#   'stavanger',
#   'abv',
#   'clear',
#   'pale',
#   'golden',
#   'colour',
#   'moderate',
#   'white',
#   'head',
#   'sweetish',
#   'aroma',
#   'pilsener',
#   'malt',
#   'starch',
#   'grass',
#   'candy',
#   'fizzy',
#   'medium',
#   'sweet',
#   'flavour',
#   'element',
#   'aroma',
#   'moderate',
#   'hop'],
#  ['secret',
#   'drinking',
#   'ca',
#   'step',
#   'buy',
#   'large',
#   'plastic',
#   'bottle',
#   'variety',
#   'multiple',
#   'bottlesstep',
#   'buy',
#   'bottle',
#   'soju',
#   'multiple',
#   'bottlesstep',
#   'safe',
#   'location',
#   'ie',
#   'barrack',
#   'room',
#   'day',
#   'room',
#   'place',
#   'residence',
#   'etc',
#   'pour',
#   'solo',
#   'cup',
#   'pour',
#   'shot',
#   'two',
#   'soju',
#   'solo',
#   'cupstep',
#   'drink',
#   'enjoy',
#   'responsibly',
#   'something'],
#  ['let',
#   'real',
#   'becomes',
#   'pretty',
#   'memory',
#   'night',
#   'hongdae',
#   'mix',
#   'soju',
#   'call',
#   'bar',
#   'see',
#   'lose',
#   'phone',
#   'turn',
#   'next',
#   'morning',
#   'remember',
#   'time',
#   'friend',
#   'ca',
#   'guess',
#   'mind',
#   'purposely',
#   'block',
#   'end',
#   'day',
#   'potable',
#   'liquid',
#   'contains',
#   'alcohol'],
#  ['delicious', 'wtf', 'snob', 'bbq', 'much'],
#  ['plain', 'reminiscent', 'american', 'mass', 'produce', 'lager'],
#  ['l',
#   'color',
#   'seem',
#   'fine',
#   'head',
#   'come',
#   'pour',
#   'glass',
#   'look',
#   'hop',
#   'grain',
#   'litely',
#   'come',
#   'first',
#   'like',
#   'ordinary',
#   'american',
#   'lager',
#   'come',
#   'later',
#   'front',
#   'quite',
#   'fine',
#   'american',
#   'large',
#   'little',
#   'bit',
#   'sweet',
#   'tast',
#   'corn',
#   'come',
#   'first',
#   'swallow',
#   'bad',
#   'remains',
#   'fresh',
#   'highly',
#   'carbonate',
#   'ruin',
#   'everythingoverall',
#   'recommend',
#   'mix',
#   'soju',
#   'highly',
#   'reduces',
#   'awful',
#   'behind'],
#  ['bottle',
#   'restaurant',
#   'seoul',
#   'clear',
#   'golden',
#   'color',
#   'white',
#   'head',
#   'grassy',
#   'light',
#   'body',
#   'taste',
#   'cracker',
#   'malt',
#   'grassy',
#   'hop',
#   'typical',
#   'asian',
#   'lager',
#   'go',
#   'food',
#   'interest'],
#  ['get',
#   'bottle',
#   'samhae',
#   'jib',
#   'fatty',
#   'food',
#   'restaurant',
#   'though',
#   'bland',
#   'mass',
#   'brew',
#   'little']]

# %%
gensim_terms = corpora.Dictionary(cass2)

# %%
cass_matrix = [gensim_terms.doc2bow(w) for w in cass2]

# %%
lda = gensim.models.ldamodel.LdaModel
lda_model = lda(cass_matrix, num_topics=1, id2word=gensim_terms, random_state=0)
lda_model.print_topics(num_words=5)
# Out:
# [(0,
#   '0.016*"bottle" + 0.014*"come" + 0.012*"soju" + 0.012*"lager" + 0.009*"hop"')]

# %% [markdown]
# ### Hite

# %%
hite2 = []

for d in hite:
    d1 = my_tokenizer(d)
    hite2.append(d1)

hite2
# Out:
# [['light',
#   'easy',
#   'drinking',
#   'hint',
#   'sweetness',
#   'even',
#   'bit',
#   'soda',
#   'nose',
#   'reflect',
#   'one',
#   'lot',
#   'laud',
#   'complain'],
#  ['ml',
#   'bottle',
#   'green',
#   'pea',
#   'stavanger',
#   'abv',
#   'crystal',
#   'clear',
#   'pale',
#   'golden',
#   'colour',
#   'moderate',
#   'white',
#   'head',
#   'sweetish',
#   'aroma',
#   'pilsener',
#   'malt',
#   'grass',
#   'maize',
#   'light',
#   'body',
#   'citric',
#   'sweet',
#   'citric',
#   'flavour',
#   'note',
#   'grass',
#   'maize',
#   'modest',
#   'bitterness'],
#  ['drink',
#   'cold',
#   'cold',
#   'get',
#   'pours',
#   'clear',
#   'minimal',
#   'aroma',
#   'bland',
#   'fizzy',
#   'flavor',
#   'quick',
#   'finish',
#   'come',
#   'can',
#   'bottle',
#   'even',
#   'plastic',
#   'bottle',
#   'something'],
#  ['great',
#   'even',
#   'really',
#   'one',
#   'love',
#   'reason',
#   'always',
#   'seem',
#   'case',
#   'house',
#   'bland',
#   'boring',
#   'real',
#   'another',
#   'fantastic',
#   'hot',
#   'day',
#   'want',
#   'hop',
#   'anything',
#   'beyond',
#   'malt',
#   'rice',
#   'go',
#   'disappoint',
#   'take',
#   'sk',
#   'rendition',
#   'budweiser',
#   'kind',
#   'dig'],
#  ['drink',
#   'lot',
#   'back',
#   'old',
#   'day',
#   'korea',
#   'college',
#   'student',
#   'tight',
#   'budget',
#   'typical',
#   'blend',
#   'pale',
#   'lager',
#   'easy',
#   'drink',
#   'give',
#   'refresh',
#   'feeling',
#   'rich',
#   'aroma',
#   'lack',
#   'body',
#   'even',
#   'nowadays',
#   'korea',
#   'savor',
#   'mix',
#   'soju',
#   'make',
#   'high',
#   'alcohol',
#   'content',
#   'call',
#   'soju',
#   'macju',
#   'people',
#   'tend',
#   'enjoy',
#   'binge',
#   'drinking',
#   'get',
#   'drunk',
#   'easily',
#   'week',
#   'ago',
#   'go',
#   'local',
#   'vietnamese',
#   'restaurant',
#   'menu',
#   'give',
#   'nostalgic',
#   'feel',
#   'skip',
#   'order',
#   'singapore',
#   'would',
#   'drink',
#   'hite',
#   'meet',
#   'old',
#   'friend',
#   'high',
#   'school',
#   'college',
#   'neighborhood',
#   'tavern'],
#  ['another',
#   'asian',
#   'probably',
#   'taste',
#   'well',
#   'drinking',
#   'home',
#   'overly',
#   'special',
#   'crisp',
#   'clean',
#   'typical',
#   'light'],
#  ['hite',
#   'extra',
#   'cold',
#   'thick',
#   'frothy',
#   'head',
#   'heavy',
#   'glass',
#   'lace',
#   'bubble',
#   'mostly',
#   'clear',
#   'straw',
#   'appearance',
#   'lot',
#   'fine',
#   'powdery',
#   'sediment',
#   'throughout',
#   'aroma',
#   'pungent',
#   'yeasty',
#   'sweet',
#   'white',
#   'bread',
#   'grass',
#   'note',
#   'flavor',
#   'similar',
#   'balance',
#   'medium',
#   'hite',
#   'finish',
#   'mostly'],
#  ['ok',
#   'sip',
#   'appreciate',
#   'nuance',
#   'bouquet',
#   'complex',
#   'flavor',
#   'light',
#   'crisp',
#   'rice',
#   'lager',
#   'best',
#   'drunk',
#   'ice',
#   'cold',
#   'order',
#   'wash',
#   'spicy',
#   'asian',
#   'meal',
#   'well',
#   'yet',
#   'bbq',
#   'purpose',
#   'none',
#   'well',
#   'imho',
#   'hard',
#   'find',
#   'restaurant',
#   'brew',
#   'menu'],
#  ['pours',
#   'color',
#   'vanish',
#   'medium',
#   'size',
#   'toffee',
#   'wrap',
#   'straw',
#   'light',
#   'herbal',
#   'note',
#   'fizzy',
#   'superlight',
#   'thin',
#   'highly',
#   'basically',
#   'smell',
#   'sweet',
#   'malt',
#   'among',
#   'metallic',
#   'bubbly',
#   'carbonation',
#   'omnipresent',
#   'watery',
#   'flavor',
#   'hole',
#   'develops',
#   'surprising',
#   'dry',
#   'note',
#   'lager',
#   'light',
#   'thin',
#   'boring'],
#  ['bought',
#   'asian',
#   'grocery',
#   'like',
#   'american',
#   'adjunct',
#   'lager',
#   'well',
#   'something']]

# %%
gensim_terms = corpora.Dictionary(hite2)

# %%
hite_matrix = [gensim_terms.doc2bow(w) for w in hite2]

# %%
lda = gensim.models.ldamodel.LdaModel
lda_model = lda(hite_matrix, num_topics=1, id2word=gensim_terms, random_state=0)
lda_model.print_topics(num_words=5)
# Out:
# [(0,
#   '0.014*"light" + 0.010*"flavor" + 0.010*"drink" + 0.010*"lager" + 0.010*"cold"')]
